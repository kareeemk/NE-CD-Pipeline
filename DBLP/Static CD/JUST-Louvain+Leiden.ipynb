# %% [markdown]
# # Static Community Detection Using CDLIB and NetworkX - JUST
#
# After calculating similairties and updating the edge list with the values, we will look to execute the well-known Louvain and Leiden community detection algorithms using NetworkX library and CDLIB.

# %% [markdown]
# ## Importing Edge List w/ Weights to NetworkX
#
# NetworkX's read_weighted_edgelist function expects a simple text file with lines of the form <node1> <node2> <weight>, without headers. Since our data is in CSV format, you'll need to use Pandas (or another method) to load the CSV and adjust it to become readable.

# %%
import pandas as pd

edge_list_df = pd.read_csv('New Input/JUST_edge_list_with_similarity.csv')

print(edge_list_df)
# Out:
#        source  target    weight
# 0          p0      a1  0.810501
# 1          p0      a2  0.825994
# 2          p0      a3  0.846090
# 3          p0      a4  0.766287
# 4          p0      a5  0.839626
# ...       ...     ...       ...
# 51372  p10169   p8094  0.586715
# 51373  p10169   p7974  0.669212
# 51374  p10169   p5852  0.599799
# 51375  p10169  p10113  0.639972
# 51376  p10169  p10031  0.488926
#
# [51377 rows x 3 columns]

# %%
negative_weights = edge_list_df[edge_list_df['weight'] < 0]
print(f"Number of edges with negative weights: {len(negative_weights)}")
# Out:
# Number of edges with negative weights: 21

# %% [markdown]
# Since Louvain is not made to consider negative edge weights, we will rescale the weights such that instead of [-1, 1] being the range, it is now [0, 1], where 0 now represents perfect dissimilarity, 0.5 represents orthogonality, and 1 represents perfect similarity.

# %%
edge_list_df['weight'] = (edge_list_df['weight'] + 1) / 2

print(edge_list_df)
# Out:
#        source  target    weight
# 0          p0      a1  0.905251
# 1          p0      a2  0.912997
# 2          p0      a3  0.923045
# 3          p0      a4  0.883144
# 4          p0      a5  0.919813
# ...       ...     ...       ...
# 51372  p10169   p8094  0.793358
# 51373  p10169   p7974  0.834606
# 51374  p10169   p5852  0.799899
# 51375  p10169  p10113  0.819986
# 51376  p10169  p10031  0.744463
#
# [51377 rows x 3 columns]

# %% [markdown]
# Before we continue with the creation of a graph, NetworkX specifies that an undirected, weighted graph must not have self-loop, parallel edges (A->B, B->A), or duplicate edges.

# %%
duplicate_edges = edge_list_df.duplicated(subset=['source', 'target'], keep=False)
print(f"Number of duplicate edges: {duplicate_edges.sum()}")

self_loops = edge_list_df[edge_list_df['source'] == edge_list_df['target']]
print(f"Number of self-loops: {len(self_loops)}")
print(self_loops)

print(edge_list_df.isnull().sum())
# Out:
# Number of duplicate edges: 0
# Number of self-loops: 4
#       source target  weight
# 2030    p661   p661     1.0
# 18335  p4680  p4680     1.0
# 25834  p6225  p6225     1.0
# 45560  p9359  p9359     1.0
# source    0
# target    0
# weight    0
# dtype: int64

# %%
print(f"Number of edges before dropping self-loops: {len(edge_list_df)}")

edge_list_df = edge_list_df[edge_list_df['source'] != edge_list_df['target']]

print(f"Number of edges after dropping self-loops: {len(edge_list_df)}")
# Out:
# Number of edges before dropping self-loops: 51377
# Number of edges after dropping self-loops: 51373

# %%
# Find duplicate edges (ignoring the weight column)
duplicate_edges = edge_list_df.duplicated(subset=['source', 'target'], keep=False)

# Filter to get only the duplicate edges
parallel_edges_df = edge_list_df[duplicate_edges]

# Sort to better visualize parallel edges
parallel_edges_sorted = parallel_edges_df.sort_values(by=['source', 'target'])

print(parallel_edges_sorted)
# Out:
# Empty DataFrame
# Columns: [source, target, weight]
# Index: []

# %% [markdown]
# ## Creating Undirected Weighted Graph
#
# We iterate over the edge list DataFrame rows to add edges along with their weights to a new NetworkX graph.

# %%
import networkx as nx

def get_graph_info(graph):
    print("Number of nodes:", graph.number_of_nodes())
    print("Number of edges:", graph.number_of_edges())
    
    # Checking the graph type to provide appropriate information
    if isinstance(graph, nx.DiGraph):
        print("Graph is Directed")
    else:
        print("Graph is Undirected")

# %%
# Initialize a new graph
G = nx.MultiGraph()

# Add edges and weights
for index, row in edge_list_df.iterrows():
    source = row['source']
    target = row['target']
    weight = row['weight']
    
    # Add the edge with weight
    G.add_edge(source, target, weight=weight)

# %%
get_graph_info(G)
# Out:
# Number of nodes: 15649
# Number of edges: 51373
# Graph is Undirected

# %% [markdown]
# ## Running Louvain Using CDLIB
#
# CDlib (Community Discovery Library) is designed for community detection and analysis, providing easy access to various algorithms, including Louvain and Leiden, and tools for evaluating and visualizing the results.

# %%
from cdlib import algorithms
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'bayanpy', 'wurlitzer', 'graph_tool', 'infomap'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'pyclustering', 'ASLPAw'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'infomap'}

# %%
communities_louvain = algorithms.louvain(G)

# Accessing the number of communities/partitions
num_partitions = len(communities_louvain.communities)
print(f"Number of partitions: {num_partitions}")

# Accessing modularity
modularity = communities_louvain.newman_girvan_modularity().score
print(f"Modularity: {modularity}")
# Out:
# Number of partitions: 1697
# Modularity: 0.6216423331358831

# %% [markdown]
# ## Running Leiden Using CDLIB

# %%
# Assuming `G` is your NetworkX graph with non-negative weights
communities_leiden = algorithms.leiden(G)

# Accessing the number of communities and other properties
num_partitions = len(communities_leiden.communities)
print(f"Number of partitions: {num_partitions}")

# Accessing modularity
modularity = communities_leiden.newman_girvan_modularity().score
print(f"Modularity: {modularity}")
# Out:
# Number of partitions: 23
# Modularity: 0.7399579052237379

# %% [markdown]
# ## Saving Node List w/ Community Assignments
#
# In order for us to visualize the partitions, we need to iterate through each partition and assign an ID to every node in it. This way we can color code when visualizing to see which nodes were assigned together.

# %% [markdown]
# ### Load Node ID List
#
# This was copied from Similar+Weights folder.

# %%
import pandas as pd

# Load node IDs into a DataFrame
node_df = pd.read_csv('New Input/JUST_node_indexes.txt', header=None, names=['nodeID'])

display(node_df)
# Out:
#        nodeID
# 0      t10503
# 1      v10189
# 2      v10187
# 3      v10181
# 4      v10188
# ...       ...
# 15644  t11912
# 15645  p15275
# 15646   a2418
# 15647   a2419
# 15648  p15561
#
# [15649 rows x 1 columns]

# %%
def get_type(node_id):
    if node_id.startswith('t'):
        return 'topic'
    elif node_id.startswith('a'):
        return 'author'
    elif node_id.startswith('v'):
        return 'venue'
    elif node_id.startswith('p'):
        return 'paper'
    else:
        return 'unknown'

node_df['type'] = node_df['nodeID'].apply(get_type)

display(node_df)
# Out:
#        nodeID    type
# 0      t10503   topic
# 1      v10189   venue
# 2      v10187   venue
# 3      v10181   venue
# 4      v10188   venue
# ...       ...     ...
# 15644  t11912   topic
# 15645  p15275   paper
# 15646   a2418  author
# 15647   a2419  author
# 15648  p15561   paper
#
# [15649 rows x 2 columns]

# %%
import matplotlib.cm as cm
import matplotlib

# %% [markdown]
# ### For Louvain

# %%
# Correctly accessing the communities for iteration
n_communities = len(communities_louvain.communities)
colors = cm.get_cmap('viridis', n_communities)

# Initialize the mapping dictionary
node_community_color_map = {}

for community_id, community_nodes in enumerate(communities_louvain.communities):
    color = colors(community_id / n_communities)  # Get a color from the colormap
    color_hex = matplotlib.colors.rgb2hex(color)  # Convert the color to hex format
    
    for node in community_nodes:
        node_community_color_map[str(node)] = {"communityID": community_id, "color": color_hex}

# %%
node_df_louvain = node_df.copy()

# Add community ID, color, and type to the DataFrame
node_df_louvain['communityID'] = node_df['nodeID'].apply(lambda x: node_community_color_map[x]['communityID'] if x in node_community_color_map else -1)
node_df_louvain['color'] = node_df['nodeID'].apply(lambda x: node_community_color_map[x]['color'] if x in node_community_color_map else '#000000')

display(node_df_louvain)
# Out:
#        nodeID    type  communityID    color
# 0      t10503   topic            1  #440154
# 1      v10189   venue            1  #440154
# 2      v10187   venue            0  #440154
# 3      v10181   venue          347  #404588
# 4      v10188   venue            1  #440154
# ...       ...     ...          ...      ...
# 15644  t11912   topic          131  #481c6e
# 15645  p15275   paper            4  #440154
# 15646   a2418  author          131  #481c6e
# 15647   a2419  author          131  #481c6e
# 15648  p15561   paper            1  #440154
#
# [15649 rows x 4 columns]

# %%
# Select relevant columns if necessary and export to CSV
node_df_louvain[['nodeID', 'communityID', 'color', 'type']].to_csv('Output/node_metadata_JUST_Louvain.csv', index=False, sep=';')

# %% [markdown]
# ### For Leiden

# %%
# Correctly accessing the communities for iteration
n_communities = len(communities_leiden.communities)
colors = cm.get_cmap('viridis', n_communities)

# Initialize the mapping dictionary
node_community_color_map = {}

for community_id, community_nodes in enumerate(communities_leiden.communities):
    color = colors(community_id / n_communities)  # Get a color from the colormap
    color_hex = matplotlib.colors.rgb2hex(color)  # Convert the color to hex format
    
    for node in community_nodes:
        node_community_color_map[str(node)] = {"communityID": community_id, "color": color_hex}

# %%
node_df_leiden = node_df.copy()

# Add community ID, color, and type to the DataFrame
node_df_leiden['communityID'] = node_df['nodeID'].apply(lambda x: node_community_color_map[x]['communityID'] if x in node_community_color_map else -1)
node_df_leiden['color'] = node_df['nodeID'].apply(lambda x: node_community_color_map[x]['color'] if x in node_community_color_map else '#000000')

display(node_df_leiden)
# Out:
#        nodeID    type  communityID    color
# 0      t10503   topic            8  #2d708e
# 1      v10189   venue            4  #433e85
# 2      v10187   venue            1  #471164
# 3      v10181   venue            0  #440154
# 4      v10188   venue            4  #433e85
# ...       ...     ...          ...      ...
# 15644  t11912   topic            7  #32648e
# 15645  p15275   paper           10  #25858e
# 15646   a2418  author            7  #32648e
# 15647   a2419  author            7  #32648e
# 15648  p15561   paper            4  #433e85
#
# [15649 rows x 4 columns]

# %%
# Select relevant columns if necessary and export to CSV
node_df_leiden[['nodeID', 'communityID', 'color', 'type']].to_csv('Output/node_metadata_JUST_Leiden.csv', index=False, sep=';')

# %% [markdown]
# ## Exploring Community Assignments
#
# We would also like to explore the difference in communities between Leiden and Louvain, check whether they make sense by looking at their content, and investigate why Leiden produces significantly less communities in comparison to Louvain.

# %% [markdown]
# ### Import Original Node Information
#
# First, we import the original dataset information including tag and artist names, as well as user IDs. This way we can check if the assignment makes sense, by looking at the actual content of its nodes.
#
# For example, if there was a distinction of grouping by "Death Metal" vs. "Pop" tags.

# %%
tags_df = pd.read_csv('Extra Input/tags.dat', sep='\t', encoding='ISO-8859-1')
artists_df = pd.read_csv('Extra Input/artists.dat', sep='\t')
users_df = pd.read_csv('Extra Input/user_friends.dat', sep='\t')

artists_df = artists_df.drop(['url', 'pictureURL'], axis=1)

display(tags_df)
display(artists_df)
display(users_df)
# Out:
#        tagID           tagValue
# 0          1              metal
# 1          2  alternative metal
# 2          3          goth rock
# 3          4        black metal
# 4          5        death metal
# ...      ...                ...
# 11941  12644              suomi
# 11942  12645          symbiosis
# 11943  12646            sverige
# 11944  12647               eire
# 11945  12648     electro latino
#
# [11946 rows x 2 columns]
#           id               name
# 0          1       MALICE MIZER
# 1          2    Diary of Dreams
# 2          3  Carpathian Forest
# 3          4       Moi dix Mois
# 4          5        Bella Morte
# ...      ...                ...
# 17627  18741     Diamanda Galás
# 17628  18742             Aya RL
# 17629  18743        Coptic Rain
# 17630  18744       Oz Alchemist
# 17631  18745   Grzegorz Tomczak
#
# [17632 rows x 2 columns]
#        userID  friendID
# 0           2       275
# 1           2       428
# 2           2       515
# 3           2       761
# 4           2       831
# ...       ...       ...
# 25429    2099      1801
# 25430    2099      2006
# 25431    2099      2016
# 25432    2100       586
# 25433    2100       607
#
# [25434 rows x 2 columns]

# %% [markdown]
# To add the names of tags and artists to our main dataframes, we create dictionaries that help us directly map ID to name. We also define a function that adds the corresponding name to a new column based on the ID.

# %%
tag_dict = pd.Series(tags_df.tagValue.values, index=tags_df.tagID).to_dict()
artist_dict = pd.Series(artists_df.name.values, index=artists_df.id).to_dict()

def id_to_name(node_id):
    prefix = node_id[0]
    # Adjust this line based on the actual format of your node IDs
    numeric_part = node_id.split('_')[-1]  # This splits at the underscore and takes the last part
    
    try:
        numeric_id = int(numeric_part)
    except ValueError:
        return "Invalid ID format"
    
    if prefix == 't':
        return tag_dict.get(numeric_id, "Unknown Tag")
    elif prefix == 'a':
        return artist_dict.get(numeric_id, "Unknown Artist")
    return "Invalid prefix"

# %%
node_df_louvain['name'] = node_df_louvain['nodeID'].apply(id_to_name)
node_df_leiden['name'] = node_df_leiden['nodeID'].apply(id_to_name)

# %%
display(node_df_louvain)
display(node_df_leiden)
# Out:
#         nodeID    type  communityID    color                             name
# 0         t_24     tag            4  #440256                              pop
# 1         t_73     tag            4  #440256                             rock
# 2         t_18     tag            1  #440154                       electronic
# 3         t_81     tag            0  #440154                            indie
# 4         t_79     tag            0  #440154                      alternative
# ...        ...     ...          ...      ...                              ...
# 21513    t_403     tag            3  #440256  michael-jackson-the-king-of-pop
# 21514  a_16380  artist            2  #440154               Beyond The Embrace
# 21515   a_1637  artist          112  #3f4788               The Grouch & Eligh
# 21516   a_1635  artist          112  #3f4788                       The D.O.C.
# 21517   a_1951  artist            1  #440154                     Pomegranates
#
# [21518 rows x 5 columns]
#         nodeID    type  communityID    color                             name
# 0         t_24     tag            1  #481b6d                              pop
# 1         t_73     tag            0  #440154                             rock
# 2         t_18     tag            0  #440154                       electronic
# 3         t_81     tag            0  #440154                            indie
# 4         t_79     tag            0  #440154                      alternative
# ...        ...     ...          ...      ...                              ...
# 21513    t_403     tag            3  #3f4788  michael-jackson-the-king-of-pop
# 21514  a_16380  artist            2  #46327e               Beyond The Embrace
# 21515   a_1637  artist            6  #277f8e               The Grouch & Eligh
# 21516   a_1635  artist            6  #277f8e                       The D.O.C.
# 21517   a_1951  artist            0  #440154                     Pomegranates
#
# [21518 rows x 5 columns]

# %% [markdown]
# ### **For Louvain**

# %% [markdown]
# #### Overview of Community Data
#
# First, we aggregate the data by community ID to get an overview of each community's composition. We group our DataFrame by the community ID and then examine the types and names within each community.

# %%
# Group by community ID and list out members of each community
community_groups = node_df_louvain.groupby('communityID')

# Example to print out the composition of each community
for community_id, group in community_groups:
    print(f"Community ID: {community_id}")
    print(f"Members count: {len(group)}")
    print(group[['nodeID', 'name', 'type']].head())  # Adjust as needed
    print("\n")
# Out:
# Community ID: 0
# Members count: 3387
#   nodeID              name type
# 3   t_81             indie  tag
# 4   t_79       alternative  tag
# 6  t_292              folk  tag
# 8   t_78  alternative rock  tag
# 9   t_84        indie rock  tag
#
#
# Community ID: 1
# Members count: 3385
#    nodeID          name type
# 2    t_18    electronic  tag
# 5    t_33  experimental  tag
# 7    t_14       ambient  tag
# 11   t_13      chillout  tag
# 13  t_187   electronica  tag
#
#
# Community ID: 2
# Members count: 3115
#    nodeID         name type
# 17    t_1        metal  tag
# 18  t_376    metalcore  tag
# 20   t_72    hard rock  tag
# 28  t_386  heavy metal  tag
# 33    t_5  death metal  tag
#
#
# Community ID: 3
# Members count: 2406
#    nodeID        name type
# 19  t_625        soul  tag
# 45  t_308       latin  tag
# 55  t_512    romantic  tag
# 61  t_199  electropop  tag
# 88  t_349    teen pop  tag
#
#
# Community ID: 4
# Members count: 2280
#    nodeID      name type
# 0    t_24       pop  tag
# 1    t_73      rock  tag
# 12   t_25       80s  tag
# 15  t_352       90s  tag
# 26   t_74  synthpop  tag
#
#
# Community ID: 5
# Members count: 471
#      nodeID            name type
# 10    t_103             rap  tag
# 22    t_304         hip hop  tag
# 114   t_197     gangsta rap  tag
# 123  t_6162     hip hop/rap  tag
# 140  t_3555  east coast rap  tag
#
#
# Community ID: 6
# Members count: 325
#      nodeID           name type
# 14    t_181           punk  tag
# 29    t_182      punk rock  tag
# 47    t_169       pop punk  tag
# 81   t_1222  hardcore punk  tag
# 189  t_5939   80s hardcore  tag
#
#
# Community ID: 7
# Members count: 235
#      nodeID                name type
# 34    t_829               blues  tag
# 76    t_445          blues rock  tag
# 148  t_4258  barrelhouse covers  tag
# 182  t_1074    rhythm and blues  tag
# 228  t_6824      electric blues  tag
#
#
# Community ID: 8
# Members count: 211
#      nodeID             name type
# 35    t_193          country  tag
# 43    t_839              sad  tag
# 107  t_1096       chill zone  tag
# 138  t_4430  classic country  tag
# 144  t_6645      new country  tag
#
#
# Community ID: 9
# Members count: 134
#      nodeID            name  type
# 84    t_164           k-pop   tag
# 99   t_1249        powerpop   tag
# 141   t_145            kpop   tag
# 590   u_899  Invalid prefix  user
# 772   u_946  Invalid prefix  user
#
#
# Community ID: 10
# Members count: 110
#       nodeID            name type
# 56     t_712          gospel  tag
# 73     t_183  christian rock  tag
# 293   t_1091   inspirational  tag
# 376  t_12267    keep ya calm  tag
# 450   t_2360       uplifting  tag
#
#
# Community ID: 11
# Members count: 89
#       nodeID                      name  type
# 24     t_387          progressive rock   tag
# 108   t_1538                  art rock   tag
# 117   t_4046  italian progressive rock   tag
# 950   t_1016                 jazz rock   tag
# 1768   u_529            Invalid prefix  user
#
#
# Community ID: 12
# Members count: 87
#       nodeID          name    type
# 44     t_140         j-pop     tag
# 92    t_1316          jpop     tag
# 412   t_8414     asian pop     tag
# 611   t_2666  japanese pop     tag
# 1713  a_3324         安室奈美恵  artist
#
#
# Community ID: 13
# Members count: 76
#        nodeID                                      name    type
# 23      t_545                                 classical     tag
# 115    t_8505  the best classical opera and film scores     tag
# 831   t_11498                           classical music     tag
# 1426   t_4887                          classical terror     tag
# 2686   a_1121                   Wolfgang Amadeus Mozart  artist
#
#
# Community ID: 14
# Members count: 66
#        nodeID                       name    type
# 991    u_1161             Invalid prefix    user
# 2249   t_7554        j rock plastic tree     tag
# 4399   u_1930             Invalid prefix    user
# 4701  a_12805                      SCREW  artist
# 4708   a_5110  Dio - Distraught Overlord  artist
#
#
# Community ID: 15
# Members count: 47
#        nodeID                           name    type
# 2705   u_1499                 Invalid prefix    user
# 5384  a_14996                       Joe Wise  artist
# 6000  a_15006  Ernie Haase & Signature Sound  artist
# 6677  a_14989                     Wayne Kerr  artist
# 6741  a_15029                    The Steeles  artist
#
#
# Community ID: 16
# Members count: 46
#      nodeID         name type
# 165   t_124    pop dance  tag
# 209  t_1955         90's  tag
# 239  t_1973  house music  tag
# 570  t_1969    dance 90s  tag
# 597  t_1975    90s dance  tag
#
#
# Community ID: 17
# Members count: 44
#        nodeID               name    type
# 5115   u_1847     Invalid prefix    user
# 5830  a_17052     Alice Coltrane  artist
# 6128  a_17044      The Pop Group  artist
# 7463  a_17029  Campbell Brothers  artist
# 7607  a_17046                Zeb  artist
#
#
# Community ID: 18
# Members count: 42
#        nodeID            name    type
# 447    u_1706  Invalid prefix    user
# 796     u_726  Invalid prefix    user
# 3175   a_2804             손담비  artist
# 4594   a_2111           鬼束ちひろ  artist
# 4610  a_16163     Mr.Children  artist
#
#
# Community ID: 19
# Members count: 42
#        nodeID                                name    type
# 5331  a_12469  Smadj, Orhan Osman & Savaş Zurnacı  artist
# 6365  a_12455          Muhammed Celalettin Yüksel  artist
# 6407  a_12451               Qari Syed Sadaqat Ali  artist
# 8400  a_12446                  Aylin Şengün Taşçı  artist
# 9374  a_12471                               GOCOO  artist
#
#
# Community ID: 20
# Members count: 41
#       nodeID                    name    type
# 4222   u_360          Invalid prefix    user
# 4563  a_6109          Yuji Masubuchi  artist
# 5492  a_6108  Goemon Production Team  artist
# 6356  a_6101     Donkey Kong Country  artist
# 6740  a_6096              MegaDriver  artist
#
#
# Community ID: 21
# Members count: 40
#        nodeID             name    type
# 1494    u_820   Invalid prefix    user
# 6131  a_10336  Hugo Montenegro  artist
# 6133  a_10337   Piero Piccioni  artist
# 7249  a_10371     Margo Guryan  artist
# 7250  a_10372   John Carpenter  artist
#
#
# Community ID: 22
# Members count: 40
#        nodeID             name    type
# 4188   u_1090   Invalid prefix    user
# 5703  a_12260       Tony Rebel  artist
# 5708  a_12232       Lutan Fyah  artist
# 6460  a_12246     Warrior King  artist
# 7576  a_11074  Morgan Heritage  artist
#
#
# Community ID: 23
# Members count: 39
#       nodeID            name    type
# 930    u_467  Invalid prefix    user
# 3319  a_7208      Boris Vian  artist
# 4019  a_7227   Alain Bashung  artist
# 5262  a_7241    Marc Lavoine  artist
# 5552  a_7237            Luke  artist
#
#
# Community ID: 24
# Members count: 39
#         nodeID            name    type
# 3798    u_1315  Invalid prefix    user
# 4746   a_13827    Thavius Beck  artist
# 5985   a_13826           Adlib  artist
# 7815   a_13790            Soso  artist
# 11592  a_13809   Animal Nation  artist
#
#
# Community ID: 25
# Members count: 38
#         nodeID                            name    type
# 3424    u_1721                  Invalid prefix    user
# 5623   a_16287                 Rockabilly Rebs  artist
# 8943   a_16301                   Moon Mullican  artist
# 10554   a_4722                       Batmobile  artist
# 11240  a_16309  Wildfire Willie & The Ramblers  artist
#
#
# Community ID: 26
# Members count: 38
#        nodeID                   name    type
# 4394   u_1854         Invalid prefix    user
# 6163  a_17135  Turkish Military Band  artist
# 8088  a_17121     Djelimady Tounkara  artist
# 8231  a_17101         Talib al-Habib  artist
# 8532  a_17116           حسين الاعظمي  artist
#
#
# Community ID: 27
# Members count: 35
#       nodeID                          name    type
# 1527   u_296                Invalid prefix    user
# 5038  a_5388                   The Rockats  artist
# 5039  a_5387                 Andy Anderson  artist
# 5300  a_5407  Frank Yankovic and His Yanks  artist
# 5803  a_5373                    Eddie Bond  artist
#
#
# Community ID: 28
# Members count: 34
#        nodeID           name    type
# 65      t_139         j-rock     tag
# 102    t_1219          jrock     tag
# 2307   t_7571        j  rock     tag
# 2359    a_396  L'Arc~en~Ciel  artist
# 3006  t_11763        jap rap     tag
#
#
# Community ID: 29
# Members count: 34
#        nodeID            name    type
# 4154    u_810  Invalid prefix    user
# 7139   a_2338    Şebnem Ferah  artist
# 7574  a_10253           Kıraç  artist
# 7696  a_10270       paylas.de  artist
# 8466  a_10257           Şenay  artist
#
#
# Community ID: 30
# Members count: 34
#       nodeID                            name    type
# 1601   u_238                  Invalid prefix    user
# 4456  a_4662        The Flying Luttenbachers  artist
# 4457  a_4660  Henry Threadgill & Make a Move  artist
# 7188  a_4652                       Last Exit  artist
# 7388  a_4664                         Wozzeck  artist
#
#
# Community ID: 31
# Members count: 34
#       nodeID            name    type
# 3096   u_552  Invalid prefix    user
# 4844  a_7974    AXiS & Trank  artist
# 7013  a_7985        Temulent  artist
# 8771  a_7957      Hemoglobin  artist
# 8897  a_7973         ZuBCoRe  artist
#
#
# Community ID: 32
# Members count: 34
#        nodeID                  name    type
# 906    u_1882        Invalid prefix    user
# 4424   a_9397  Ramallah Underground  artist
# 4488  a_17351            Panjabi MC  artist
# 5188  a_17349         Issa Bagayogo  artist
# 5316  a_17336               Abdelli  artist
#
#
# Community ID: 33
# Members count: 33
#       nodeID            name    type
# 58     t_265             ska     tag
# 1294   u_507  Invalid prefix    user
# 4967  a_7534      Los Cafres  artist
# 6689   a_201       Ленинград  artist
# 6789  a_7555     Dermis Tatú  artist
#
#
# Community ID: 34
# Members count: 32
#      nodeID                     name    type
# 1061    u_3           Invalid prefix    user
# 5804  a_111  Pleq & Anna Rose Carter  artist
# 7440  a_147           Svarte Greiner  artist
# 7650  a_125                   aslope  artist
# 8401  a_124  Shinkei & Mise En Scene  artist
#
#
# Community ID: 35
# Members count: 32
#       nodeID             name    type
# 3977   u_661   Invalid prefix    user
# 4336  a_9045         Bandista  artist
# 5938  a_9065  Anita Livstrand  artist
# 5939  a_9062           Oneira  artist
# 6759  a_9076      Yavuz Çetin  artist
#
#
# Community ID: 36
# Members count: 32
#       nodeID                                 name    type
# 1040   u_508                       Invalid prefix    user
# 4390  a_7576          Chief Stephen Osita Osadebe  artist
# 5642  a_7565                           Baaba Maal  artist
# 6942  a_7572        Tunji Oyelana and the Benders  artist
# 7609  a_7591  Oscar Sulley & the Uhuru Dance Band  artist
#
#
# Community ID: 37
# Members count: 31
#        nodeID            name    type
# 3310   u_1867  Invalid prefix    user
# 8851  a_17268       ПОРТ(812)  artist
# 8856  a_17263           Avail  artist
# 8878  a_17241            Смех  artist
# 8879  a_17244       Agitators  artist
#
#
# Community ID: 38
# Members count: 31
#        nodeID            name    type
# 994    u_1719  Invalid prefix    user
# 3690  a_16236       にせんねんもんだい  artist
# 4576  a_16251    COLTEMONIKHA  artist
# 4641  a_11878             ミドリ  artist
# 4774  a_16238   Kazumi Totaka  artist
#
#
# Community ID: 39
# Members count: 30
#       nodeID                  name    type
# 2796   u_618        Invalid prefix    user
# 6866  a_8633              Dianogah  artist
# 6867  a_8635                Klowns  artist
# 6868  a_8634  Moscow Death Brigade  artist
# 6869  a_8636                Диета!  artist
#
#
# Community ID: 40
# Members count: 30
#       nodeID                   name    type
# 6315  a_3529            Supersilent  artist
# 6470  a_5851  Oneohtrix Point Never  artist
# 9216  a_5862  Oidupaa Vladimir Oiun  artist
# 9217  a_5860              Off Minor  artist
# 9218  a_5869               Depakote  artist
#
#
# Community ID: 41
# Members count: 29
#         nodeID            name    type
# 3225    u_1371  Invalid prefix    user
# 6564   a_14164       Ska;L?5;L  artist
# 10874  a_14177       Pink Punk  artist
# 10885  a_14174         Coaxial  artist
# 11537  a_14155     Invader Zim  artist
#
#
# Community ID: 42
# Members count: 27
#       nodeID            name    type
# 1755   u_660  Invalid prefix    user
# 4502  a_9024    Sofia Rotaru  artist
# 6195  a_9022        Code Red  artist
# 6197  a_9027          Paulla  artist
# 7973  a_9031  Urban Symphony  artist
#
#
# Community ID: 43
# Members count: 27
#        nodeID              name    type
# 2136   u_1891    Invalid prefix    user
# 4080  a_17440  Михаил Пилявский  artist
# 6225  a_16748    Mr. Projectile  artist
# 7240  a_17446          DJ Zahar  artist
# 7634  a_17451       Cleanscreen  artist
#
#
# Community ID: 44
# Members count: 27
#         nodeID                 name    type
# 3580    u_1939       Invalid prefix    user
# 5198   a_17754           MOSAIC.WAV  artist
# 6820    a_8400        Silver Forest  artist
# 9319   a_17774     Kuwatani Natsuko  artist
# 11721  a_17767  hoshina anniversary  artist
#
#
# Community ID: 45
# Members count: 27
#       nodeID            name    type
# 2325   u_607  Invalid prefix    user
# 6035  a_8516      Gallhammer  artist
# 6090  a_8542  G&G Sindikatas  artist
# 7446  a_8520        Disiplin  artist
# 7818  a_8525   Dissimulation  artist
#
#
# Community ID: 46
# Members count: 27
#        nodeID                   name    type
# 1114   u_1221         Invalid prefix    user
# 3859  a_13247             Riverdales  artist
# 4842  a_13261               Get Bent  artist
# 4891  a_13249           the peabodys  artist
# 5500  a_13250  Balance and Composure  artist
#
#
# Community ID: 47
# Members count: 26
#       nodeID            name    type
# 3475   u_663  Invalid prefix    user
# 4790  a_9099            米倉千尋  artist
# 5581  a_2000         いきものがかり  artist
# 7124  a_9112           スガシカオ  artist
# 8434  a_9092            平原綾香  artist
#
#
# Community ID: 48
# Members count: 26
#       nodeID            name    type
# 2169    u_81  Invalid prefix    user
# 4674  a_2244       Alborosie  artist
# 5362  a_2259             MSJ  artist
# 6508  a_2224         Alkpote  artist
# 7371  a_2230      Roi Heenok  artist
#
#
# Community ID: 49
# Members count: 26
#        nodeID            name    type
# 4252    u_601  Invalid prefix    user
# 4340  t_10828       doom rock     tag
# 7238   a_2307  Zülfü Livaneli  artist
# 7366   a_8444         Pinhani  artist
# 9284   a_8437     Fatih Yaşar  artist
#
#
# Community ID: 50
# Members count: 26
#        nodeID            name    type
# 4983   u_2095  Invalid prefix    user
# 6750  a_18669      Kızılırmak  artist
# 6815  a_18689      Yalçın Gül  artist
# 7638   a_8699             Vas  artist
# 8234  a_18676     Mehmet Atlı  artist
#
#
# Community ID: 51
# Members count: 26
#       nodeID                                          name    type
# 3466   u_291                                Invalid prefix    user
# 6264  a_5273              Naturi Naughton & Collins Pennie  artist
# 6265  a_5276  Naturi Naughton, Asher Booke & Kay Panabaker  artist
# 7635  a_5290            Garrett Hedlund & Leighton Meester  artist
# 7750  a_5294                                          Finn  artist
#
#
# Community ID: 52
# Members count: 26
#        nodeID                       name    type
# 4873    u_801             Invalid prefix    user
# 6141  a_10156             Ce Ce Peniston  artist
# 7575  a_10155  Elton John & Leon Russell  artist
# 8467  a_10152                 Barry Gibb  artist
# 8927  a_10151   Gladys Knight & The Pips  artist
#
#
# Community ID: 53
# Members count: 25
#         nodeID                       name    type
# 3095    u_1166             Invalid prefix    user
# 6584   a_12863  Maldini, Vegas & D-Bridge  artist
# 8322   a_12855                     Mimosa  artist
# 8770    a_7954                      Audio  artist
# 11312   a_3725                      Bar 9  artist
#
#
# Community ID: 54
# Members count: 25
#       nodeID                      name    type
# 110   t_2141          my indie friends     tag
# 2476   u_217            Invalid prefix    user
# 4904  a_4416  Electromagnetic Impulses  artist
# 4905  a_4419        Nessie & Her Beard  artist
# 5580  a_4402                    Ugress  artist
#
#
# Community ID: 55
# Members count: 25
#        nodeID             name    type
# 2853   u_1426   Invalid prefix    user
# 5700  a_14072  Johnny Burnette  artist
# 5914  a_14503       Boz Boorer  artist
# 5915  a_14506    Die Echocords  artist
# 5916  a_14505     Warren Smith  artist
#
#
# Community ID: 56
# Members count: 24
#      nodeID                  name    type
# 1260   u_16        Invalid prefix    user
# 5373  a_645              Stavento  artist
# 6510  a_650  Giorgos Papadopoulos  artist
# 6654  a_671  Alkistis Protopsalti  artist
# 6909  a_639       Milan Stanković  artist
#
#
# Community ID: 57
# Members count: 24
#       nodeID             name    type
# 3618   u_382   Invalid prefix    user
# 7229  a_6331    Ugly Duckling  artist
# 7230  a_6335             El-P  artist
# 8850  a_6326             Shad  artist
# 9037  a_3678  Digable Planets  artist
#
#
# Community ID: 58
# Members count: 24
#         nodeID                name    type
# 5644   a_17546         Celo & Abdi  artist
# 9275    a_5677              Massiv  artist
# 10808   u_1912      Invalid prefix    user
# 12359  a_17543  Bass Sultan Hengzt  artist
# 12946  a_10878               Shiml  artist
#
#
# Community ID: 59
# Members count: 24
#       nodeID             name    type
# 2916   u_131   Invalid prefix    user
# 4401  a_3133        Scientist  artist
# 4962  a_3168  King Earthquake  artist
# 7352  a_3130    Jackie Mittoo  artist
# 7479  a_3167     Jacob Miller  artist
#
#
# Community ID: 60
# Members count: 24
#         nodeID                      name    type
# 6753    a_5810    Original Broadway Cast  artist
# 6951    u_1576            Invalid prefix    user
# 7006   a_15406  The Hives & Cyndi Lauper  artist
# 8695    a_4815         Kristin Chenoweth  artist
# 13633  a_15408             Rebecca Caine  artist
#
#
# Community ID: 61
# Members count: 24
#       nodeID             name    type
# 2395   u_394   Invalid prefix    user
# 6002  a_4467           Pixote  artist
# 6164  a_6475  Leões de Israel  artist
# 6319  a_6469        Mato Seco  artist
# 7237  a_6483        Falamansa  artist
#
#
# Community ID: 62
# Members count: 24
#        nodeID            name    type
# 6332  a_16190          Heroin  artist
# 6733   u_1710  Invalid prefix    user
# 8305  a_16187          Meanna  artist
# 8315  a_16192     Munen Musin  artist
# 9102  a_16189     The Priests  artist
#
#
# Community ID: 63
# Members count: 24
#        nodeID             name    type
# 5551   a_6345    Little Dragon  artist
# 7113  a_18161  Stian Westerhus  artist
# 7114  a_18162             PUMA  artist
# 7115  a_18165   Dorian Concept  artist
# 9153  a_18175     Terje Rypdal  artist
#
#
# Community ID: 64
# Members count: 24
#       nodeID            name    type
# 3554   u_444  Invalid prefix    user
# 4307  a_6981    Thomas Köner  artist
# 5705  a_6988     Flint Glass  artist
# 7169  a_6654     Allerseelen  artist
# 9601  a_6989          Endura  artist
#
#
# Community ID: 65
# Members count: 24
#         nodeID                            name    type
# 6066   a_15855                   The Diskettes  artist
# 6997   a_15873  The Scotland Yard Gospel Choir  artist
# 7134   a_15851                     Tender Trap  artist
# 13043  a_15857                       Boy Crazy  artist
# 13053  a_15854       Saturday Looks Good to Me  artist
#
#
# Community ID: 66
# Members count: 23
#         nodeID                  name    type
# 4619    u_1755        Invalid prefix    user
# 9021   a_16465                 Vordr  artist
# 9821   a_16467  Satanicpornocultshop  artist
# 12348  a_16466         Liquid Liquid  artist
# 12350  a_16464                  V/Vm  artist
#
#
# Community ID: 67
# Members count: 23
#        nodeID                               name    type
# 1775    u_929                     Invalid prefix    user
# 4703  a_11138                             ghouti  artist
# 5444  a_11141  Cheb Khaled feat. Cheba Zahouania  artist
# 5794  a_11149                          Tom Snare  artist
# 6713  a_11136                             Khaled  artist
#
#
# Community ID: 68
# Members count: 23
#        nodeID            name    type
# 2495   u_1848  Invalid prefix    user
# 4355  a_14356      Bilge Pump  artist
# 5965  a_17074          Chacda  artist
# 6093   a_2290      Sky Larkin  artist
# 6681  a_14353         Cowtown  artist
#
#
# Community ID: 69
# Members count: 23
#        nodeID                                name    type
# 4157    u_115                      Invalid prefix    user
# 6787   a_2890  Rod Piazza & The Blues Instigators  artist
# 8544   a_2884          MORBLUS - Funky Blues Band  artist
# 10638  a_2876                          Ann Rabson  artist
# 13437  a_2878                         Finis Tasby  artist
#
#
# Community ID: 70
# Members count: 23
#       nodeID                name    type
# 897    u_122      Invalid prefix    user
# 4642  a_3013    Jimmie Lunceford  artist
# 4954  a_2991         Fats Waller  artist
# 8549  a_3008        Cab Calloway  artist
# 9368  a_3002  Fletcher Henderson  artist
#
#
# Community ID: 71
# Members count: 23
#       nodeID            name    type
# 721    u_561  Invalid prefix    user
# 5719  a_4580        Shareefa  artist
# 6298  a_8087     Drew Sidora  artist
# 8251  a_8095   Brandon Hines  artist
# 8682  a_8073        Mashonda  artist
#
#
# Community ID: 72
# Members count: 23
#        nodeID               name    type
# 5685   a_5353        Buju Banton  artist
# 6411   a_5330             Haltya  artist
# 8119   a_5328  Eraser vs Yöjalka  artist
# 10217  a_5334         Salakavala  artist
# 14534  a_5354            Mauxuam  artist
#
#
# Community ID: 73
# Members count: 23
#       nodeID            name    type
# 6936  a_6372           Julie  artist
# 6937  a_6370          Simone  artist
# 7082  a_6353      Kim Larsen  artist
# 7693  a_6355    Lars Lilholt  artist
# 8273   u_386  Invalid prefix    user
#
#
# Community ID: 74
# Members count: 22
#        nodeID            name    type
# 215     t_723       reggaeton     tag
# 2115   u_1229  Invalid prefix    user
# 3448   u_1401  Invalid prefix    user
# 3488   a_1433    Daddy Yankee  artist
# 5119  a_13303   Tego Calderon  artist
#
#
# Community ID: 75
# Members count: 22
#      nodeID                name    type
# 3236   u_14      Invalid prefix    user
# 5204  a_560         The Woggles  artist
# 6346  a_556       The Strollers  artist
# 6347  a_551     The Satelliters  artist
# 8601  a_586  Professor Longhair  artist
#
#
# Community ID: 76
# Members count: 22
#         nodeID               name    type
# 3145    u_1276     Invalid prefix    user
# 5341    a_8931         Cruel Hand  artist
# 8252   a_13628  Socially Retarded  artist
# 8626   a_13614    Reversal of Man  artist
# 11182  a_13617          Tim Barry  artist
#
#
# Community ID: 77
# Members count: 22
#        nodeID                                name    type
# 5964  a_18111                                Z-Ro  artist
# 6254   u_1996                      Invalid prefix    user
# 7245  a_18106  Ramon Ayala Y Los Bravos Del Norte  artist
# 7246  a_18105                          Chalie Boy  artist
# 8323  a_12854                       High Contrast  artist
#
#
# Community ID: 78
# Members count: 22
#        nodeID             name    type
# 5604   a_2731      Кажэ Обойма  artist
# 6623   a_2721       MICROCOBRA  artist
# 10825  a_2722          Snork25  artist
# 11421  a_2703           Ed Cox  artist
# 13049  a_2720  Electric Dragon  artist
#
#
# Community ID: 79
# Members count: 21
#         nodeID             name    type
# 3166    u_1694   Invalid prefix    user
# 6148     a_284  Dilated Peoples  artist
# 6154   a_16081    NickT Records  artist
# 8190    a_2237       Busta Flex  artist
# 10966  a_16088              C2C  artist
#
#
# Community ID: 80
# Members count: 21
#        nodeID          name    type
# 36      t_311        reggae     tag
# 441    t_1468  roots reggae     tag
# 5136  a_16098       Culture  artist
# 7830   a_3134   Horace Andy  artist
# 9062   a_5849    Diana King  artist
#
#
# Community ID: 81
# Members count: 21
#       nodeID             name    type
# 3805    u_83   Invalid prefix    user
# 7098  a_2325    Mehmet Güreli  artist
# 7099  a_2321   Müzeyyen Senar  artist
# 7213  a_2311  Kostas Pavlidis  artist
# 7848   a_384           Fairuz  artist
#
#
# Community ID: 82
# Members count: 21
#       nodeID                   name    type
# 3233   u_533         Invalid prefix    user
# 4562  a_7506                   Bond  artist
# 5983  a_2441           Celtic Woman  artist
# 7618  a_7842  Marco Antonio Vázquez  artist
# 9333  a_6860       Declan Galbraith  artist
#
#
# Community ID: 83
# Members count: 21
#        nodeID             name    type
# 1964   u_1484   Invalid prefix    user
# 5441  a_10320  Helge Schneider  artist
# 6022  a_14838      xREPRESENTx  artist
# 6417   a_3034           K.I.Z.  artist
# 7632   a_5628    The Cool Kids  artist
#
#
# Community ID: 84
# Members count: 21
#         nodeID                name    type
# 3339     u_834      Invalid prefix    user
# 6204   a_10488             Стингер  artist
# 6205   a_10485               Газон  artist
# 10106  a_10505            Таке-Тшо  artist
# 10108  a_10503  10-20 БЕЗ ВЫХОДНЫХ  artist
#
#
# Community ID: 85
# Members count: 21
#         nodeID               name    type
# 4835   a_15506  Break the Silence  artist
# 6074   a_15496      Much The Same  artist
# 6873    u_1599     Invalid prefix    user
# 7135   a_15503       Order!Order!  artist
# 10753  a_15497     I Sea Monsters  artist
#
#
# Community ID: 86
# Members count: 21
#         nodeID               name    type
# 1785    u_1971     Invalid prefix    user
# 7846   a_17935  Sabertooth Zombie  artist
# 7905    a_5227          Mortician  artist
# 8297   a_17952           Betrayed  artist
# 10200   a_5632              Verse  artist
#
#
# Community ID: 87
# Members count: 21
#        nodeID            name    type
# 4623   u_1193  Invalid prefix    user
# 5737  a_13020            Zeus  artist
# 5944   a_3650          T.Love  artist
# 7532  a_13024       Kastracja  artist
# 8763   a_3638    Defekt Muzgó  artist
#
#
# Community ID: 88
# Members count: 21
#       nodeID                name    type
# 387    u_655      Invalid prefix    user
# 5667  a_8966                Nina  artist
# 6865  a_8976  Melissa Manchester  artist
# 9076  a_8977          Raul Midón  artist
# 9077  a_8979               Rufus  artist
#
#
# Community ID: 89
# Members count: 20
#        nodeID            name type
# 139     t_297        pop-rock  tag
# 623   t_10393  indie-romantic  tag
# 782   t_10392   romantic rock  tag
# 828    t_1186         poprock  tag
# 1193  t_10395       love-rock  tag
#
#
# Community ID: 90
# Members count: 20
#       nodeID               name    type
# 4017   u_576     Invalid prefix    user
# 6052  a_8216  General Elektriks  artist
# 6290  a_8222   Digital Alkemist  artist
# 8665  a_8200         Freakpower  artist
# 9460  a_8218       Berry Weight  artist
#
#
# Community ID: 91
# Members count: 20
#         nodeID                    name    type
# 6727   a_15717  When Saints Go Machine  artist
# 7052    a_3257    The Rumour Said Fire  artist
# 9452   a_15711                    Kira  artist
# 11478  a_14124    Big Bad Voodoo Daddy  artist
# 14651   u_1630          Invalid prefix    user
#
#
# Community ID: 92
# Members count: 20
#       nodeID                    name    type
# 2627   u_262          Invalid prefix    user
# 5797  a_4972            Jocelyn Pook  artist
# 5798  a_4973  CCCP Fedeli alla linea  artist
# 5931  a_4956              Monumentum  artist
# 7140  a_4960                   Aarni  artist
#
#
# Community ID: 93
# Members count: 20
#       nodeID              name    type
# 79     t_253        rockabilly     tag
# 275    t_261        punkabilly     tag
# 512    t_262  50s rock revival     tag
# 4528  a_7239        Stray Cats  artist
# 6567  a_3455       Nekromantix  artist
#
#
# Community ID: 94
# Members count: 20
#         nodeID                            name    type
# 6357   a_17580                           Zowie  artist
# 7218   a_17579  Mirko Oberto feat. Amanda Lear  artist
# 11583  a_17588                     Chris Bondy  artist
# 11584  a_17589                         Violens  artist
# 11585  a_17582                       Dirt Club  artist
#
#
# Community ID: 95
# Members count: 20
#        nodeID              name    type
# 2709   u_1794    Invalid prefix    user
# 4910  a_16352         Kisschasy  artist
# 8476  a_16712      Sleep Parade  artist
# 8477  a_16713  National Product  artist
# 8725   a_9936            Yashin  artist
#
#
# Community ID: 96
# Members count: 20
#        nodeID                        name    type
# 3185   u_1330              Invalid prefix    user
# 6966  a_10333              Piero Umiliani  artist
# 7066  a_13928                 Enoch Light  artist
# 7069  a_13920  Sérgio Mendes & Brasil '66  artist
# 7070  a_13922                     Blowfly  artist
#
#
# Community ID: 97
# Members count: 20
#        nodeID                                     name    type
# 3396   u_1123                           Invalid prefix    user
# 7538  a_12487  Empire! Empire! (I Was A Lonely Estate)  artist
# 7539  a_12488                        Teenage Cool Kids  artist
# 7540  a_12489                                    1994!  artist
# 7777  a_12492                     Algernon Cadwallader  artist
#
#
# Community ID: 98
# Members count: 20
#       nodeID            name    type
# 1989   u_727  Invalid prefix    user
# 4984  a_9613        Skarface  artist
# 5771  a_9601     Judge Dread  artist
# 9484  a_9623      Stomper 98  artist
# 9834  a_9609  The Techniques  artist
#
#
# Community ID: 99
# Members count: 20
#        nodeID              name    type
# 3721   u_1779    Invalid prefix    user
# 6049  a_13478           Austere  artist
# 6509  a_16642           Ophelia  artist
# 6604  a_16645       Grey Waters  artist
# 8374  a_16635  Sleeping Peonies  artist
#
#
# Community ID: 100
# Members count: 20
#        nodeID            name type
# 4853  t_11215  singalong punk  tag
# 5932   t_2881       punk-rock  tag
# 7007   t_8080       power-pop  tag
# 7651  t_11199  old skool punk  tag
# 9228  t_11203        punk-pop  tag
#
#
# Community ID: 101
# Members count: 19
#        nodeID                        name    type
# 3141   u_1398              Invalid prefix    user
# 6124  a_14316  The Chorus (Les Choristes)  artist
# 6126  a_14319             4Tops & KAT-TUN  artist
# 7078  a_11236                Superchic[k]  artist
# 7370    a_394                        山下智久  artist
#
#
# Community ID: 102
# Members count: 19
#        nodeID            name    type
# 1807   u_1890  Invalid prefix    user
# 5886  a_17425            ST1M  artist
# 7897    a_483           Centr  artist
# 8042  a_17432     Пост Мортем  artist
# 8130   a_4892            Лион  artist
#
#
# Community ID: 103
# Members count: 19
#       nodeID             name    type
# 3444   u_752   Invalid prefix    user
# 5401  a_9800      Daggermouth  artist
# 5906  a_8681  Close Your Eyes  artist
# 6775  a_9803   Heart To Heart  artist
# 8986  a_9812    Crucial Dudes  artist
#
#
# Community ID: 104
# Members count: 19
#       nodeID            name    type
# 518    u_247  Invalid prefix    user
# 5824  a_4754     Silverstone  artist
# 5966  a_4760    Adelitas Way  artist
# 7195  a_4738    Static Cycle  artist
# 7380  a_4753          Vonray  artist
#
#
# Community ID: 105
# Members count: 19
#        nodeID                           name    type
# 3579   a_7091                    Michel Teló  artist
# 5968   a_7094            Jammil e uma Noites  artist
# 9986    u_456                 Invalid prefix    user
# 10431  a_7090                   Estudio Base  artist
# 10432  a_7092  Jorge e Mateus (Ao Vivo 2009)  artist
#
#
# Community ID: 106
# Members count: 19
#         nodeID           name    type
# 5882    a_5566             신화  artist
# 7399   a_10938            Mr.  artist
# 8903   a_10548      Epik High  artist
# 12310  a_10939  Vanilla Unity  artist
# 12318  a_10937         HAKUEI  artist
#
#
# Community ID: 107
# Members count: 19
#         nodeID            name    type
# 3352    u_2048  Invalid prefix    user
# 4705    a_7059          Sylvan  artist
# 6472   a_18414    Bill Bruford  artist
# 6545   a_18395    Norman Brown  artist
# 11965  a_18411    Marc Antoine  artist
#
#
# Community ID: 108
# Members count: 19
#        nodeID                  name    type
# 2252   u_1047        Invalid prefix    user
# 5570  a_11986  Combatwoundedveteran  artist
# 7144  a_11994             Trap Them  artist
# 7145  a_11992                 Khann  artist
# 8614  a_11982            Doomriders  artist
#
#
# Community ID: 109
# Members count: 19
#        nodeID                    name    type
# 2490   u_1807          Invalid prefix    user
# 5715  a_16800  Le pré où je suis mort  artist
# 6964  a_10449                  Orchid  artist
# 7001  a_16788   The Saddest Landscape  artist
# 8945  a_16795         Endless Inertia  artist
#
#
# Community ID: 110
# Members count: 19
#         nodeID                  name    type
# 4607    a_8843           Glenn Gould  artist
# 5676     u_996        Invalid prefix    user
# 7325   a_11659            Art Pepper  artist
# 12237  a_11669           Sonny Stitt  artist
# 14575  a_11658  Sérgio & Odair Assad  artist
#
#
# Community ID: 111
# Members count: 18
#         nodeID               name    type
# 409     u_1761     Invalid prefix    user
# 6358   a_16510        Peter Brown  artist
# 6404   a_16517      Angela Bofill  artist
# 10213  a_16504  Sabrina Malheiros  artist
# 10216  a_16506     Patrice Rushen  artist
#
#
# Community ID: 112
# Members count: 18
#        nodeID               name    type
# 5589     u_55     Invalid prefix    user
# 5818   a_1618      Hieroglyphics  artist
# 5819   a_1619      Blackalicious  artist
# 9539   a_1634  Souls of Mischief  artist
# 10744  a_1628            Das EFX  artist
#
#
# Community ID: 113
# Members count: 18
#         nodeID            name    type
# 3822    a_1740      Soundtrack  artist
# 5432    u_1119  Invalid prefix    user
# 6162   a_12418         Şanışer  artist
# 7568   a_12421         6.Cadde  artist
# 10089  a_12430  Şanışer & Bela  artist
#
#
# Community ID: 114
# Members count: 18
#        nodeID                  name    type
# 1852   u_1618        Invalid prefix    user
# 5744  a_15599     Świetliki i Linda  artist
# 5745  a_15594   Jean-Jacques Burnel  artist
# 6645  a_15606         Rosetta Stone  artist
# 9745  a_15598  Oppenheimer Analysis  artist
#
#
# Community ID: 115
# Members count: 18
#        nodeID            name    type
# 1446    u_998  Invalid prefix    user
# 6216  a_11689              민호  artist
# 6217  a_11688             장근석  artist
# 9209   a_5575           SS501  artist
# 9359  a_11691     Cinta Laura  artist
#
#
# Community ID: 116
# Members count: 18
#        nodeID             name    type
# 4081   u_1440   Invalid prefix    user
# 5502  a_11249  Bruno & Marrone  artist
# 5943  a_10459        Fábio Jr.  artist
# 7682  a_14573   Calcinha Preta  artist
# 9847  a_14568    Limão com Mel  artist
#
#
# Community ID: 117
# Members count: 18
#       nodeID            name    type
# 4265   u_148  Invalid prefix    user
# 6256  a_3351     Melt-Banana  artist
# 8495  a_3342       Realicide  artist
# 8507  a_3343  Choking Victim  artist
# 9139  a_3334         Fat Jon  artist
#
#
# Community ID: 118
# Members count: 18
#         nodeID            name    type
# 6257    u_1531  Invalid prefix    user
# 7248   a_10370          Goblin  artist
# 11151  a_15210       Raw Power  artist
# 11152  a_15211            Void  artist
# 11153  a_15212        Disclose  artist
#
#
# Community ID: 119
# Members count: 18
#        nodeID                       name    type
# 4047    u_556             Invalid prefix    user
# 6242   a_8036                Zack Hemsey  artist
# 10617  a_8029  Mark Sherry pres Outburst  artist
# 10835  a_6299           Freelance Whales  artist
# 11233  a_8039              Audio Network  artist
#
#
# Community ID: 120
# Members count: 18
#       nodeID                            name    type
# 3535   u_645                  Invalid prefix    user
# 6767  a_8851   Arturo Benedetti Michelangeli  artist
# 7059  a_8857                  Silje Nergaard  artist
# 8451  a_8855  Patrizia Laquidara & Hotel Rif  artist
# 8452  a_8850                   Amici Forever  artist
#
#
# Community ID: 121
# Members count: 18
#        nodeID                name    type
# 1080    u_420      Invalid prefix    user
# 6376   a_6720        As Marcianas  artist
# 6668   a_6702   Anna Nicole Smith  artist
# 7434   a_6697  Dana International  artist
# 10073  a_6709          Per Gessle  artist
#
#
# Community ID: 122
# Members count: 18
#       nodeID                  name    type
# 2013   u_416        Invalid prefix    user
# 6799  a_6649       Karjalan Sissit  artist
# 7170  a_6656  In Slaughter Natives  artist
# 7997  a_6670     Ghosts of Breslau  artist
# 8889  a_6672              Darkwood  artist
#
#
# Community ID: 123
# Members count: 18
#         nodeID                       name    type
# 6313   a_18351   Taku Sugimoto/Moe Kamura  artist
# 7754    u_2035             Invalid prefix    user
# 10293  a_18337                 MONDO BOYS  artist
# 10301  a_18338  Space Mountain Mix Series  artist
# 11439  a_18352                   Alan Tew  artist
#
#
# Community ID: 124
# Members count: 18
#        nodeID               name    type
# 2882    u_736     Invalid prefix    user
# 6288   a_9681         Kool Savas  artist
# 8091   a_9697              Curse  artist
# 11384  a_9687  Absolute Beginner  artist
# 11386  a_9683               Lili  artist
#
#
# Community ID: 125
# Members count: 18
#        nodeID                              name    type
# 5333   u_1624                    Invalid prefix    user
# 6139  a_15650                    Joe Crepúsculo  artist
# 7051  a_15662  Facto delafé y las flores azules  artist
# 9082  a_15655            Wildbirds & Peacedrums  artist
# 9716  a_15644                           amatria  artist
#
#
# Community ID: 126
# Members count: 17
#        nodeID            name    type
# 1322   u_1841  Invalid prefix    user
# 6388  a_16970     Aesma Daeva  artist
# 8201  a_16961  Umbra et Imago  artist
# 8202  a_16960   Drained Scorn  artist
# 9942   a_7454       Snakeskin  artist
#
#
# Community ID: 127
# Members count: 17
#       nodeID                   name    type
# 3231   u_356         Invalid prefix    user
# 4971  a_6029     A Midsky Surrender  artist
# 7519  a_5967  2 0' Clock Girlfriend  artist
# 7887  a_6028   The Handshake Affair  artist
# 9145  a_6019     Her Demise My Rise  artist
#
#
# Community ID: 128
# Members count: 17
#        nodeID             name    type
# 1220   u_1357   Invalid prefix    user
# 7554  a_14080      Irma Thomas  artist
# 9058  a_14079        Yma Sumac  artist
# 9060  a_14073  Geraint Watkins  artist
# 9496  a_14090  Mickey Lee Lane  artist
#
#
# Community ID: 129
# Members count: 17
#       nodeID            name    type
# 1415   u_181  Invalid prefix    user
# 5928  a_3835        Пси(Х)еЯ  artist
# 6213  a_3851           Настя  artist
# 6338  a_3838           Михей  artist
# 6961  a_3842   Bonus-Дельфин  artist
#
#
# Community ID: 130
# Members count: 17
#         nodeID              name    type
# 3702    a_4107        Some Girls  artist
# 5155    u_1861    Invalid prefix    user
# 9825   a_17191            Ekkaia  artist
# 9826   a_17190         Hakim Bey  artist
# 10798  a_13612  His Hero Is Gone  artist
#
#
# Community ID: 131
# Members count: 17
#       nodeID             name    type
# 3498   u_204   Invalid prefix    user
# 4099  a_4204             Bane  artist
# 4879  a_4220  Bombshell Rocks  artist
# 7053  a_4186      Ann Beretta  artist
# 7717  a_4193   The Loved Ones  artist
#
#
# Community ID: 132
# Members count: 17
#        nodeID                     name    type
# 667    u_2036           Invalid prefix    user
# 6314  a_18356          Liliana Herrero  artist
# 6478   a_6462  G. Love & Special Sauce  artist
# 7899   a_5250    Luis Alberto Spinetta  artist
# 7964  a_18362            Oumou Sangare  artist
#
#
# Community ID: 133
# Members count: 17
#         nodeID            name    type
# 2688     u_962  Invalid prefix    user
# 4857    a_5302            Gong  artist
# 7264   a_11426  Arrigo Barnabé  artist
# 9318   a_11432   Airto Moreira  artist
# 14149   a_5303    Soft Machine  artist
#
#
# Community ID: 134
# Members count: 17
#         nodeID                   name    type
# 4296    a_8121  Toots and the Maytals  artist
# 8162   a_13699           Tagada Jones  artist
# 10305  a_13694                   Race  artist
# 11225  a_13686              GrimSkunk  artist
# 12243  a_13701             Jason Kent  artist
#
#
# Community ID: 135
# Members count: 17
#         nodeID            name    type
# 3720    u_1770  Invalid prefix    user
# 12176  a_16571     Bladerunner  artist
# 12178  a_16573      Too Strong  artist
# 12182  a_16577           I-Low  artist
# 12183  a_16578           Sigma  artist
#
#
# Community ID: 136
# Members count: 17
#         nodeID             name    type
# 2073    u_1195   Invalid prefix    user
# 9428   a_11959      Jana Hunter  artist
# 13107  a_13056    Dirty Beaches  artist
# 13893  a_13043  Sleeping States  artist
# 14041  a_11999  Benoît Pioulard  artist
#
#
# Community ID: 137
# Members count: 17
#         nodeID              name    type
# 5410    u_1126    Invalid prefix    user
# 7085   a_12525               Sk6  artist
# 9118   a_12530       Devil In Me  artist
# 13840  a_12529   Barafunda Total  artist
# 13841  a_12528  TwentyInchBurial  artist
#
#
# Community ID: 138
# Members count: 17
#         nodeID            name    type
# 2674    u_1207  Invalid prefix    user
# 5158   a_13143     MullMuzzler  artist
# 6223   a_13132      Dreamscape  artist
# 11183  a_13133      Shawn Lane  artist
# 11184  a_13130        Dominici  artist
#
#
# Community ID: 139
# Members count: 17
#         nodeID                                name    type
# 2285    u_1864                      Invalid prefix    user
# 7267   a_17217                       Chicken Shack  artist
# 7776   a_17216             Boban Marković Orkestar  artist
# 9621   a_13605  Bob Seger & the Silver Bullet Band  artist
# 13504  a_17207                             Michael  artist
#
#
# Community ID: 140
# Members count: 16
#         nodeID            name    type
# 4259    u_1817  Invalid prefix    user
# 5975   a_16845           Salyu  artist
# 7753   a_16851         YA-KYIM  artist
# 10492  a_16846           globe  artist
# 10493  a_16847    Doping Panda  artist
#
#
# Community ID: 141
# Members count: 16
#         nodeID            name    type
# 2950    u_1665  Invalid prefix    user
# 5572   a_13275            Kumm  artist
# 8710   a_15946    Maximov Show  artist
# 9461   a_15940      VeritaSaga  artist
# 13146  a_15934      Billy Fury  artist
#
#
# Community ID: 142
# Members count: 16
#        nodeID                name    type
# 2839    u_228      Invalid prefix    user
# 4469   a_4528               Meven  artist
# 10535  a_4547  ABC Radio National  artist
# 10536  a_4546    Seleshe Damessae  artist
# 10538  a_4540           Dolchamar  artist
#
#
# Community ID: 143
# Members count: 16
#       nodeID            name    type
# 4001   u_510  Invalid prefix    user
# 5493  a_3462       [unknown]  artist
# 5960  a_7632    Mina/심지환/최지호  artist
# 7942  a_7160            下村陽子  artist
# 9972  a_7614             張震嶽  artist
#
#
# Community ID: 144
# Members count: 16
#        nodeID              name    type
# 1182    u_843    Invalid prefix    user
# 5085  a_10575    Righteous Jams  artist
# 6270  a_10566   Down to Nothing  artist
# 8210  a_10577  Internal Affairs  artist
# 8975   a_8925  The Wonder Years  artist
#
#
# Community ID: 145
# Members count: 16
#         nodeID                      name    type
# 2591    u_1724            Invalid prefix    user
# 6801   a_16341                   D-Pulse  artist
# 9436    a_4913   Berliner Philharmoniker  artist
# 14176  a_16337            Arthur Verocai  artist
# 14184  a_16338  Metropolitan Jazz Affair  artist
#
#
# Community ID: 146
# Members count: 16
#       nodeID            name    type
# 1066   u_725  Invalid prefix    user
# 6231  a_9565     Frank Luntz  artist
# 6441  a_9556      Sami Yusuf  artist
# 7804  a_7148      John Barry  artist
# 9069  a_9564  Dinesh D'Souza  artist
#
#
# Community ID: 147
# Members count: 16
#        nodeID                                           name    type
# 1810    u_463                                 Invalid prefix    user
# 4484   a_7173                                   Doug Carroll  artist
# 7941   a_7166                                        AmIEvil  artist
# 10634  a_7159                                            崎元仁  artist
# 10635  a_7158  Junya Nakano, Masashi Hamauzu & Nobuo Uematsu  artist
#
#
# Community ID: 148
# Members count: 16
#         nodeID             name    type
# 4168    u_1720   Invalid prefix    user
# 4684   a_11859      Blacklisted  artist
# 10940  a_16260         Slapshot  artist
# 10946  a_16266         Swirlies  artist
# 10947  a_16267  Moscow Olympics  artist
#
#
# Community ID: 149
# Members count: 16
#         nodeID            name    type
# 4192    u_1859  Invalid prefix    user
# 7147   a_17155       Krautheim  artist
# 8399   a_17162        R.U.D.E.  artist
# 11779  a_17172      Fake Drugs  artist
# 11780  a_17170          Kalson  artist
#
#
# Community ID: 150
# Members count: 15
#        nodeID             name    type
# 63      t_120      world music     tag
# 4809   a_4983           Elissa  artist
# 6843  a_17275         Mohicans  artist
# 7799   a_9387      Nancy Ajram  artist
# 7980   a_1136  Amadou & Mariam  artist
#
#
# Community ID: 151
# Members count: 15
#         nodeID             name    type
# 2979    u_1629   Invalid prefix    user
# 7514   a_15709    Rom di Prisco  artist
# 15138  a_15706     Reza Yazdani  artist
# 15140  a_15704   Kaveh Yaghmaei  artist
# 15141  a_15705  Mohsen Chavoshi  artist
#
#
# Community ID: 152
# Members count: 15
#         nodeID            name    type
# 7225   a_14902   Ania Wyszkoni  artist
# 7581    u_1492  Invalid prefix    user
# 7957    a_5038         Grubson  artist
# 14257  a_14906        Tim Berg  artist
# 14258  a_14905        Afrojack  artist
#
#
# Community ID: 153
# Members count: 15
#         nodeID            name    type
# 3151    u_1100  Invalid prefix    user
# 7189    a_4655          C.S.I.  artist
# 11836   a_1212       Manorexia  artist
# 14787  a_12321    Geoff Farina  artist
# 14793  a_12323   Cop Shoot Cop  artist
#
#
# Community ID: 154
# Members count: 15
#         nodeID                                       name    type
# 4868    a_5680                         Kanye West & Jay-Z  artist
# 7392   a_11409                               Radio Killer  artist
# 7394   a_11406                PH Electro - [muz-zone.net]  artist
# 10787    u_960                             Invalid prefix    user
# 12754  a_11411  Eminem feat. Drake, Kanye West, Lil Wayne  artist
#
#
# Community ID: 155
# Members count: 15
#       nodeID                       name    type
# 2452   u_742             Invalid prefix    user
# 4675  a_9720              Natacha Atlas  artist
# 5967  a_9730  Benjamin Francis Leftwich  artist
# 8839  a_9725              Diana Navarro  artist
# 9336  a_9721            Johanna Kurkela  artist
#
#
# Community ID: 156
# Members count: 15
#       nodeID                       name    type
# 4277   u_192             Invalid prefix    user
# 7584  a_4014                  In:aviate  artist
# 7585  a_4012             Across The Sun  artist
# 9531  a_4006  Conducting From the Grave  artist
# 9536  a_4008                    Arbiter  artist
#
#
# Community ID: 157
# Members count: 15
#        nodeID                    name    type
# 4104   u_1152          Invalid prefix    user
# 7426  a_12712          Colour of Fire  artist
# 7427  a_12713          Akira Kosemura  artist
# 9355  a_12709  Seven Percent Solution  artist
# 9490  a_12722                fathom 5  artist
#
#
# Community ID: 158
# Members count: 15
#         nodeID                         name    type
# 2710    u_2045               Invalid prefix    user
# 5738   a_18381               Ольга Арефьева  artist
# 8425   a_18383                Peter Nalitch  artist
# 11048  a_18378               Мертвий Півень  artist
# 11049  a_18379  Иисус Христос - Суперзвезда  artist
#
#
# Community ID: 159
# Members count: 15
#        nodeID            name    type
# 2613    u_993  Invalid prefix    user
# 5239  a_11612             Woe  artist
# 6609  a_11624  Fall of Efrafa  artist
# 9987  a_11627   Buried Inside  artist
# 9988  a_11626  biggerstronger  artist
#
#
# Community ID: 160
# Members count: 15
#        nodeID            name    type
# 5491  a_12553          Ha-Ash  artist
# 7537   u_1658  Invalid prefix    user
# 8556  a_13739   Eiza Gonzalez  artist
# 9979  a_15901        Lyon Fi!  artist
# 9980  a_15902    Paulina Goto  artist
#
#
# Community ID: 161
# Members count: 15
#        nodeID                           name    type
# 2782    u_492                 Invalid prefix    user
# 3791   a_7429              Robert Downey Jr.  artist
# 6573   a_7431                 John Barrowman  artist
# 6576   a_7434  The Rocky Horror Picture Show  artist
# 10231  a_7424                    Noël Coward  artist
#
#
# Community ID: 162
# Members count: 15
#        nodeID                                        name    type
# 3853    u_807                              Invalid prefix    user
# 5809  a_10243                                      やなわらばー  artist
# 6188  a_10229                                     オレスカバンド  artist
# 6374  a_10241                                     ステレオポニー  artist
# 9918  a_10246  Satou Rina & Inoue Marina & Chihara Minori  artist
#
#
# Community ID: 163
# Members count: 15
#        nodeID            name    type
# 2308   u_1467  Invalid prefix    user
# 8494  a_12651       AJ McLean  artist
# 8759  a_12698   38th Parallel  artist
# 9015  a_12028   Apocalipse 16  artist
# 9360  a_14707    Duncan James  artist
#
#
# Community ID: 164
# Members count: 14
# ...
# 3658  t_4616           1900     tag
# 8343  a_9552  Gustav Mahler  artist
#
#
# Community ID: 429
# Members count: 2
#         nodeID                                 name    type
# 2927   t_10520                     country: germany     tag
# 21386   a_9625  Dr. Ring-Ding & The Senior Allstars  artist
#
#
# Community ID: 430
# Members count: 2
#        nodeID                          name    type
# 1248   t_5741  the new wave of classic rock     tag
# 17475  a_9650                    Stone Gods  artist
#
#
# Community ID: 431
# Members count: 2
#       nodeID               name    type
# 973   t_5184  melodic hard rock     tag
# 7345  a_9651        stonecollar  artist
#
#
# Community ID: 432
# Members count: 2
#       nodeID           name    type
# 3259  t_5190      ska metal     tag
# 7681  a_9671  Border Patrol  artist
#
#
# Community ID: 433
# Members count: 2
#       nodeID                 name    type
# 1503  t_5236         mogilevskaya     tag
# 8410  a_9757  Наталья Могилевская  artist
#
#
# Community ID: 434
# Members count: 2
#        nodeID          name    type
# 1757   t_5247  chilean rock     tag
# 20681  a_9781        los ex  artist
#
#
# Community ID: 435
# Members count: 2
#         nodeID            name    type
# 3030    t_3934           j-ska     tag
# 17851  a_10234  Yum!Yum!ORANGE  artist
#
#
# Community ID: 436
# Members count: 2
#         nodeID                       name    type
# 1207    t_5738               sleaze metal     tag
# 10910  a_10446  Addiction For Destruction  artist
#
#
# Community ID: 437
# Members count: 2
#        nodeID               name    type
# 2297   t_5745      french reggae     tag
# 4739  a_10464  Dub Incorporation  artist
#
#
# Community ID: 438
# Members count: 2
#         nodeID          name    type
# 1642    t_5751    skate-punk     tag
# 16692  a_10490  The Joystick  artist
#
#
# Community ID: 439
# Members count: 2
#        nodeID          name    type
# 5564   t_6114      fun rock     tag
# 8209  a_10571  Mustard Plug  artist
#
#
# Community ID: 440
# Members count: 2
#         nodeID           name    type
# 1996    t_2079         punk77     tag
# 21028  a_10758  The Carpettes  artist
#
#
# Community ID: 441
# Members count: 2
#         nodeID        name    type
# 2358    t_5989  pop singer     tag
# 12580  a_10822      Wilmie  artist
#
#
# Community ID: 442
# Members count: 2
#         nodeID               name    type
# 1636    t_6081          salsa pop     tag
# 16116  a_10920  Scenes And Sirens  artist
#
#
# Community ID: 443
# Members count: 2
#         nodeID         name    type
# 1637    t_6084  chinese pop     tag
# 14324  a_10925          黃立行  artist
#
#
# Community ID: 444
# Members count: 2
#        nodeID         name    type
# 1558   t_6094  korean rock     tag
# 9172  a_10935          서태지  artist
#
#
# Community ID: 445
# Members count: 2
#         nodeID                            name    type
# 1340    t_6144              panic at the disco     tag
# 13088  a_10985  Brendon Urie and Dresden Dolls  artist
#
#
# Community ID: 446
# Members count: 2
#         nodeID               name    type
# 1963    t_5832  hard rock revival     tag
# 13614  a_11178                MQN  artist
#
#
# Community ID: 447
# Members count: 2
#        nodeID           name    type
# 836    t_3521        pop emo     tag
# 5166  a_11553  The Movielife  artist
#
#
# Community ID: 448
# Members count: 2
#         nodeID               name    type
# 2858    t_6543  metallic hardcore     tag
# 21503  a_11607      Pulling Teeth  artist
#
#
# Community ID: 449
# Members count: 2
#         nodeID                name    type
# 1593    t_6703  good christian rap     tag
# 19730  a_11799       Tyrone Andrew  artist
#
#
# Community ID: 450
# Members count: 2
#         nodeID                      name    type
# 1618    t_6907  houston psychedelic rock     tag
# 20895  a_11969                     Kable  artist
#
#
# Community ID: 451
# Members count: 2
#        nodeID            name    type
# 1366   t_6983  latin ska punk     tag
# 4927  a_12050  La Vela Puerca  artist
#
#
# Community ID: 452
# Members count: 2
#        nodeID           name    type
# 5902   t_6982  rock mexicano     tag
# 9408  a_12060         El Tri  artist
#
#
# Community ID: 453
# Members count: 2
#         nodeID            name    type
# 1335    t_7271   not math rock     tag
# 13579  a_12375  Crime In Choir  artist
#
#
# Community ID: 454
# Members count: 2
#         nodeID       name    type
# 1728    t_7398  agrometal     tag
# 13848  a_12526  Ukurralle  artist
#
#
# Community ID: 455
# Members count: 2
#         nodeID            name    type
# 1714    t_6088  korean hip hop     tag
# 15892  a_12585              빅뱅  artist
#
#
# Community ID: 456
# Members count: 2
#         nodeID          name    type
# 1760    t_7470  earlie indie     tag
# 11642  a_12600    Big Dipper  artist
#
#
# Community ID: 457
# Members count: 2
#         nodeID       name    type
# 1774   t_10555  k-hip hop     tag
# 18192  a_12659        배치기  artist
#
#
# Community ID: 458
# Members count: 2
#        nodeID              name    type
# 2248   t_7557     jrock kawaiii     tag
# 8605  a_12812  9GOATS BLACK OUT  artist
#
#
# Community ID: 459
# Members count: 2
#         nodeID                         name    type
# 1621    t_7592  best croatian pop-rock band     tag
# 19045  a_12832                 Parni Valjak  artist
#
#
# Community ID: 460
# Members count: 2
#         nodeID                       name    type
# 1067   t_11626  atmospheric drum and bass     tag
# 11972  a_12846                       Seba  artist
#
#
# Community ID: 461
# Members count: 2
#         nodeID            name    type
# 1007    t_7596  inflight music     tag
# 18325  a_12878  abyssal plains  artist
#
#
# Community ID: 462
# Members count: 2
#         nodeID                  name    type
# 1770    t_7656  electronic junk punk     tag
# 16522  a_12973              Babyland  artist
#
#
# Community ID: 463
# Members count: 2
#         nodeID           name    type
# 1756    t_7682        ringpop     tag
# 14844  a_13001  Mariage Blanc  artist
#
#
# Community ID: 464
# Members count: 2
#         nodeID      name    type
# 2585    t_5886  rock pop     tag
# 11190  a_13138    Ok que  artist
#
#
# Community ID: 465
# Members count: 2
#        nodeID            name    type
# 2202   t_7988  rap dominicano     tag
# 9868  a_13298    Monkey Black  artist
#
#
# Community ID: 466
# Members count: 2
#         nodeID                                               name    type
# 1764    t_7992  lapiz conciente vakero hip hop latino toxic cr...     tag
# 16368  a_13301                                                joa  artist
#
#
# Community ID: 467
# Members count: 2
#         nodeID           name    type
# 2213    t_8043  oriental rock     tag
# 15789  a_13409       Cairokee  artist
#
#
# Community ID: 468
# Members count: 2
#        nodeID       name    type
# 3230   t_4309  etno rock     tag
# 6045  a_13434    Пелагея  artist
#
#
# Community ID: 469
# Members count: 2
#         nodeID       name    type
# 2589   t_10409  turk rock     tag
# 12480  a_13510     Kurban  artist
#
#
# Community ID: 470
# Members count: 2
#         nodeID         name    type
# 1722    t_8192  aussie rock     tag
# 14952  a_10729        Gotye  artist
#
#
# Community ID: 471
# Members count: 2
#         nodeID                   name    type
# 1339     t_264        90s pop espanol     tag
# 20296  a_13666  Los Fresones Rebeldes  artist
#
#
# Community ID: 472
# Members count: 2
#         nodeID                      name    type
# 1672    t_8372  great pop with real soul     tag
# 20032  a_13689             James Murdoch  artist
#
#
# Community ID: 473
# Members count: 2
#         nodeID            name    type
# 1705    t_1888          p-funk     tag
# 20250  a_13918  Bootsy Collins  artist
#
#
# Community ID: 474
# Members count: 2
#         nodeID        name    type
# 2801    t_8801    art-rock     tag
# 17008  a_13999  Heartscore  artist
#
#
# Community ID: 475
# Members count: 2
#         nodeID         name    type
# 1695    t_8867   cello rock     tag
# 14113  a_14063  Cellofourte  artist
#
#
# Community ID: 476
# Members count: 2
#         nodeID                          name    type
# 7221    t_8878                 pre-war blues     tag
# 13122  a_14075  The Radio R.A.T. Misery Hour  artist
#
#
# Community ID: 477
# Members count: 2
#         nodeID                                       name    type
# 1690    t_3355  sound collage psychedelia electronic folk     tag
# 11816  a_14209              Broadcast and The Focus Group  artist
#
#
# Community ID: 478
# Members count: 2
#         nodeID            name    type
# 1664    t_8982      celtic pop     tag
# 13069  a_14219  Aselin Debison  artist
#
#
# Community ID: 479
# Members count: 2
#         nodeID                   name    type
# 1244    t_3379            wizard rock     tag
# 10862  a_14315  Draco and the Malfoys  artist
#
#
# Community ID: 480
# Members count: 2
#         nodeID              name    type
# 3021    t_9516  geek rock comedy     tag
# 21039  a_14368       Lemon Demon  artist
#
#
# Community ID: 481
# Members count: 2
#         nodeID            name    type
# 1660    t_9214  neo-rockabilly     tag
# 11250  a_14489    The Ace Cats  artist
#
#
# Community ID: 482
# Members count: 2
#         nodeID       name    type
# 1635    t_9279  chica pop     tag
# 21407  a_14542     Zahara  artist
#
#
# Community ID: 483
# Members count: 2
#         nodeID  name    type
# 3620    t_9327  cpop     tag
# 14491  a_14594   羅志祥  artist
#
#
# Community ID: 484
# Members count: 2
#         nodeID                   name    type
# 1634    t_1183  aussie pop dance band     tag
# 21088  a_14641    Kids in the Kitchen  artist
#
#
# Community ID: 485
# Members count: 2
#         nodeID                   name    type
# 2508   t_11813  gay church folk music     tag
# 11278  a_14667     The Hidden Cameras  artist
#
#
# Community ID: 486
# Members count: 2
#        nodeID                        name    type
# 1095   t_9496  my favorite hip hop artist     tag
# 8008  a_14734                        Tyga  artist
#
#
# Community ID: 487
# Members count: 2
#         nodeID               name    type
# 2622    t_9619  rock patriotyczny     tag
# 20694  a_14911     Prawe Skrzydło  artist
#
#
# Community ID: 488
# Members count: 2
#        nodeID                    name    type
# 2218   t_9658         christian blues     tag
# 6675  a_14987  RICHARD DIXON-COMPOSER  artist
#
#
# Community ID: 489
# Members count: 2
#         nodeID            name    type
# 1599    t_9707  hip-hop latino     tag
# 19018  a_15114      Chyno Nyno  artist
#
#
# Community ID: 490
# Members count: 2
#         nodeID               name    type
# 3962    t_9777     indie pop punk     tag
# 17149  a_15220  We Should Be Dead  artist
#
#
# Community ID: 491
# Members count: 2
#        nodeID            name    type
# 1493   t_9991  j-pop acoustic     tag
# 8469  a_15463        DEPAPEPE  artist
#
#
# Community ID: 492
# Members count: 2
#         nodeID             name    type
# 2264    t_9356      italo-disco     tag
# 13747  a_15668  Ricchi e Poveri  artist
#
#
# Community ID: 493
# Members count: 2
#         nodeID                                  name    type
# 3256    t_6241  slamming guttural brutal death metal     tag
# 20935  a_15948                               Ранетки  artist
#
#
# Community ID: 494
# Members count: 2
#         nodeID                     name    type
# 1665    t_4477  russian underground rap     tag
# 21345  a_16006                    KODLA  artist
#
#
# Community ID: 495
# Members count: 2
#        nodeID        name    type
# 2516  t_10461  disco rock     tag
# 9813  a_16027        Kreş  artist
#
#
# Community ID: 496
# Members count: 2
#         nodeID     name    type
# 1711   t_11482  popping     tag
# 10604  a_16060  Osborne  artist
#
#
# Community ID: 497
# Members count: 2
#         nodeID              name    type
# 3436   t_10508  country: jamaica     tag
# 19857   a_9843   Barrington Levy  artist
#
#
# Community ID: 498
# Members count: 2
#         nodeID          name    type
# 2712   t_10410  anadolu rock     tag
# 21205  a_15134      Moğollar  artist
#
#
# Community ID: 499
# Members count: 2
#         nodeID        name    type
# 1675   t_10668    neo punk     tag
# 12004  a_16257  Battleship  artist
#
#
# Community ID: 500
# Members count: 2
#         nodeID       name    type
# 2734    t_7520  noise-pop     tag
# 16504  a_16270   Medicine  artist
#
#
# Community ID: 501
# Members count: 2
#         nodeID            name    type
# 3650    t_5123  neo rockabilly     tag
# 16505  a_16277            Jets  artist
#
#
# Community ID: 502
# Members count: 2
#        nodeID                 name    type
# 1542  t_10678  japanese rockabilly     tag
# 9328  a_16288            ブルー・エンジェル  artist
#
#
# Community ID: 503
# Members count: 2
#         nodeID                   name    type
# 1724    t_9224  louisiana rock n roll     tag
# 11251  a_16305          Billy Wallace  artist
#
#
# Community ID: 504
# Members count: 2
#        nodeID               name    type
# 2700  t_10811  girl electro rock     tag
# 8148  a_16418         The Trucks  artist
#
#
# Community ID: 505
# Members count: 2
#        nodeID                           name    type
# 1518   t_4264                   blues fusion     tag
# 8941  a_16650  John Lee Hooker & Miles Davis  artist
#
#
# Community ID: 506
# Members count: 2
#         nodeID          name    type
# 1719    t_4410  anarchy punk     tag
# 17676  a_16772         Mulan  artist
#
#
# Community ID: 507
# Members count: 2
#        nodeID                         name    type
# 1540  t_11134              a crock of crap     tag
# 6259  a_16787  The Time Travelling Pirates  artist
#
#
# Community ID: 508
# Members count: 2
#         nodeID        name    type
# 1592   t_11182  melody pop     tag
# 17487  a_16866    The Rebs  artist
#
#
# Community ID: 509
# Members count: 2
#         nodeID          name    type
# 1646   t_11371  balearic pop     tag
# 21079  a_17093        Kisses  artist
#
#
# Community ID: 510
# Members count: 2
#         nodeID                              name    type
# 1735   t_11402  the best punk rock album of 2006     tag
# 12523  a_17149                       Ryan's Hope  artist
#
#
# Community ID: 511
# Members count: 2
#         nodeID             name    type
# 1181    t_9962  real indie rock     tag
# 16161  a_17307          Mineral  artist
#
#
# Community ID: 512
# Members count: 2
#         nodeID       name    type
# 1987    t_6849  spacerock     tag
# 16580  a_17324  Autodrone  artist
#
#
# Community ID: 513
# Members count: 2
#         nodeID               name    type
# 5759   t_11605  funky white bitch     tag
# 18326  a_10016        Nikka Costa  artist
#
#
# Community ID: 514
# Members count: 2
#         nodeID             name    type
# 1614   t_11660  indie jazz rock     tag
# 15023  a_17534          Mordida  artist
#
#
# Community ID: 515
# Members count: 2
#         nodeID                    name    type
# 1615   t_11661  indie folk acustic art     tag
# 15022  a_17535            Rosie and Me  artist
#
#
# Community ID: 516
# Members count: 2
#        nodeID            name    type
# 1495   t_8652     gremio rock     tag
# 7467  a_17536  Wander Wildner  artist
#
#
# Community ID: 517
# Members count: 2
#        nodeID         name    type
# 1403   t_8984     darkness     tag
# 4840  a_17622  Silent Hill  artist
#
#
# Community ID: 518
# Members count: 2
#         nodeID               name    type
# 5442   t_11924          romantico     tag
# 16092  a_17891  Caco van Hollanda  artist
#
#
# Community ID: 519
# Members count: 2
#         nodeID                       name    type
# 1730   t_12068           nepali rock band     tag
# 18534  a_17994  Abhaya & the Steam Injuns  artist
#
#
# Community ID: 520
# Members count: 2
#         nodeID          name    type
# 2689    t_9806      dark psy     tag
# 18735  a_18260  Gorump Peyya  artist
#
#
# Community ID: 521
# Members count: 2
#         nodeID             name    type
# 3470     t_295       greek rock     tag
# 15039  a_18308  Μύρωνας Στρατής  artist
#
#
# Community ID: 522
# Members count: 2
#         nodeID                    name    type
# 1633   t_12528  crossover thrash metal     tag
# 16100  a_18547           The Crucified  artist
#
#
# Community ID: 523
# Members count: 2
#        nodeID            name    type
# 1977   u_2085  Invalid prefix    user
# 5231  a_18615           YEFFI  artist
#
#
# Community ID: 524
# Members count: 2
#         nodeID                name    type
# 8122   t_12633  russian dark scene     tag
# 17842  a_18630        Doppelganger  artist
#
#
# Community ID: 525
# Members count: 2
#         nodeID                  name    type
# 2984   t_12627     batcave deathrock     tag
# 17844  a_18632  Bloody Dead and Sexy  artist
#
#
# Community ID: 526
# Members count: 2
#         nodeID               name    type
# 1771    t_5408  stoner power rock     tag
# 17839  a_18639       Brain Police  artist

# %% [markdown]
# We can also get generate a summary table that lists each community ID along with the counts of tags, artists, and users in each community.

# %%
community_summary_louvain = node_df_louvain.groupby('communityID')['type'].value_counts().unstack(fill_value=0)

# Calculate the total number of entities in each community
community_summary_louvain['total_entities'] = community_summary_louvain.sum(axis=1)

# Reset the index to turn the index into a column
community_summary_louvain.reset_index(inplace=True)

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')


# Display the summary table
community_summary_louvain
# Out:
# type  communityID  artist  tag  user  total_entities
# 0               0    2666  272   449            3387
# 1               1    2981  262   142            3385
# 2               2    2388  401   326            3115
# 3               3    1711  189   506            2406
# 4               4    1883  228   169            2280
# ..            ...     ...  ...   ...             ...
# 522           522       1    1     0               2
# 523           523       1    0     1               2
# 524           524       1    1     0               2
# 525           525       1    1     0               2
# 526           526       1    1     0               2
#
# [527 rows x 5 columns]

# %% [markdown]
# #### Specific Community Analysis

# %%
community = node_df_louvain[node_df_louvain['communityID'] == 26]
# Count the occurrence of each type within the community
print(community['type'].value_counts())
# List all unique tags or artists within the community
print("Unique tags:", community[community['type'] == 'tag']['name'].unique())
print("Unique artists:", community[community['type'] == 'artist']['name'].unique())
# Out:
# type
# artist    37
# user       1
# Name: count, dtype: int64
# Unique tags: []
# Unique artists: ['Turkish Military Band' 'Djelimady Tounkara' 'Talib al-Habib'
#  'حسين الاعظمي' 'Houria Aïchi' 'grup genç' 'Ahmet Çalışır'
#  'Abu Ali & Abu Abdul Maalik' 'Yusuf Islam' 'Shabnam Majid' 'DEBU'
#  'Al-Aseef' 'Ahmed Bukhatir' 'Salif Keita' 'عماد الشريف' 'محمد منير'
#  'Hasan Dursun' 'ميس شلش' 'Sajid Raza Qadri' 'Nass Marrakech' 'Noor'
#  'Imad Al-Sharif' 'Shaam' 'Irfan Makki'
#  'Mustafa Demirci & Murat Necipoğlu' 'Ali Farka Touré and Ry Cooder'
#  'Ibrahim Jibreen' 'Abu Ali' 'Ottoman Military Band' 'Hadiqa Kiani'
#  'Nusrat Fateh Ali Khan & Party' 'بوب مارلي' 'Firqat al-Isra'
#  'Grup Yeniçağ' 'Maher Zain' "Hussein al A'dhami" 'Abdullah Rolle']

# %% [markdown]
# ### **For Leiden**

# %% [markdown]
# #### Overview of Community Data
#
# First, we aggregate the data by community ID to get an overview of each community's composition. We group our DataFrame by the community ID and then examine the types and names within each community.

# %%
# Group by community ID and list out members of each community
community_groups = node_df_leiden.groupby('communityID')

# Example to print out the composition of each community
for community_id, group in community_groups:
    print(f"Community ID: {community_id}")
    print(f"Members count: {len(group)}")
    print(group[['nodeID', 'name', 'type']].head())  # Adjust as needed
    print("\n")
# Out:
# Community ID: 0
# Members count: 4650
#   nodeID          name type
# 1   t_73          rock  tag
# 2   t_18    electronic  tag
# 3   t_81         indie  tag
# 4   t_79   alternative  tag
# 5   t_33  experimental  tag
#
#
# Community ID: 1
# Members count: 2862
#    nodeID      name type
# 0    t_24       pop  tag
# 12   t_25       80s  tag
# 15  t_352       90s  tag
# 19  t_625      soul  tag
# 26   t_74  synthpop  tag
#
#
# Community ID: 2
# Members count: 2710
#    nodeID              name type
# 17    t_1             metal  tag
# 20   t_72         hard rock  tag
# 24  t_387  progressive rock  tag
# 28  t_386       heavy metal  tag
# 33    t_5       death metal  tag
#
#
# Community ID: 3
# Members count: 2666
#    nodeID        name type
# 25  t_109    pop rock  tag
# 45  t_308       latin  tag
# 55  t_512    romantic  tag
# 61  t_199  electropop  tag
# 88  t_349    teen pop  tag
#
#
# Community ID: 4
# Members count: 2603
#    nodeID       name type
# 14  t_181       punk  tag
# 18  t_376  metalcore  tag
# 29  t_182  punk rock  tag
# 47  t_169   pop punk  tag
# 56  t_712     gospel  tag
#
#
# Community ID: 5
# Members count: 2303
#    nodeID          name type
# 49  t_565  dark electro  tag
# 52  t_575      darkwave  tag
# 78  t_600     futurepop  tag
# 80   t_56   melancholic  tag
# 82  t_249   garage rock  tag
#
#
# Community ID: 6
# Members count: 1166
#     nodeID         name type
# 10   t_103          rap  tag
# 22   t_304      hip hop  tag
# 36   t_311       reggae  tag
# 58   t_265          ska  tag
# 114  t_197  gangsta rap  tag
#
#
# Community ID: 7
# Members count: 694
#       nodeID                                      name type
# 23     t_545                                 classical  tag
# 104  t_12639                             winds of soul  tag
# 115   t_8505  the best classical opera and film scores  tag
# 161   t_8116                              turkish rock  tag
# 171   t_6383                          classical guitar  tag
#
#
# Community ID: 8
# Members count: 686
#    nodeID                name type
# 31  t_105               house  tag
# 40  t_570              techno  tag
# 42   t_90              trance  tag
# 86  t_626       drum and bass  tag
# 87  t_327  progressive trance  tag
#
#
# Community ID: 9
# Members count: 588
#      nodeID    name type
# 44    t_140   j-pop  tag
# 65    t_139  j-rock  tag
# 84    t_164   k-pop  tag
# 92   t_1316    jpop  tag
# 102  t_1219   jrock  tag
#
#
# Community ID: 10
# Members count: 492
#      nodeID             name type
# 35    t_193          country  tag
# 43    t_839              sad  tag
# 79    t_253       rockabilly  tag
# 107  t_1096       chill zone  tag
# 138  t_4430  classic country  tag
#
#
# Community ID: 11
# Members count: 44
#        nodeID               name    type
# 5115   u_1847     Invalid prefix    user
# 5830  a_17052     Alice Coltrane  artist
# 6128  a_17044      The Pop Group  artist
# 7463  a_17029  Campbell Brothers  artist
# 7607  a_17046                Zeb  artist
#
#
# Community ID: 12
# Members count: 35
#        nodeID            name type
# 139     t_297        pop-rock  tag
# 363    t_1628     russian pop  tag
# 623   t_10393  indie-romantic  tag
# 782   t_10392   romantic rock  tag
# 1193  t_10395       love-rock  tag
#
#
# Community ID: 13
# Members count: 14
#       nodeID           name    type
# 1503  t_5236   mogilevskaya     tag
# 4286  t_5225  popular music     tag
# 4482  t_3209  ukrainian pop     tag
# 6711  a_9756   Макс Барских  artist
# 7086  a_9759  Потап и Настя  artist
#
#
# Community ID: 14
# Members count: 5
#        nodeID          name    type
# 3376   t_1618   techno punk     tag
# 4079   t_1624  digital-punk     tag
# 4711   t_1617    cyber-punk     tag
# 8493   t_1623   gabber punk     tag
# 19436  a_3348     KESSENCHU  artist

# %% [markdown]
# We can also get generate a summary table that lists each community ID along with the counts of tags, artists, and users in each community.

# %%
community_summary_leiden = node_df_leiden.groupby('communityID')['type'].value_counts().unstack(fill_value=0)

# Calculate the total number of entities in each community
community_summary_leiden['total_entities'] = community_summary_leiden.sum(axis=1)

# Reset the index to turn the index into a column
community_summary_leiden.reset_index(inplace=True)

# Display the summary table
community_summary_leiden
# Out:
# type  communityID  artist  tag  user  total_entities
# 0               0    4075  347   228            4650
# 1               1    2402  315   145            2862
# 2               2    2105  388   217            2710
# 3               3    1923  205   538            2666
# 4               4    2136  210   257            2603
# 5               5    1721  208   374            2303
# 6               6    1022   98    46            1166
# 7               7     628   41    25             694
# 8               8     606   64    16             686
# 9               9     514   49    25             588
# 10             10     424   49    19             492
# 11             11      43    0     1              44
# 12             12      22   13     0              35
# 13             13      10    3     1              14
# 14             14       1    4     0               5

# %% [markdown]
# #### Specific Community Analysis

# %%
community = node_df_louvain[node_df_leiden['communityID'] == 0]
# Count the occurrence of each type within the community
print(community['type'].value_counts())
# List all unique tags or artists within the community
print("Unique tags:", community[community['type'] == 'tag']['name'].unique())
print("Unique artists:", community[community['type'] == 'artist']['name'].unique())
# Out:
# type
# artist    4075
# tag        347
# user       228
# Name: count, dtype: int64
# Unique tags: ['rock' 'electronic' 'indie' 'alternative' 'experimental' 'folk' 'ambient'
#  'alternative rock' 'indie rock' 'chillout' 'electronica' 'jazz'
#  'indie pop' 'post-rock' 'britpop' 'chill' 'dark ambient' 'dream pop'
#  'new age' 'world music' 'dreamy' 'relaxing' 'dubstep' '90210' 'post rock'
#  'grunge' 'dark' 'my indie friends' 'indie luv' 'barkbarkdisco'
#  'acoustic rock' 'indietronica' 'rock me babe' 'alt-country' 'space rock'
#  'noise pop' 'dreampop' 'nu jazz' 'contemporary classical' 'acid jazz'
#  'noise rock' 'indie folk' 'neofolk' 'synth-pop' 'anti-folk' 'smooth jazz'
#  'jazz fusion' 'just chillin' 'math rock' 'light trip-hop'
#  'in the witch house family' 'contemporary jazz'
#  'berep guest dj closedmouth 239645' 'rockville ca'
#  'in the chillwave family' 'dark disco' 'twilight' 'witch house'
#  'free jazz' 'experimental rock' 'music for my soul' 'chill out'
#  'freak folk'
#  'the fact that this is the name of a band makes me want to check their music out even though i do not care much for indie pop'
#  'sadness' 'nu-jazz' 'krautrock' 'blissrock' 'soothing' 'ethnic chill'
#  'jazz sax' 'berep guest dj closedmouth jfr' 'witch chill'
#  'new discoverys' 'chillwave' 'italian rock' 'psychill' 'dream-pop'
#  'dance-punk' 'chill witch' 'dance rock' 'cute but slightly sinister'
#  'drone ambient' 'relaxing muscles' 'cool jazz' 'neo-pop'
#  'spanish indie pop' 'calming' 'rock argentino' 'synth-punk'
#  'relaxing music' 'rocker chick' 'funk rock' 'twee pop'
#  'happygoodfunandhandclaps' 'inflight music' 'space-rock' 'jazz guitar'
#  'calm' 'neo-classical underground' 'ambiental' 'real indie rock'
#  'clickpop' 'british folk' 'chill-out' 'psychedelic folk' 'not math rock'
#  'techno-industrial' 'electro-rock' 'darkness' 'indie-ish'
#  'gives me chills' 'piano led indie' 'a crock of crap'
#  'songs that make me happy in the pants :d' 'dark pop' 'intense sadness'
#  'good christian rap' 'garage punk' 'polish jazz'
#  'houston psychedelic rock' 'abstract hip hop' 'power electronics'
#  'funky house' 'sound collage psychedelia electronic folk' 'poppy'
#  'cello rock' 'popping' 'nepali rock band' '4700' 'ringpop' 'earlie indie'
#  'industrail rock' 'electronic junk punk' 'geography' 'folktronica'
#  'white lightning' 'beautifulsad' 'progressive electronic' 'punk sound'
#  'spacerock' 'dub techno' 'ambient folk' 'happy song' 'moody'
#  'jazz pianist' 'drill n bass' 'dark magic' 'jazz core' 'artsy folk-punk'
#  'sweet electronic' 'dance punk' 'progressive folk' 'funk-jazz'
#  'psychedelic pop' 'laptop folk' 'modern classical' 'indie funk'
#  'undulating' 'lustpop' 'gay church folk music' 'orgasm-inducing-ska'
#  'alternative country' 'dark rock'
#  'motherfuckin rabbits ejaculating sunshine' 'electro-house' 'seraphic'
#  'makes me trigger happy with the love button' 'girl electro rock'
#  'art-rock' 'post-dubstep' 'samba bucolic' 'antifolk'
#  'avant garde electronica' 'smart electronics' 'jazz piano' 'quickjazz'
#  '8600' 'indie electronica' 'club house' 'poetic rock' 'post-jazz'
#  'psychedelic pop electronica' 'bubblegum pop' 'dark as fuck' 'garage pop'
#  'crap music--delete this song' 'greek rock' 'popcore' 'psy chill'
#  'instrumental alternative' 'alt rock' 'alternative music' 'poppyfields'
#  'rocketta' 'chill wave' 'psychedelic-folk' 'psychedelic-pop'
#  'amazing pop' 'cinematic folk' 'i will follow you into the dark'
#  'best indie ever' 'jazz female vocalists' 'soothing nightmare'
#  'scrap basket' 'neoambient' 'uk indie' 'alternrock'
#  'new zealands fourth most popular digi-folk parody duo' 'porno rock'
#  'pra acalmar' 'noisepop' 'dark shoegaze' 'general alternative'
#  'angry chick music' 'chamber pop' 'electrofunk' 'more crap' 'girl rock'
#  'goldfrapp' 'maybe post rock' 'chill latin hh' '7800' 'indie-electronic'
#  'ambient techno' 'dream-folk' 'gay pop' 'psych pop' 'ambient lounge'
#  'filmska muzika' 'instrumental hip hop' 'indie-folk'
#  'sounds like iggy pop' 'uk funky' 'experimental techno'
#  'guitar-based digi-bongo acapella-rap-funk-comedy folk duo' 'punk funk'
#  'peaceful ambient' 'techno-rock' 'rock music' 'psy ambient' 'jazz hop'
#  'female rock band'
#  'the last of the great early experimental current 93 albums'
#  'twilight original soundtrack' 'sade' 'sadcore' 'nosowska'
#  'the temper trap' 'alternative  punk' 'acoustic folk'
#  'sad lovely touching expressive' 'a mix of indie and hip hop' 'ghostrock'
#  'black light' 'ritual ambient' 'hard blues' 'alternative folk'
#  'very dreamy' 'gospel-noise' 'to discover' 'electrorock' 'ambient rock'
#  'alternative rock  gooood' 'ambient-breakbeat' 'ethno-rock'
#  'freak folk tropicalia' 'anti-anti-folk' 'power rock' 'indie indi'
#  'indie jazz dance math rock' 'female alternative' 'melancholic idm'
#  'lovely sadness' 'indiepop' 'french indie' 'indie rock e alternative'
#  'jazzcore' 'deep electronic' 'blues pop'
#  'harmonisch ambient classical new nu classic' 'minimalist pop'
#  'lightwave' 'rock-a-rolla cover stars' 'indietronic remix'
#  'light ambient' 'brazilian funk' 'german-indie' 'math pop' 'retro rock'
#  'smokeyblues' 'neo grunge' 'italian alternative' 'disco fuckin yea'
#  'freak-pop' 'red hot chilli peppers' 'postrock' 'alpha centauri rock'
#  'sub-pop' 'freak-folk' 'punk cabaret' 'extraordinary indie' 'acid folk'
#  'indie indie pop acoustic mellow norwegian alternative indie rock folk scandinavian'
#  'intelligent techno' 'electro trance' 'indie electronic'
#  'american trad rock' 'southern soul' 'rocking' 'elettro pop'
#  'rock in rool' 'sad and beautiful'
#  'people who are freakier and folkier than motherfucking devendra banhart'
#  "70's rock" 'sad and beautifull' 'rhythym blues' 'dark music'
#  'lo-fi-folk' 'rockpop' 'psych-pop' 'kasia noswoska' 'techno trance'
#  'undie rock' 'electro post rock' 'avant-folk' 'sub pop' 'ambient sound'
#  'baroque harmonic pop jams' 'chick rock' 'chillosophy'
#  'very cool rock song' 'jam rock' 'alternative country rock'
#  'southern rock revival' 'bedroom pop' 'limehyperambient' 'british pop'
#  'folksinger' 'sad music' 'orchestral pop' 'moon rock' 'mars rock'
#  'ambient pop' 'post-folk' 'dj food ultimate funk groove'
#  'niggas that rock']
# Unique artists: ['Sigur Rós' 'Death Cab for Cutie' 'Belle and Sebastian' ...
#  'Dancing Ghosts' 'Krallice' 'Pomegranates']
