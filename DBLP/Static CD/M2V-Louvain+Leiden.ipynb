# %% [markdown]
# # Static Community Detection Using CDLIB and NetworkX - M2V
#
# After calculating similairties and updating the edge list with the values, we will look to execute the well-known Louvain and Leiden community detection algorithms using NetworkX library and CDLIB.

# %% [markdown]
# ## Importing Edge List w/ Weights to NetworkX
#
# NetworkX's read_weighted_edgelist function expects a simple text file with lines of the form <node1> <node2> <weight>, without headers. Since our data is in CSV format, you'll need to use Pandas (or another method) to load the CSV and adjust it to become readable.

# %%
import pandas as pd

edge_list_df = pd.read_csv('New Input/M2V_edge_list_with_similarity.csv')

print(edge_list_df)
# Out:
#        source  target    weight
# 0          p0      a1  0.752102
# 1          p0      a2  0.803198
# 2          p0      a3  0.900095
# 3          p0      a4  0.682413
# 4          p0      a5  0.833705
# ...       ...     ...       ...
# 51372  p10169   p8094  0.209173
# 51373  p10169   p7974  0.235403
# 51374  p10169   p5852  0.265217
# 51375  p10169  p10113  0.639329
# 51376  p10169  p10031  0.371488
#
# [51377 rows x 3 columns]

# %%
negative_weights = edge_list_df[edge_list_df['weight'] < 0]
print(f"Number of edges with negative weights: {len(negative_weights)}")
# Out:
# Number of edges with negative weights: 1981

# %% [markdown]
# Since Louvain is not made to consider negative edge weights, we will rescale the weights such that instead of [-1, 1] being the range, it is now [0, 1], where 0 now represents perfect dissimilarity, 0.5 represents orthogonality, and 1 represents perfect similarity.

# %%
edge_list_df['weight'] = (edge_list_df['weight'] + 1) / 2

print(edge_list_df)
# Out:
#        source  target    weight
# 0          p0      a1  0.876051
# 1          p0      a2  0.901599
# 2          p0      a3  0.950047
# 3          p0      a4  0.841207
# 4          p0      a5  0.916853
# ...       ...     ...       ...
# 51372  p10169   p8094  0.604586
# 51373  p10169   p7974  0.617701
# 51374  p10169   p5852  0.632609
# 51375  p10169  p10113  0.819664
# 51376  p10169  p10031  0.685744
#
# [51377 rows x 3 columns]

# %% [markdown]
# Before we continue with the creation of a graph, NetworkX specifies that an undirected, weighted graph must not have self-loop, parallel edges (A->B, B->A), or duplicate edges.

# %%
duplicate_edges = edge_list_df.duplicated(subset=['source', 'target'], keep=False)
print(f"Number of duplicate edges: {duplicate_edges.sum()}")

self_loops = edge_list_df[edge_list_df['source'] == edge_list_df['target']]
print(f"Number of self-loops: {len(self_loops)}")

print(edge_list_df.isnull().sum())
# Out:
# Number of duplicate edges: 0
# Number of self-loops: 4
# source    0
# target    0
# weight    0
# dtype: int64

# %%
print(f"Number of edges before dropping self-loops: {len(edge_list_df)}")

edge_list_df = edge_list_df[edge_list_df['source'] != edge_list_df['target']]

print(f"Number of edges after dropping self-loops: {len(edge_list_df)}")
# Out:
# Number of edges before dropping self-loops: 51377
# Number of edges after dropping self-loops: 51373

# %%
# Find duplicate edges (ignoring the weight column)
duplicate_edges = edge_list_df.duplicated(subset=['source', 'target'], keep=False)

# Filter to get only the duplicate edges
parallel_edges_df = edge_list_df[duplicate_edges]

# Sort to better visualize parallel edges
parallel_edges_sorted = parallel_edges_df.sort_values(by=['source', 'target'])

print(parallel_edges_sorted)
# Out:
# Empty DataFrame
# Columns: [source, target, weight]
# Index: []

# %% [markdown]
# ## Creating Undirected Weighted Graph
#
# We iterate over the edge list DataFrame rows to add edges along with their weights to a new NetworkX graph.

# %%
import networkx as nx

def get_graph_info(graph):
    print("Number of nodes:", graph.number_of_nodes())
    print("Number of edges:", graph.number_of_edges())
    
    # Checking the graph type to provide appropriate information
    if isinstance(graph, nx.DiGraph):
        print("Graph is Directed")
    else:
        print("Graph is Undirected")

# %%
# Initialize a new graph
G = nx.MultiGraph()

# Add edges and weights
for index, row in edge_list_df.iterrows():
    source = row['source']
    target = row['target']
    weight = row['weight']
    
    # Add the edge with weight
    G.add_edge(source, target, weight=weight)

# %%
get_graph_info(G)
# Out:
# Number of nodes: 15649
# Number of edges: 51373
# Graph is Undirected

# %% [markdown]
# ## Running Louvain Using CDLIB
#
# CDlib (Community Discovery Library) is designed for community detection and analysis, providing easy access to various algorithms, including Louvain and Leiden, and tools for evaluating and visualizing the results.

# %%
from cdlib import algorithms
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool', 'infomap', 'bayanpy', 'wurlitzer'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'pyclustering', 'ASLPAw'}
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'infomap', 'wurlitzer'}

# %%
communities_louvain = algorithms.louvain(G)

# Accessing the number of communities/partitions
num_partitions = len(communities_louvain.communities)
print(f"Number of partitions: {num_partitions}")

# Accessing modularity
modularity = communities_louvain.newman_girvan_modularity().score
print(f"Modularity: {modularity}")
# Out:
# Number of partitions: 1799
# Modularity: 0.5830536561607349

# %% [markdown]
# ## Running Leiden Using CDLIB

# %%
# Assuming `G` is your NetworkX graph with non-negative weights
communities_leiden = algorithms.leiden(G)

# Accessing the number of communities and other properties
num_partitions = len(communities_leiden.communities)
print(f"Number of partitions: {num_partitions}")

# Accessing modularity
modularity = communities_leiden.newman_girvan_modularity().score
print(f"Modularity: {modularity}")
# Out:
# Number of partitions: 29
# Modularity: 0.7384090385869698

# %% [markdown]
# ## Saving Node List w/ Community Assignments
#
# In order for us to visualize the partitions, we need to iterate through each partition and assign an ID to every node in it. This way we can color code when visualizing to see which nodes were assigned together.

# %% [markdown]
# ### Load Node ID List
#
# This was copied from Similar+Weights folder.

# %%
import pandas as pd

# Load node IDs into a DataFrame
node_df = pd.read_csv('New Input/M2V_node_indexes.txt', header=None, names=['nodeID'])

display(node_df)
# Out:
#        nodeID
# 0      v10189
# 1      v10187
# 2      v10181
# 3      v10188
# 4      v10178
# ...       ...
# 15644  p15459
# 15645  p14999
# 15646  p15549
# 15647  p14699
# 15648  p15127
#
# [15649 rows x 1 columns]

# %%
def get_type(node_id):
    if node_id.startswith('t'):
        return 'topic'
    elif node_id.startswith('a'):
        return 'author'
    elif node_id.startswith('v'):
        return 'venue'
    elif node_id.startswith('p'):
        return 'paper'
    else:
        return 'unknown'

node_df['type'] = node_df['nodeID'].apply(get_type)

display(node_df)
# Out:
#        nodeID   type
# 0      v10189  venue
# 1      v10187  venue
# 2      v10181  venue
# 3      v10188  venue
# 4      v10178  venue
# ...       ...    ...
# 15644  p15459  paper
# 15645  p14999  paper
# 15646  p15549  paper
# 15647  p14699  paper
# 15648  p15127  paper
#
# [15649 rows x 2 columns]

# %%
import matplotlib.cm as cm
import matplotlib

# %% [markdown]
# ### For Louvain

# %%
# Correctly accessing the communities for iteration
n_communities = len(communities_louvain.communities)
colors = cm.get_cmap('viridis', n_communities)

# Initialize the mapping dictionary
node_community_color_map = {}

for community_id, community_nodes in enumerate(communities_louvain.communities):
    color = colors(community_id / n_communities)  # Get a color from the colormap
    color_hex = matplotlib.colors.rgb2hex(color)  # Convert the color to hex format
    
    for node in community_nodes:
        node_community_color_map[str(node)] = {"communityID": community_id, "color": color_hex}

# %%
node_df_louvain = node_df.copy()

# Add community ID, color, and type to the DataFrame
node_df_louvain['communityID'] = node_df['nodeID'].apply(lambda x: node_community_color_map[x]['communityID'] if x in node_community_color_map else -1)
node_df_louvain['color'] = node_df['nodeID'].apply(lambda x: node_community_color_map[x]['color'] if x in node_community_color_map else '#000000')

display(node_df_louvain)
# Out:
#        nodeID   type  communityID    color
# 0      v10189  venue            2  #440154
# 1      v10187  venue            1  #440154
# 2      v10181  venue            5  #440154
# 3      v10188  venue            2  #440154
# 4      v10178  venue            2  #440154
# ...       ...    ...          ...      ...
# 15644  p15459  paper            7  #440154
# 15645  p14999  paper            2  #440154
# 15646  p15549  paper          861  #228b8d
# 15647  p14699  paper          253  #46327e
# 15648  p15127  paper          103  #481668
#
# [15649 rows x 4 columns]

# %%
# Select relevant columns if necessary and export to CSV
node_df_louvain[['nodeID', 'communityID', 'color', 'type']].to_csv('Output/node_metadata_M2V_Louvain.csv', index=False, sep=';')

# %% [markdown]
# ### For Leiden

# %%
# Correctly accessing the communities for iteration
n_communities = len(communities_leiden.communities)
colors = cm.get_cmap('viridis', n_communities)

# Initialize the mapping dictionary
node_community_color_map = {}

for community_id, community_nodes in enumerate(communities_leiden.communities):
    color = colors(community_id / n_communities)  # Get a color from the colormap
    color_hex = matplotlib.colors.rgb2hex(color)  # Convert the color to hex format
    
    for node in community_nodes:
        node_community_color_map[str(node)] = {"communityID": community_id, "color": color_hex}

# %%
node_df_leiden = node_df.copy()

# Add community ID, color, and type to the DataFrame
node_df_leiden['communityID'] = node_df['nodeID'].apply(lambda x: node_community_color_map[x]['communityID'] if x in node_community_color_map else -1)
node_df_leiden['color'] = node_df['nodeID'].apply(lambda x: node_community_color_map[x]['color'] if x in node_community_color_map else '#000000')

display(node_df_leiden)
# Out:
#        nodeID   type  communityID    color
# 0      v10189  venue            0  #440154
# 1      v10187  venue            3  #482677
# 2      v10181  venue            1  #470e61
# 3      v10188  venue            0  #440154
# 4      v10178  venue            0  #440154
# ...       ...    ...          ...      ...
# 15644  p15459  paper            5  #433d84
# 15645  p14999  paper            0  #440154
# 15646  p15549  paper           20  #4ac16d
# 15647  p14699  paper            1  #470e61
# 15648  p15127  paper           12  #277f8e
#
# [15649 rows x 4 columns]

# %%
# Select relevant columns if necessary and export to CSV
node_df_leiden[['nodeID', 'communityID', 'color', 'type']].to_csv('Output/node_metadata_M2V_Leiden.csv', index=False, sep=';')

# %% [markdown]
# ## Exploring Community Assignments
#
# We would also like to explore the difference in communities between Leiden and Louvain, check whether they make sense by looking at their content, and investigate why Leiden produces significantly less communities in comparison to Louvain.

# %% [markdown]
# ### Import Original Node Information
#
# First, we import the original dataset information including venue, paper, author and topic names. This way we can check if the assignment makes sense, by looking at the actual content of its nodes.

# %%
tags_df = pd.read_csv('Extra Input/tags.dat', sep='\t', encoding='ISO-8859-1')
artists_df = pd.read_csv('Extra Input/artists.dat', sep='\t')
users_df = pd.read_csv('Extra Input/user_friends.dat', sep='\t')

artists_df = artists_df.drop(['url', 'pictureURL'], axis=1)

display(tags_df)
display(artists_df)
display(users_df)
# Out:
#        tagID           tagValue
# 0          1              metal
# 1          2  alternative metal
# 2          3          goth rock
# 3          4        black metal
# 4          5        death metal
# ...      ...                ...
# 11941  12644              suomi
# 11942  12645          symbiosis
# 11943  12646            sverige
# 11944  12647               eire
# 11945  12648     electro latino
#
# [11946 rows x 2 columns]
#           id               name
# 0          1       MALICE MIZER
# 1          2    Diary of Dreams
# 2          3  Carpathian Forest
# 3          4       Moi dix Mois
# 4          5        Bella Morte
# ...      ...                ...
# 17627  18741     Diamanda Galás
# 17628  18742             Aya RL
# 17629  18743        Coptic Rain
# 17630  18744       Oz Alchemist
# 17631  18745   Grzegorz Tomczak
#
# [17632 rows x 2 columns]
#        userID  friendID
# 0           2       275
# 1           2       428
# 2           2       515
# 3           2       761
# 4           2       831
# ...       ...       ...
# 25429    2099      1801
# 25430    2099      2006
# 25431    2099      2016
# 25432    2100       586
# 25433    2100       607
#
# [25434 rows x 2 columns]

# %% [markdown]
# To add the names of tags and artists to our main dataframes, we create dictionaries that help us directly map ID to name. We also define a function that adds the corresponding name to a new column based on the ID.

# %%
tag_dict = pd.Series(tags_df.tagValue.values, index=tags_df.tagID).to_dict()
artist_dict = pd.Series(artists_df.name.values, index=artists_df.id).to_dict()

def id_to_name(node_id):
    prefix = node_id[0]
    # Adjust this line based on the actual format of your node IDs
    numeric_part = node_id.split('_')[-1]  # This splits at the underscore and takes the last part
    
    try:
        numeric_id = int(numeric_part)
    except ValueError:
        return "Invalid ID format"
    
    if prefix == 't':
        return tag_dict.get(numeric_id, "Unknown Tag")
    elif prefix == 'a':
        return artist_dict.get(numeric_id, "Unknown Artist")
    return "Invalid prefix"

# %%
node_df_louvain['name'] = node_df_louvain['nodeID'].apply(id_to_name)
node_df_leiden['name'] = node_df_leiden['nodeID'].apply(id_to_name)

# %%
display(node_df_louvain)
display(node_df_leiden)
# Out:
#        nodeID    type  communityID    color              name
# 0        t_73     tag            0  #440154              rock
# 1        t_24     tag            3  #440256               pop
# 2        t_79     tag            0  #440154       alternative
# 3        t_18     tag            1  #440154        electronic
# 4        t_81     tag            0  #440154             indie
# ...       ...     ...          ...      ...               ...
# 21513  a_9850  artist            3  #440256              K.K.
# 21514  a_2770  artist            2  #440154          Teratism
# 21515  a_5723  artist            3  #440256             NSYNC
# 21516  a_3395  artist            3  #440256  Nosso Sentimento
# 21517  a_7497  artist            1  #440154       Mike & Rich
#
# [21518 rows x 5 columns]
#        nodeID    type  communityID    color              name
# 0        t_73     tag            0  #440154              rock
# 1        t_24     tag            3  #414487               pop
# 2        t_79     tag            0  #440154       alternative
# 3        t_18     tag            1  #481a6c        electronic
# 4        t_81     tag            0  #440154             indie
# ...       ...     ...          ...      ...               ...
# 21513  a_9850  artist            3  #414487              K.K.
# 21514  a_2770  artist            5  #31688e          Teratism
# 21515  a_5723  artist            3  #414487             NSYNC
# 21516  a_3395  artist            3  #414487  Nosso Sentimento
# 21517  a_7497  artist            1  #481a6c       Mike & Rich
#
# [21518 rows x 5 columns]

# %% [markdown]
# ### **For Louvain**

# %% [markdown]
# #### Overview of Community Data
#
# First, we aggregate the data by community ID to get an overview of each community's composition. We group our DataFrame by the community ID and then examine the types and names within each community.

# %%
# Group by community ID and list out members of each community
community_groups_louvain = node_df_louvain.groupby('communityID')

# Example to print out the composition of each community
for community_id, group in community_groups_louvain:
    print(f"Community ID: {community_id}")
    print(f"Members count: {len(group)}")
    print(group[['nodeID', 'name', 'type']].head())  # Adjust as needed
    print("\n")
# Out:
# Community ID: 0
# Members count: 4983
#    nodeID              name type
# 0    t_73              rock  tag
# 2    t_79       alternative  tag
# 4    t_81             indie  tag
# 6    t_78  alternative rock  tag
# 10   t_84        indie rock  tag
#
#
# Community ID: 1
# Members count: 3657
#    nodeID          name type
# 3    t_18    electronic  tag
# 5    t_33  experimental  tag
# 8   t_352           90s  tag
# 9    t_14       ambient  tag
# 11  t_187   electronica  tag
#
#
# Community ID: 2
# Members count: 3150
#    nodeID              name type
# 14    t_1             metal  tag
# 16   t_72         hard rock  tag
# 17  t_192      classic rock  tag
# 20  t_735               70s  tag
# 25  t_387  progressive rock  tag
#
#
# Community ID: 3
# Members count: 3048
#    nodeID        name type
# 1    t_24         pop  tag
# 21  t_625        soul  tag
# 46  t_308       latin  tag
# 48  t_512    romantic  tag
# 55  t_199  electropop  tag
#
#
# Community ID: 4
# Members count: 925
#    nodeID          name    type
# 7    t_25           80s     tag
# 27  t_275     post-punk     tag
# 51   t_17     synth pop     tag
# 60  t_203         disco     tag
# 85   a_72  Depeche Mode  artist
#
#
# Community ID: 5
# Members count: 374
#      nodeID            name type
# 22    t_103             rap  tag
# 34    t_304         hip hop  tag
# 204   t_197     gangsta rap  tag
# 271  t_6162     hip hop/rap  tag
# 320  t_3555  east coast rap  tag
#
#
# Community ID: 6
# Members count: 187
#      nodeID             name type
# 41    t_193          country  tag
# 105  t_1096       chill zone  tag
# 205  t_4430  classic country  tag
# 293  t_6645      new country  tag
# 410  t_1767   country ladies  tag
#
#
# Community ID: 7
# Members count: 57
#       nodeID                   name    type
# 67     t_140                  j-pop     tag
# 113    t_139                 j-rock     tag
# 270   t_1219                  jrock     tag
# 3194  a_4980                 Olivia  artist
# 3417  a_1919  HIGH and MIGHTY COLOR  artist
#
#
# Community ID: 8
# Members count: 50
#        nodeID                            name    type
# 44      t_545                       classical     tag
# 3286   u_1723                  Invalid prefix    user
# 6814   a_1491                 Antonio Vivaldi  artist
# 7010   a_7119                 Johannes Brahms  artist
# 9037  a_16319  Heinrich Ignaz Franz von Biber  artist
#
#
# Community ID: 9
# Members count: 49
#        nodeID            name    type
# 97      t_183  christian rock     tag
# 101     t_712          gospel     tag
# 3012   u_1177  Invalid prefix    user
# 5833   a_3092    Decyfer Down  artist
# 5942  a_11217        Hillsong  artist
#
#
# Community ID: 10
# Members count: 46
#         nodeID              name    type
# 6553    u_1499    Invalid prefix    user
# 16075  a_14992          Big Stuf  artist
# 16867  a_15002  Joel Rosenberger  artist
# 16979  a_15028      Guy Mitchell  artist
# 17001  a_14997      Chelsie Boyd  artist
#
#
# Community ID: 11
# Members count: 43
#         nodeID            name    type
# 3958    u_1847  Invalid prefix    user
# 10067  a_17044   The Pop Group  artist
# 11471  a_17013       Loop Guru  artist
# 12049  a_16449   Nicole Atkins  artist
# 12967  a_17051    Baby Mammoth  artist
#
#
# Community ID: 12
# Members count: 42
#        nodeID            name    type
# 378   t_12639   winds of soul     tag
# 5109   u_2095  Invalid prefix    user
# 8680   a_2952        Azam Ali  artist
# 8882  a_18692    Farid Farjad  artist
# 8976   a_8699             Vas  artist
#
#
# Community ID: 13
# Members count: 42
#         nodeID            name    type
# 7648   a_12470     Brent Lewis  artist
# 8071    u_1121  Invalid prefix    user
# 11658  a_12437      Yansımalar  artist
# 11880  a_12439     Kani Karaca  artist
# 12634  a_12457     Ercan Irmak  artist
#
#
# Community ID: 14
# Members count: 40
#        nodeID                    name    type
# 5206    u_360          Invalid prefix    user
# 10907  a_6081              Powerglove  artist
# 14273  a_6108  Goemon Production Team  artist
# 14642  a_6092           Stephen Rippy  artist
# 15470  a_6111  SIGN/dot Hack/dot Hack  artist
#
#
# Community ID: 15
# Members count: 39
#         nodeID            name    type
# 2582     u_820  Invalid prefix    user
# 7957   a_10346        The Digs  artist
# 11500  a_10367  The Millennium  artist
# 11901  a_10377  Alain Goraguer  artist
# 11968  a_10369  Burt Bacharach  artist
#
#
# Community ID: 16
# Members count: 38
#         nodeID                           name    type
# 6587    u_1854                 Invalid prefix    user
# 7966   a_17120                 Nass Marrakech  artist
# 10748  a_17130  Ali Farka Touré and Ry Cooder  artist
# 13199  a_17105                   Houria Aïchi  artist
# 14804   a_7558                    Salif Keita  artist
#
#
# Community ID: 17
# Members count: 38
#         nodeID            name    type
# 5125    u_1315  Invalid prefix    user
# 10188  a_13814    The Spinners  artist
# 14462  a_13827    Thavius Beck  artist
# 14722  a_13802         Def Tex  artist
# 14766  a_13819          Factor  artist
#
#
# Community ID: 18
# Members count: 37
#        nodeID            name    type
# 1719    u_467  Invalid prefix    user
# 7364   a_7214       Téléphone  artist
# 9240   a_7242  Stephan Eicher  artist
# 11887  a_7225     Tom Poisson  artist
# 11905  a_7197          Renaud  artist
#
#
# Community ID: 19
# Members count: 37
#         nodeID                            name    type
# 3948    u_1721                  Invalid prefix    user
# 9742   a_16294   Big Sandy & His Fly-Rite Boys  artist
# 12258  a_16302                 Skeets McDonald  artist
# 12884  a_16289  Bob Wills & His Texas Playboys  artist
# 12933  a_16274                        Restless  artist
#
#
# Community ID: 20
# Members count: 37
#         nodeID             name    type
# 4184    u_1090   Invalid prefix    user
# 9800   a_12239    Bounty Killer  artist
# 11401  a_12237     Richie Spice  artist
# 11648  a_11074  Morgan Heritage  artist
# 13070  a_12235    Natural Black  artist
#
#
# Community ID: 21
# Members count: 37
#         nodeID            name    type
# 3745    u_1930  Invalid prefix    user
# 10105  a_17667         Gothika  artist
# 11111  a_17662            ヴァルナ  artist
# 11434  a_12816           ギルティア  artist
# 12856   a_6994            Nega  artist
#
#
# Community ID: 22
# Members count: 35
#        nodeID                 name    type
# 3692    u_296       Invalid prefix    user
# 9297   a_5386   The Knickerbockers  artist
# 11181  a_5370     The Strangeloves  artist
# 13149  a_5397         Dale Hawkins  artist
# 15219  a_5403  The Dave Clark Five  artist
#
#
# Community ID: 23
# Members count: 34
#       nodeID            name    type
# 75     t_265             ska     tag
# 2075   u_507  Invalid prefix    user
# 4138  a_5645  The Aggrolites  artist
# 7869  a_7529            Yatu  artist
# 7995  a_7524          Hepcat  artist
#
#
# Community ID: 24
# Members count: 33
#        nodeID                      name    type
# 2220    u_238            Invalid prefix    user
# 9054   a_4638                   SUPERiO  artist
# 11290  a_4626                 Unnaddarè  artist
# 11546  a_4652                 Last Exit  artist
# 11601  a_4647  Henry Threadgill's Zooid  artist
#
#
# Community ID: 25
# Members count: 33
#        nodeID             name    type
# 4040    u_552   Invalid prefix    user
# 8770   a_7976           Skynet  artist
# 13011  a_7991  DJ floorclearer  artist
# 15848  a_7978            Fizyk  artist
# 15915  a_7965           snaper  artist
#
#
# Community ID: 26
# Members count: 32
#       nodeID            name    type
# 2309     u_3  Invalid prefix    user
# 10956  a_116         Fjordne  artist
# 11277  a_122     Manekinekod  artist
# 12428  a_140      Matryoshka  artist
# 12563  a_108    Magnitophono  artist
#
#
# Community ID: 27
# Members count: 32
#         nodeID            name    type
# 6938    u_1867  Invalid prefix    user
# 11600  a_17253   The Silencers  artist
# 11983  a_13244     Chixdiggit!  artist
# 12480  a_17267          Lustra  artist
# 14654   a_5021        Ber-linn  artist
#
#
# Community ID: 28
# Members count: 32
#       nodeID                               name    type
# 1103   u_508                     Invalid prefix    user
# 6032  a_7561                   Orchestra Baobab  artist
# 7126  a_7596                         Mory Kanté  artist
# 8922  a_7582  Ali Farka Touré & Toumani Diabaté  artist
# 9222  a_7581                    Ali Farka Touré  artist
#
#
# Community ID: 29
# Members count: 32
#         nodeID            name    type
# 5179     u_810  Invalid prefix    user
# 13717  a_10250      Şevval Sam  artist
# 15897  a_10269        Guelay74  artist
# 15955  a_10257           Şenay  artist
# 16035  a_10263  Rafet El Roman  artist
#
#
# Community ID: 30
# Members count: 31
#         nodeID            name    type
# 2394    u_1719  Invalid prefix    user
# 9205    a_4636              Zu  artist
# 11939  a_16250             2up  artist
# 13000  a_16239           NOISM  artist
# 13578  a_16249            PE'Z  artist
#
#
# Community ID: 31
# Members count: 29
#         nodeID                 name    type
# 689     u_1882       Invalid prefix    user
# 12577  a_17348     Black Star Liner  artist
# 13713  a_17333         Hamza El Din  artist
# 13842  a_17371  Dahmane El Harrachi  artist
# 14981  a_17343                Jomed  artist
#
#
# Community ID: 32
# Members count: 28
#        nodeID              name    type
# 5024    u_341    Invalid prefix    user
# 11125  a_3529       Supersilent  artist
# 11623  a_5877         Pendulums  artist
# 11845  a_5861     Raccoo-oo-oon  artist
# 12061  a_5852  Mohave Triangles  artist
#
#
# Community ID: 33
# Members count: 28
#        nodeID            name    type
# 1558    u_618  Invalid prefix    user
# 8915   a_8621  Young Heretics  artist
# 11322  a_8633        Dianogah  artist
# 11504  a_8617    What We Feel  artist
# 13690  a_8627       Дядя Женя  artist
#
#
# Community ID: 34
# Members count: 28
#        nodeID                      name    type
# 3315    u_801            Invalid prefix    user
# 6471  a_10146               Karyn White  artist
# 7524  a_10151  Gladys Knight & The Pips  artist
# 8239  a_10150             Patti LaBelle  artist
# 9170   a_8975              Bobby Womack  artist
#
#
# Community ID: 35
# Members count: 28
#         nodeID                name    type
# 1687    u_1371      Invalid prefix    user
# 9540   a_14162  The Cast of Cheers  artist
# 11323  a_14170                ILWT  artist
# 15959  a_14181          Pakava It'  artist
# 16669  a_14159  Billy Crystal Meth  artist
#
#
# Community ID: 36
# Members count: 27
#        nodeID                           name    type
# 1164    u_660                 Invalid prefix    user
# 10743  a_9034                      Bimbo Boy  artist
# 10860  a_9026                     Candy Girl  artist
# 11515  a_9036  Magda Femme & Iwona Węgrowska  artist
# 11689  a_9033                     Man Meadow  artist
#
#
# Community ID: 37
# Members count: 27
#         nodeID            name    type
# 4174    u_1891  Invalid prefix    user
# 11964  a_17451     Cleanscreen  artist
# 12218  a_17456         Iambic²  artist
# 14367    a_762    the Chemodan  artist
# 14744  a_17194             ТГК  artist
#
#
# Community ID: 38
# Members count: 27
#        nodeID                   name    type
# 5082     u_81         Invalid prefix    user
# 11466  a_2249  Compton's Most Wanted  artist
# 11830  a_2231                Spice 1  artist
# 13340  a_2229                DJ Quik  artist
# 14620  a_2260                  K-Dee  artist
#
#
# Community ID: 39
# Members count: 27
#        nodeID              name    type
# 3547    u_607    Invalid prefix    user
# 11087  a_8533  Shape of Despair  artist
# 12548  a_8517            Thorns  artist
# 13023  a_8516        Gallhammer  artist
# 14311  a_8328          Krabaras  artist
#
#
# Community ID: 40
# Members count: 27
#         nodeID                 name    type
# 2123    u_1221       Invalid prefix    user
# 11908  a_13257            Parasites  artist
# 13826  a_13234              Transit  artist
# 14477  a_13237  This Time Next Year  artist
# 16175  a_13254            Iron Chic  artist
#
#
# Community ID: 41
# Members count: 27
#         nodeID              name    type
# 1852    u_1939    Invalid prefix    user
# 10029  a_10228              水樹奈々  artist
# 10974  a_17766  Johann Pachelbel  artist
# 15036  a_17756   MOSAIC.WAV×鶴田加茂  artist
# 15396  a_17754        MOSAIC.WAV  artist
#
#
# Community ID: 42
# Members count: 26
#       nodeID              name    type
# 548   t_2141  my indie friends     tag
# 3253   u_217    Invalid prefix    user
# 4273  a_4397    Angry Petunias  artist
# 7384  a_4396      HealeyIsland  artist
# 8694  a_4411      Milo Moesche  artist
#
#
# Community ID: 43
# Members count: 26
#        nodeID            name    type
# 80      t_190     gothic rock     tag
# 4378   u_2090  Invalid prefix    user
# 7189  a_12977       The Prids  artist
# 7681  a_12504     Crimson Ivy  artist
# 7736  a_18634     O. Children  artist
#
#
# Community ID: 44
# Members count: 26
#         nodeID                           name    type
# 4601    u_1166                 Invalid prefix    user
# 10967   a_3725                          Bar 9  artist
# 12148  a_12846                           Seba  artist
# 15112  a_12837                      Logistics  artist
# 15388  a_12849  Counterstrike & Current Value  artist
#
#
# Community ID: 45
# Members count: 26
#        nodeID                             name    type
# 2479    u_291                   Invalid prefix    user
# 11336  a_5288                     Rachael Sage  artist
# 14931  a_5294                             Finn  artist
# 15103  a_5283  Raney Shockne Feat. Stella Moon  artist
# 15174  a_5269                       Asher Book  artist
#
#
# Community ID: 46
# Members count: 25
#         nodeID            name    type
# 2679    u_1426  Invalid prefix    user
# 8795   a_14501    The BossHoss  artist
# 11050  a_14089          BR5-49  artist
# 11349  a_14481      Lee Rocker  artist
# 11796   a_5392      Jack Scott  artist
#
#
# Community ID: 47
# Members count: 25
#        nodeID              name    type
# 4153    u_661    Invalid prefix    user
# 9097   a_9065   Anita Livstrand  artist
# 11587  a_9076       Yavuz Çetin  artist
# 12173  a_9055          maliétès  artist
# 12178  a_9042  Ünol Büyükgönenç  artist
#
#
# Community ID: 48
# Members count: 24
#        nodeID                name    type
# 5160    u_663      Invalid prefix    user
# 11554  a_1157                坂本真綾  artist
# 11602  a_9098  day after tomorrow  artist
# 11853  a_9102               Suara  artist
# 11897  a_9096                  樹海  artist
#
#
# Community ID: 49
# Members count: 24
#         nodeID            name    type
# 5741    u_1576  Invalid prefix    user
# 8356    a_6700      Blue Angel  artist
# 11033   a_3760    Idina Menzel  artist
# 11420  a_15399   Erik og Kriss  artist
# 12266   a_5285  Megan Mullally  artist
#
#
# Community ID: 50
# Members count: 24
#        nodeID            name    type
# 824     u_561  Invalid prefix    user
# 7485   a_8093          Auburn  artist
# 12976  a_8096    Dawn Richard  artist
# 13433  a_8084       Baby Bash  artist
# 13546  a_8073        Mashonda  artist
#
#
# Community ID: 51
# Members count: 24
#         nodeID            name    type
# 5978    u_1710  Invalid prefix    user
# 8858    a_4895   Янка Дягилева  artist
# 11183   a_5970        iamerror  artist
# 11357  a_16184       Babangida  artist
# 11882  a_16191              8u  artist
#
#
# Community ID: 52
# Members count: 24
#         nodeID                                name    type
# 5816    u_2005                      Invalid prefix    user
# 11577  a_18161                     Stian Westerhus  artist
# 11722  a_18177                Arild Andersen Group  artist
# 12114  a_18169  Sidsel Endresen & Bugge Wesseltoft  artist
# 12858  a_18176                 Nik Bärtsch's Ronin  artist
#
#
# Community ID: 53
# Members count: 24
#        nodeID            name    type
# 3915   u_1330  Invalid prefix    user
# 6166  a_13917    Fatback Band  artist
# 7422  a_13923    Ohio Players  artist
# 8850  a_13815    The Bar-Kays  artist
# 9214  a_13926   The Bongolian  artist
#
#
# Community ID: 54
# Members count: 24
#         nodeID            name    type
# 3618    u_1477  Invalid prefix    user
# 11391  a_14751    Marco Carola  artist
# 11394  a_14783           Popof  artist
# 12134  a_14764     John Tejada  artist
# 14288  a_11202      Marc Houle  artist
#
#
# Community ID: 55
# Members count: 24
#         nodeID                      name    type
# 5276    u_1654            Invalid prefix    user
# 9316   a_15863  All Girl Summer Fun Band  artist
# 11410  a_15871               The Pastels  artist
# 11948  a_15853                Tiger Trap  artist
# 12069  a_15862             Henry's Dress  artist
#
#
# Community ID: 56
# Members count: 23
#         nodeID             name    type
# 3661     u_929   Invalid prefix    user
# 9651    a_1238        Tinariwen  artist
# 10971  a_11136           Khaled  artist
# 11862  a_11150      Julien Doré  artist
# 12651  a_11132  Gnawa Diffusion  artist
#
#
# Community ID: 57
# Members count: 23
#        nodeID            name    type
# 5927    u_106  Invalid prefix    user
# 8894   a_2732   Кожаный Олень  artist
# 11252  a_2717        64revolt  artist
# 11720  a_2712   Firebrand Boy  artist
# 14393  a_2715       Bonaparte  artist
#
#
# Community ID: 58
# Members count: 23
#        nodeID                     name    type
# 3700    u_115           Invalid prefix    user
# 12289  a_2879             Ace Moreland  artist
# 13171  a_2865           Anders Osborne  artist
# 15466  a_2863            Kirk Fletcher  artist
# 16791  a_2891  Bobby Greenshoes Parker  artist
#
#
# Community ID: 59
# Members count: 23
#        nodeID             name    type
# 4004    u_131   Invalid prefix    user
# 11018  a_3153   Adrian Sanchez  artist
# 11151  a_3133        Scientist  artist
# 11296  a_3154           YouDub  artist
# 12285  a_3142  Linval Thompson  artist
#
#
# Community ID: 60
# Members count: 23
#        nodeID             name    type
# 3445    u_394   Invalid prefix    user
# 8615   a_6466      Groundation  artist
# 9030   a_6469        Mato Seco  artist
# 11411  a_6475  Leões de Israel  artist
# 12909  a_5443       João Bosco  artist
#
#
# Community ID: 61
# Members count: 23
#        nodeID                  name    type
# 3708    u_386        Invalid prefix    user
# 11429  a_6347            Shu-Bi-Dua  artist
# 11937  a_6353            Kim Larsen  artist
# 12718  a_6357            Celina Ree  artist
# 13420  a_6364  Kim Larsen & Bellami  artist
#
#
# Community ID: 62
# Members count: 23
#        nodeID            name    type
# 4489    u_444  Invalid prefix    user
# 11285  a_6963     Halo Manash  artist
# 12953  a_6970       Blood Box  artist
# 13478  a_6986         _Algol_  artist
# 13906  a_6979          Arditi  artist
#
#
# Community ID: 63
# Members count: 22
#       nodeID                 name    type
# 56     t_311               reggae     tag
# 1625  t_1468         roots reggae     tag
# 3439  a_3846          The Wailers  artist
# 5487  a_3147  Lee "Scratch" Perry  artist
# 6705   a_286           Peter Tosh  artist
#
#
# Community ID: 64
# Members count: 22
#        nodeID              name    type
# 1144    u_122    Invalid prefix    user
# 9831   a_2996  Uncle Dave Macon  artist
# 11422  a_2991       Fats Waller  artist
# 11962  a_3023       Buell Kazee  artist
# 12402  a_3005      Louis Jordan  artist
#
#
# Community ID: 65
# Members count: 22
#        nodeID                     name    type
# 4859    u_601           Invalid prefix    user
# 7346    a_723  Buena Vista Social Club  artist
# 11957  a_8432             Quadro Nuevo  artist
# 12131  a_8426              Barış Güney  artist
# 13113  a_8446         Peyman Yazdanian  artist
#
#
# Community ID: 66
# Members count: 22
#         nodeID             name    type
# 4692    u_1755   Invalid prefix    user
# 12048  a_16468  Clutchy Hopkins  artist
# 12521  a_16459         Prurient  artist
# 12736  a_16466    Liquid Liquid  artist
# 14680  a_12365     Marnie Stern  artist
#
#
# Community ID: 67
# Members count: 22
#        nodeID             name    type
# 5211    u_382   Invalid prefix    user
# 11743  a_6337     Company Flow  artist
# 12763  a_6325  Jungle Brothers  artist
# 12816  a_6324         3rd Bass  artist
# 13503  a_6340   The Last Poets  artist
#
#
# Community ID: 68
# Members count: 22
#         nodeID            name    type
# 4134    u_1848  Invalid prefix    user
# 6120   a_17054      June Tabor  artist
# 10819  a_17064     Quack Quack  artist
# 10857  a_17065      Oysterband  artist
# 11172  a_17062   blah blah tin  artist
#
#
# Community ID: 69
# Members count: 22
#         nodeID              name    type
# 4948    u_1996    Invalid prefix    user
# 11448  a_15101           Lil Rob  artist
# 14448   a_9910  Jay-Z & Coldplay  artist
# 14760  a_12854     High Contrast  artist
# 15099   a_2232      Mr. Capone-E  artist
#
#
# Community ID: 70
# Members count: 22
#        nodeID            name    type
# 3977     u_83  Invalid prefix    user
# 9698   a_2303   Haris Alexiou  artist
# 11095  a_2323       Baba Zula  artist
# 11461  a_2322     Zerrin Özer  artist
# 11529  a_2319         Nilüfer  artist
#
#
# Community ID: 71
# Members count: 22
#        nodeID               name    type
# 5619    u_294     Invalid prefix    user
# 8349   a_5326        Dissidenten  artist
# 11266  a_5336             Ocelot  artist
# 12290  a_5356           Raappana  artist
# 13372  a_5340  Bodhisattva 13:20  artist
#
#
# Community ID: 72
# Members count: 22
#         nodeID                            name    type
# 774     u_1167                  Invalid prefix    user
# 11070   a_6914  Sharon Jones and the Dap-Kings  artist
# 13061   a_7565                      Baaba Maal  artist
# 13641  a_12876                      Matt Darey  artist
# 13692  a_12885                           Ganga  artist
#
#
# Community ID: 73
# Members count: 21
#         nodeID               name    type
# 354     u_1761     Invalid prefix    user
# 10209  a_16506     Patrice Rushen  artist
# 10498  a_16512                Guy  artist
# 11359  a_16504  Sabrina Malheiros  artist
# 11490  a_16517      Angela Bofill  artist
#
#
# Community ID: 74
# Members count: 21
#         nodeID            name    type
# 3073    u_1013  Invalid prefix    user
# 5101     u_834  Invalid prefix    user
# 10656  a_10485           Газон  artist
# 11537  a_10494         Элизиум  artist
# 11829    a_781   Fail Emotions  artist
#
#
# Community ID: 75
# Members count: 21
#        nodeID            name    type
# 1503   u_1276  Invalid prefix    user
# 11156  a_9794       Fireworks  artist
# 12835  a_8921  Youth of Today  artist
# 14162  a_9801      Cold World  artist
# 14513  a_1962   King Geedorah  artist
#
#
# Community ID: 76
# Members count: 21
#         nodeID              name    type
# 1267    u_2025    Invalid prefix    user
# 8993   a_18290           Fun Fun  artist
# 10169  a_18284         Company B  artist
# 11485  a_18296     Pretty Poison  artist
# 11746   a_4590  Afrika Bambaataa  artist
#
#
# Community ID: 77
# Members count: 21
#         nodeID              name    type
# 5625    u_1599    Invalid prefix    user
# 12014  a_15495        Jet Market  artist
# 13063  a_15504  Nodes of Ranvier  artist
# 13168  a_15507           Colchon  artist
# 13865  a_15502          Golliwog  artist
#
#
# Community ID: 78
# Members count: 21
#         nodeID            name    type
# 1993    u_1971  Invalid prefix    user
# 13915  a_17943         XFilesX  artist
# 14351  a_17094          Cursed  artist
# 14371   a_5632           Verse  artist
# 14432   a_5227       Mortician  artist
#
#
# Community ID: 79
# Members count: 21
#         nodeID            name    type
# 4592    u_1915  Invalid prefix    user
# 10012  a_17571     Amanda Lear  artist
# 12479  a_16786            Kele  artist
# 12871  a_17572    Mirko Oberto  artist
# 12895  a_10658         Cassius  artist
#
#
# Community ID: 80
# Members count: 21
#        nodeID                name    type
# 420     u_655      Invalid prefix    user
# 9152   a_8979               Rufus  artist
# 10383  a_8966                Nina  artist
# 11605  a_8977          Raul Midón  artist
# 12121  a_8976  Melissa Manchester  artist
#
#
# Community ID: 81
# Members count: 21
#         nodeID                       name    type
# 1202    u_1161             Invalid prefix    user
# 11212  a_12808                        アヲイ  artist
# 11314  a_12811                     UnsraW  artist
# 12112  a_12801                Megaromania  artist
# 12122   a_5110  Dio - Distraught Overlord  artist
#
#
# Community ID: 82
# Members count: 20
#         nodeID                  name    type
# 4835    u_1694        Invalid prefix    user
# 14215   a_9388        Slaughterhouse  artist
# 14679  a_16083           Gorilla Zoe  artist
# 14683  a_13902  Army of the Pharaohs  artist
# 15014   a_6329             One Be Lo  artist
#
#
# Community ID: 83
# Members count: 20
#         nodeID             name    type
# 1660    u_1484   Invalid prefix    user
# 10757   a_3043       Have Heart  artist
# 10803   a_5628    The Cool Kids  artist
# 11604   a_8937         Carry On  artist
# 11686  a_10320  Helge Schneider  artist
#
#
# Community ID: 84
# Members count: 20
#         nodeID                    name    type
# 5986    u_1630          Invalid prefix    user
# 10983  a_15717  When Saints Go Machine  artist
# 11042  a_14124    Big Bad Voodoo Daddy  artist
# 11082  a_15720     Bo Kaspers Orkester  artist
# 12154  a_15728          Mikael Simpson  artist
#
#
# Community ID: 85
# Members count: 20
#        nodeID                    name    type
# 5149    u_262          Invalid prefix    user
# 10572  a_3407              Klimt 1918  artist
# 12230  a_4969          Danny Cavanagh  artist
# 15382  a_4966      Storm of Capricorn  artist
# 15452  a_4973  CCCP Fedeli alla linea  artist
#
#
# Community ID: 86
# Members count: 20
#         nodeID                    name    type
# 4068    u_1779          Invalid prefix    user
# 12459  a_16644  kill my bleeding smile  artist
# 13499  a_16626     El Último Ke Zierre  artist
# 13520  a_16641     Soziedad Alkoholika  artist
# 13644  a_16628         Fiskales Ad-Hok  artist
#
#
# Community ID: 87
# Members count: 20
#         nodeID            name    type
# 373    a_16875        Bankrupt  artist
# 10722   t_2881       punk-rock     tag
# 10726  t_11215  singalong punk     tag
# 13043  t_11196         us punk     tag
# 13505  t_11202  punk rock show     tag
#
#
# Community ID: 88
# Members count: 19
#         nodeID            name    type
# 4542    u_1398  Invalid prefix    user
# 6271   a_14324     Sailor Moon  artist
# 9674     a_395            NEWS  artist
# 12345    a_394            山下智久  artist
# 12862  a_14323    Heather Dale  artist
#
#
# Community ID: 89
# Members count: 19
#         nodeID            name    type
# 5481    u_1770  Invalid prefix    user
# 10933   a_2135     Chiddy Bang  artist
# 11103   a_5874            Hive  artist
# 11362  a_16575           U-God  artist
# 12533  a_16570   Killah Priest  artist
#
#
# Community ID: 90
# Members count: 19
#        nodeID              name    type
# 4508    u_533    Invalid prefix    user
# 7095   a_7506              Bond  artist
# 12180  a_7851      Juan Gabriel  artist
# 14502  a_1494      Rocío Dúrcal  artist
# 14930  a_6860  Declan Galbraith  artist
#
#
# Community ID: 91
# Members count: 19
#        nodeID                     name    type
# 6551     u_55           Invalid prefix    user
# 10864  a_1634        Souls of Mischief  artist
# 12176  a_1606  People Under the Stairs  artist
# 12311  a_1623          Jeru the Damaja  artist
# 12545  a_1626           Living Legends  artist
#
#
# Community ID: 92
# Members count: 19
#        nodeID               name    type
# 3826    u_576     Invalid prefix    user
# 10315  a_8216  General Elektriks  artist
# 11331  a_8221              Gabin  artist
# 12655  a_8226           Skeewiff  artist
# 13289  a_8218       Berry Weight  artist
#
#
# Community ID: 93
# Members count: 19
#         nodeID            name    type
# 5478     u_900  Invalid prefix    user
# 10975  a_10937          HAKUEI  artist
# 11024   a_2104           ルルティア  artist
# 13414  a_10926     ALI PROJECT  artist
# 14230  a_10929            有澤孝紀  artist
#
#
# Community ID: 94
# Members count: 19
#         nodeID                                     name    type
# 3741    u_1123                           Invalid prefix    user
# 11312  a_12487  Empire! Empire! (I Was A Lonely Estate)  artist
# 14266   a_2294                                    Braid  artist
# 14750  a_12499                              By Surprise  artist
# 14759   a_8460                                Footnotes  artist
#
#
# Community ID: 95
# Members count: 19
#         nodeID            name    type
# 4425    u_1890  Invalid prefix    user
# 10994   a_2713         Ноггано  artist
# 11263   a_9791        Смоки Мо  artist
# 13051  a_17426              ST  artist
# 13195  a_17432     Пост Мортем  artist
#
#
# Community ID: 96
# Members count: 19
#         nodeID               name    type
# 3037    u_1507     Invalid prefix    user
# 9968   a_15103  Delinquent Habits  artist
# 11498  a_15108    Control Machete  artist
# 11927  a_15115   The Psycho Realm  artist
# 12891  a_15107             Voltio  artist
#
#
# Community ID: 97
# Members count: 19
#         nodeID              name    type
# 2965    u_1440    Invalid prefix    user
# 7732   a_10460           LS Jack  artist
# 8713    a_3383      Victor e Leo  artist
# 9738   a_14569  Flávio Venturini  artist
# 11317   a_6706          Cassiane  artist
#
#
# Community ID: 98
# Members count: 19
#        nodeID               name    type
# 4875    u_148     Invalid prefix    user
# 11248  a_3351        Melt-Banana  artist
# 11963  a_3349   The Dead Milkmen  artist
# 12766  a_3361            Bearbot  artist
# 14609  a_3355  Ol' Dirty Bastard  artist
#
#
# Community ID: 99
# Members count: 19
#        nodeID             name    type
# 1816    u_420   Invalid prefix    user
# 9584   a_6710      Carly Simon  artist
# 12016  a_6715  Elaine De Jesus  artist
# 12059  a_6701     Cristina Mel  artist
# 12706  a_6718          Eyshila  artist
#
#
# Community ID: 100
# Members count: 19
#        nodeID                   name    type
# 3590    u_416         Invalid prefix    user
# 11684  a_3512               Coph Nia  artist
# 12666  a_6666          Deutsch Nepal  artist
# 12778  a_6673  Boyd Rice and Friends  artist
# 12779  a_6665       Der Blaue Reiter  artist
#
#
# Community ID: 101
# Members count: 19
#         nodeID                  name    type
# 1396    u_1047        Invalid prefix    user
# 11480  a_11987              Coalesce  artist
# 11579  a_11981                 Pg.99  artist
# 11984  a_11977               Cave In  artist
# 12481  a_11986  Combatwoundedveteran  artist
#
#
# Community ID: 102
# Members count: 19
#         nodeID            name    type
# 1686    u_2048  Invalid prefix    user
# 9230   a_18407     Rippingtons  artist
# 9416   a_18410      Paul Davis  artist
# 10072  a_18401       Trey Gunn  artist
# 10435  a_18397    Natalie Cole  artist
#
#
# Community ID: 103
# Members count: 19
#         nodeID            name    type
# 4340    u_1807  Invalid prefix    user
# 9994   a_16792        Kidcrash  artist
# 11858  a_16794      Mesa Verde  artist
# 14135  a_10449          Orchid  artist
# 14901  a_16797           Gantz  artist
#
#
# Community ID: 104
# Members count: 19
#         nodeID              name    type
# 4312    u_2035    Invalid prefix    user
# 10416  a_18346      Tom Verlaine  artist
# 11550  a_18339     Lee Hazlewood  artist
# 11978  a_13052      Julian Lynch  artist
# 12033  a_18350  Bridget St. John  artist
#
#
# Community ID: 105
# Members count: 18
#         nodeID            name    type
# 1639    u_1357  Invalid prefix    user
# 11157  a_14080     Irma Thomas  artist
# 11332   a_5627      Jerry Reed  artist
# 11454  a_14086    The Blasters  artist
# 11991  a_14088  Larry Williams  artist
#
#
# Community ID: 106
# Members count: 18
#         nodeID                   name    type
# 547     u_2036         Invalid prefix    user
# 9011    a_1136        Amadou & Mariam  artist
# 11640  a_15556        Cristina Branco  artist
# 13181  a_18358  Jacques Loussier Trio  artist
# 14472  a_10912        Balkan Beat Box  artist
#
#
# Community ID: 107
# Members count: 18
#         nodeID            name    type
# 4997    u_1030  Invalid prefix    user
# 9745    a_5101       Throwdown  artist
# 11199   a_2160          Maroon  artist
# 12829  a_11852       Frontside  artist
# 12950  a_11854     Sworn Enemy  artist
#
#
# Community ID: 108
# Members count: 18
#        nodeID                         name    type
# 2536    u_725               Invalid prefix    user
# 9905   a_9560  Lester Flatt & Earl Scruggs  artist
# 10644  a_7148                   John Barry  artist
# 11430  a_9550               Ahmed Bukhatir  artist
# 12339  a_9553               Sheila Chandra  artist
#
#
# Community ID: 109
# Members count: 18
#        nodeID                   name    type
# 4327    u_736         Invalid prefix    user
# 8205   a_9689  Israel Kamakawiwo'ole  artist
# 9971   a_3034                 K.I.Z.  artist
# 10004  a_8600              Nino Rota  artist
# 11326  a_5058                   Sido  artist
#
#
# Community ID: 110
# Members count: 18
#        nodeID                 name    type
# 4981    u_456       Invalid prefix    user
# 11150  a_7094  Jammil e uma Noites  artist
# 11803  a_7086                 Hori  artist
# 14380  a_7084  Hugo Pena & Gabriel  artist
# 14498  a_7083            Rapazolla  artist
#
#
# Community ID: 111
# Members count: 18
#        nodeID                      name    type
# 615    t_4046  italian progressive rock     tag
# 5404  a_14922                     Jumbo  artist
# 7361   a_3826                   Celeste  artist
# 8607  a_11636   Biglietto per l'Inferno  artist
# 8765  a_14946               Metamorfosi  artist
#
#
# Community ID: 112
# Members count: 18
#        nodeID               name    type
# 2327    u_181     Invalid prefix    user
# 8141   a_3834      Блондинка Ксю  artist
# 12260  a_3845  Михей и Джуманджи  artist
# 12937  a_3851              Настя  artist
# 12961  a_3831           Аквариум  artist
#
#
# Community ID: 113
# Members count: 18
#         nodeID                 name    type
# 2643     u_843       Invalid prefix    user
# 9740   a_10574         Jaya the Cat  artist
# 10968   a_8925     The Wonder Years  artist
# 12762  a_10573      All For Nothing  artist
# 13025  a_10581  All Or Nothing H.C.  artist
#
#
# Community ID: 114
# Members count: 18
#        nodeID                         name    type
# 4637    u_556               Invalid prefix    user
# 11558  a_6299             Freelance Whales  artist
# 12192  a_8030                  The Antlers  artist
# 14464  a_8038  Nicolaus Esterhazy Sinfonia  artist
# 14504  a_8028                      __MaX__  artist
#
#
# Community ID: 115
# Members count: 18
#         nodeID                       name    type
# 3301    u_2067             Invalid prefix    user
# 8657    a_4937     And Hell Followed With  artist
# 11709   a_9804         MyChildren MyBride  artist
# 11771  a_18533                 The Famine  artist
# 12102  a_15054  At the Throne of Judgment  artist
#
#
# Community ID: 116
# Members count: 18
#         nodeID              name    type
# 321     u_1625    Invalid prefix    user
# 9105   a_15678        F.R. David  artist
# 12413  a_15663   Claude François  artist
# 14343  a_10017  Michel Polnareff  artist
# 14519   a_4976  Claudio Baglioni  artist
#
#
# Community ID: 117
# Members count: 18
#        nodeID            name    type
# 1442    u_704  Invalid prefix    user
# 7505   a_2522          Shaggy  artist
# 8153   a_9387     Nancy Ajram  artist
# 10973  a_4983          Elissa  artist
# 13551  a_9391   Juelz Santana  artist
#
#
# Community ID: 118
# Members count: 18
#         nodeID             name    type
# 5318    u_1624   Invalid prefix    user
# 9509    a_5152  Fujiya & Miyagi  artist
# 10093  a_15659   She Keeps Bees  artist
# 10769  a_15649         Feldberg  artist
# 11014  a_15660  Bye Bye Bicycle  artist
#
#
# Community ID: 119
# Members count: 18
#         nodeID                  name    type
# 4733    u_1119        Invalid prefix    user
# 11289   a_7326                Plan B  artist
# 13477  a_12421               6.Cadde  artist
# 15046  a_12430        Şanışer & Bela  artist
# 15566  a_12424  Şanışer feat. Atakan  artist
#
#
# Community ID: 120
# Members count: 18
#         nodeID             name    type
# 5869    u_1193   Invalid prefix    user
# 11340  a_13023         The Bill  artist
# 13028  a_13026           Komety  artist
# 13531  a_13017          Habakuk  artist
# 14687  a_13025  Pięć Dwa Dębiec  artist
#
#
# Community ID: 121
# Members count: 18
#        nodeID              name    type
# 2695    u_752    Invalid prefix    user
# 11204  a_9796        Trash Talk  artist
# 12084  a_9795  A Loss For Words  artist
# 12795  a_9810       Lions Lions  artist
# 13076  a_9807     Man Overboard  artist
#
#
# Community ID: 122
# Members count: 18
#         nodeID            name    type
# 4507    u_1720  Invalid prefix    user
# 10928  a_13616       Integrity  artist
# 11725  a_16272        Outbreak  artist
# 11727  a_11850           Hoods  artist
# 11921  a_16260        Slapshot  artist
#
#
# Community ID: 123
# Members count: 17
#         nodeID            name    type
# 5694    u_1126  Invalid prefix    user
# 11902  a_12516          seis35  artist
# 14547  a_12523   Joyce & Ridge  artist
# 15267  a_12522          Jaimão  artist
# 16076  a_12521          4Taste  artist
#
#
# Community ID: 124
# Members count: 17
#        nodeID           name    type
# 100     t_120    world music     tag
# 6787  a_17339   Majid Bekkas  artist
# 7182  a_17340  Anouar Brahem  artist
# 7739  a_18454        Alabina  artist
# 8616  a_17336        Abdelli  artist
#
#
# Community ID: 125
# Members count: 17
#         nodeID                                 name    type
# 4033    u_1288                       Invalid prefix    user
# 11309   a_1972                               K'naan  artist
# 11525   a_5626  Joaquin Phoenix & Reese Witherspoon  artist
# 11568  a_13698                   The Wailin' Jennys  artist
# 11675  a_13690                        Jeremy Fisher  artist
#
#
# Community ID: 126
# Members count: 17
#         nodeID               name    type
# 2904    u_1618     Invalid prefix    user
# 11799  a_15597      Michael Brook  artist
# 12038  a_15600           Intermix  artist
# 14127  a_15599  Świetliki i Linda  artist
# 14481  a_10596       Poésie Noire  artist
#
#
# Community ID: 127
# Members count: 17
#        nodeID               name    type
# 4274    u_228     Invalid prefix    user
# 9274   a_4544       Gram Parsons  artist
# 11287  a_3145         King Tubby  artist
# 13097  a_4536  Hank Williams III  artist
# 14823  a_4518               JoMo  artist
#
#
# Community ID: 128
# Members count: 17
#        nodeID             name    type
# 3353    u_259   Invalid prefix    user
# 11898  a_4911          Ландыши  artist
# 14202  a_4893            Ассаи  artist
# 14384  a_4888  missis Garrison  artist
# 14492  a_4244          Loc-Dog  artist
#
#
# Community ID: 129
# Members count: 17
#        nodeID                name    type
# 5099    u_192      Invalid prefix    user
# 7161   a_3998             PMtoday  artist
# 7466   a_3999   The Contortionist  artist
# 7868   a_4011    Children of Nova  artist
# 10053  a_4000  Circle of Contempt  artist
#
#
# Community ID: 130
# Members count: 17
#         nodeID            name    type
# 5034    u_1861  Invalid prefix    user
# 8764    a_4107      Some Girls  artist
# 11744  a_17182          The Ex  artist
# 11806  a_17190       Hakim Bey  artist
# 11956  a_10674         Tragedy  artist
#
#
# Community ID: 131
# Members count: 17
#         nodeID                 name    type
# 4194    u_1386       Invalid prefix    user
# 8601    a_9056  Aziza Mustafa Zadeh  artist
# 10009  a_14256          Perry Blake  artist
# 11472   a_4548         Yasemin Mori  artist
# 12247  a_14257          Özlem Tekİn  artist
#
#
# Community ID: 132
# Members count: 17
#        nodeID            name    type
# 2862    u_645  Invalid prefix    user
# 7846   a_4711     Lizz Wright  artist
# 11280  a_8152    Jane Monheit  artist
# 11486  a_8847  Chiara Civello  artist
# 11831  a_8857  Silje Nergaard  artist
#
#
# Community ID: 133
# Members count: 17
#         nodeID                     name    type
# 3905    u_1724           Invalid prefix    user
# 10934  a_12674              Francis Lai  artist
# 13444  a_16350             Hess Is More  artist
# 14473   a_4913  Berliner Philharmoniker  artist
# 14496  a_13090            Dusty Fingers  artist
#
#
# Community ID: 134
# Members count: 17
#        nodeID             name    type
# 1960  a_11337  Мирбек Атабеков  artist
# 2404  a_11342            Urker  artist
# 2637   t_6352        world pop     tag
# 2723  a_11344           Muzart  artist
# 3022  a_11347           Elnare  artist
#
#
# Community ID: 135
# Members count: 17
#        nodeID                         name    type
# 5060    u_727               Invalid prefix    user
# 7024   a_9608  Justin Hinds & The Dominoes  artist
# 9499   a_9609               The Techniques  artist
# 11127  a_9611                Clancy Eccles  artist
# 11817  a_9613                     Skarface  artist
#
#
# Community ID: 136
# Members count: 17
#         nodeID             name    type
# 4440     u_996   Invalid prefix    user
# 11088  a_11683      Alirio Diaz  artist
# 11638  a_11678     Lester Young  artist
# 12256  a_11654  Joaquín Rodrigo  artist
# 13716  a_11669      Sonny Stitt  artist
#
#
# Community ID: 137
# Members count: 16
#       nodeID            name    type
# 4514     u_9  Invalid prefix    user
# 8905   a_404             백지영  artist
# 9098   a_381        C.N.BLUE  artist
# 9110   a_406            HYDE  artist
# 10861  a_401  RENTRER EN SOI  artist
#
#
# Community ID: 138
# Members count: 16
#         nodeID                 name    type
# 2496    u_1817       Invalid prefix    user
# 9569   a_16855                  CSS  artist
# 13482    a_894  Sneaky Sound System  artist
# 13539  a_16846                globe  artist
# 13624  a_11875                ravex  artist
#
#
# Community ID: 139
# Members count: 16
#        nodeID                   name    type
# 4828     u_82         Invalid prefix    user
# 9151   a_2291                No Kids  artist
# 9381   a_1139          Maurice Ravel  artist
# 11056  a_2282          Born Ruffians  artist
# 13550  a_2266  Kind of Like Spitting  artist
#
#
# Community ID: 140
# Members count: 16
#         nodeID               name    type
# 2815    u_1100     Invalid prefix    user
# 8595   a_12318  Grant Lee Buffalo  artist
# 12684  a_12323      Cop Shoot Cop  artist
# 13316  a_12329            Bedhead  artist
# 14539   a_4655             C.S.I.  artist
#
#
# Community ID: 141
# Members count: 16
#         nodeID            name    type
# 1973    u_1665  Invalid prefix    user
# 12270  a_15934      Billy Fury  artist
# 13321  a_13275            Kumm  artist
# 13930  a_15942        Arsenium  artist
# 14562   a_1586          Инь-Ян  artist
#
#
# Community ID: 142
# Members count: 16
#        nodeID                name    type
# 3809    u_807      Invalid prefix    user
# 8938   a_9105  Every Little Thing  artist
# 9675  a_10231             HALCALI  artist
# 9812   a_2095        Aira Mitsuki  artist
# 9873  a_10235               田村ゆかり  artist
#
#
# Community ID: 143
# Members count: 16
#        nodeID                         name    type
# 1607     u_80               Invalid prefix    user
# 10024  a_2205               Main-de-Gloire  artist
# 11800  a_2198        The Eyes Of A Traitor  artist
# 11923  a_2202  Dead Silence Hides My Cries  artist
# 12169  a_2194                 The Hysteria  artist
#
#
# Community ID: 144
# Members count: 16
#        nodeID            name    type
# 1691     u_92  Invalid prefix    user
# 11613  a_2502       Nightcore  artist
# 11852  a_2501        REDALiCE  artist
# 12130  a_2512          KOTOKO  artist
# 12448  a_2497           IOSYS  artist
#
#
# Community ID: 145
# Members count: 16
#        nodeID             name    type
# 5643    u_664   Invalid prefix    user
# 10944  a_9129  Cannabis Corpse  artist
# 13561  a_9124             Sole  artist
# 14218  a_8657          Buck 65  artist
# 14535  a_3785            Spazz  artist
#
#
# Community ID: 146
# Members count: 16
#         nodeID                    name    type
# 3079    u_1152          Invalid prefix    user
# 10814   a_7175                   志方あきこ  artist
# 11442  a_12709  Seven Percent Solution  artist
# 11760  a_12705               sleepy.ab  artist
# 12200  a_12713          Akira Kosemura  artist
#
#
# Community ID: 147
# Members count: 16
#        nodeID            name    type
# 593     u_726  Invalid prefix    user
# 11906  a_9569      Angela Aki  artist
# 12668  a_9577       Spin Aqua  artist
# 13039  a_9568           ayaka  artist
# 14315  a_5572             林俊傑  artist
#
#
# Community ID: 148
# Members count: 16
#        nodeID             name    type
# 1455    u_463   Invalid prefix    user
# 13395  a_7172             Enam  artist
# 14717  a_7159              崎元仁  artist
# 15035  a_7168          Na Fili  artist
# 15491  a_7162  Nature Ambience  artist
#
#
# Community ID: 149
# Members count: 16
#         nodeID               name    type
# 2110    u_1904     Invalid prefix    user
# 5789   a_17490  Melissa Etheridge  artist
# 9632   t_11903  angry chick music     tag
# 10260  a_17500        Lyle Lovett  artist
# 11667  a_17498       Shawn Colvin  artist
#
#
# Community ID: 150
# Members count: 16
#         nodeID                name    type
# 4810    u_1497      Invalid prefix    user
# 9500   a_14960           Bacamarte  artist
# 10958  a_14967  Samla Mammas Manna  artist
# 11275  a_14947          New Trolls  artist
# 11767  a_14962        Robert Wyatt  artist
#
#
# Community ID: 151
# Members count: 16
#         nodeID            name    type
# 2049    u_2091  Invalid prefix    user
# 11535  a_18642            Umek  artist
# 11660   a_9830  Ky-Mani Marley  artist
# 13410  a_18643        Kayamaré  artist
# 14381  a_12653  Grupo Tradição  artist
#
#
# Community ID: 152
# Members count: 16
#         nodeID            name    type
# 3854    u_1859  Invalid prefix    user
# 10044  a_17164         Jupiter  artist
# 10244  a_17161      Hot Feeler  artist
# 15106  a_17170          Kalson  artist
# 15269  a_17159      The Recoys  artist
#
#
# Community ID: 153
# Members count: 15
#         nodeID              name    type
# 3358    u_1467    Invalid prefix    user
# 5810     a_399                 嵐  artist
# 11580  a_11824  Styles of Beyond  artist
# 11680  a_12028     Apocalipse 16  artist
# 13582  a_14699          Salvador  artist
#
#
# Community ID: 154
# Members count: 15
#        nodeID             name    type
# 5630    u_484   Invalid prefix    user
# 10741  a_2193            Каста  artist
# 10877  a_3056  Ночные Снайперы  artist
# 12915  a_7370          Bugotak  artist
# 14487   a_480              Guf  artist
#
#
# Community ID: 155
# Members count: 15
#        nodeID            name    type
# 3929     u_76  Invalid prefix    user
# 9315   a_2093      Versailles  artist
# 9384   a_2113          heidi.  artist
# 11551  a_2115   Saori@destiny  artist
# 11714  a_1915          AYABIE  artist
#
#
# Community ID: 156
# Members count: 15
#       nodeID              name    type
# 830   t_1001          darkstep     tag
# 1918  t_1002          darkside     tag
# 4953  a_5063            Noisia  artist
# 5301  a_5069  Black Sun Empire  artist
# 5435  t_2480         neurofunk     tag
#
#
# Community ID: 157
# Members count: 15
#         nodeID                                               name    type
# 5286     u_960                                     Invalid prefix    user
# 10050  a_11402                                drake and lil wayne  artist
# 12652  a_11405                            Tom Boxer Feat. Antonia  artist
# 14690   a_2180  Marc Seales, composer. New Stories. Ernie Watt...  artist
# 14941  a_11403                                           Movetown  artist
#
#
# Community ID: 158
# Members count: 15
#         nodeID            name    type
# 4415    u_1976  Invalid prefix    user
# 8709    a_6960     Tony Gatlif  artist
# 8810    a_6951         Gevende  artist
# 10165  a_17978   Inti-Illimani  artist
# 12860   a_2307  Zülfü Livaneli  artist
#
#
# Community ID: 159
# Members count: 15
#        nodeID                       name    type
# 1680    u_742             Invalid prefix    user
# 10040  a_9724                  Anika Moa  artist
# 11347  a_9730  Benjamin Francis Leftwich  artist
# 11382  a_2376           Jenni Vartiainen  artist
# 11590  a_9720              Natacha Atlas  artist
#
#
# Community ID: 160
# Members count: 15
#         nodeID                name    type
# 5302     u_893      Invalid prefix    user
# 10964   a_5677              Massiv  artist
# 14406   a_9681          Kool Savas  artist
# 14587   a_5679            Marteria  artist
# 14704  a_10873  Nazar & Raf Camora  artist
#
#
# Community ID: 161
# Members count: 15
#        nodeID                  name    type
# 4781    u_180        Invalid prefix    user
# 10849  a_3812           The Qemists  artist
# 12207  a_3803           Wolfbrigade  artist
# 13408  a_3819  Abominable Putridity  artist
# 14697  a_3807         State of Mind  artist
#
#
# Community ID: 162
# Members count: 15
#         nodeID            name    type
# 2354    u_1697  Invalid prefix    user
# 8951   a_16103    Alpha Blondy  artist
# 10241   a_5850    Bunny Wailer  artist
# 10466   a_9833     Black Uhuru  artist
# 11890  a_16100     Mikey Dread  artist
#
#
# Community ID: 163
# Members count: 15
#         nodeID            name    type
# 3572    u_1044  Invalid prefix    user
# 9138    a_6098   George Carlin  artist
# 10367  a_11962      Lower Dens  artist
# 10908  a_11954    Lisa Germano  artist
# 11009  a_11966    Robert Fripp  artist
#
#
# Community ID: 164
# Members count: 15
#         nodeID            name    type
# 3682     u_993  Invalid prefix    user
# 11920  a_11627   Buried Inside  artist
# 13224  a_11616  United Nations  artist
# 13650  a_11610    L'Homme Puma  artist
# 13741  a_11615    Omega Massif  artist
#
#
# Community ID: 165
# Members count: 15
#        nodeID              name    type
# 6604    u_510    Invalid prefix    user
# ...
# 9890   a_8796   Juha Tapio  artist
# 13839  t_4590  finnish pop     tag
#
#
# Community ID: 403
# Members count: 2
#       nodeID                          name    type
# 6360  a_9046                          Visa  artist
# 6500  t_4758  progressive middle east folk     tag
#
#
# Community ID: 404
# Members count: 2
#       nodeID          name    type
# 6325  a_9057        MELIKE  artist
# 6514  t_4748  turkish folk     tag
#
#
# Community ID: 405
# Members count: 2
#       nodeID                       name    type
# 6220  a_9140   The Upper Egypt Ensemble  artist
# 6421  t_4794  traditional egyptian folk     tag
#
#
# Community ID: 406
# Members count: 2
#       nodeID        name    type
# 6068  a_9190    Dave Koz  artist
# 6464  t_1883  soap opera     tag
#
#
# Community ID: 407
# Members count: 2
#       nodeID                name    type
# 6247  a_9506       Ceramic Hello  artist
# 6423  t_5044  minimal electronic     tag
#
#
# Community ID: 408
# Members count: 2
#       nodeID           name    type
# 9513  a_9517     Inner Side  artist
# 9640  t_3411  amy winehouse     tag
#
#
# Community ID: 409
# Members count: 2
#        nodeID           name    type
# 9130   a_9552  Gustav Mahler  artist
# 13280  t_4616           1900     tag
#
#
# Community ID: 410
# Members count: 2
#         nodeID                                 name    type
# 10599   a_9625  Dr. Ring-Ding & The Senior Allstars  artist
# 14036  t_10520                     country: germany     tag
#
#
# Community ID: 411
# Members count: 2
#        nodeID                          name    type
# 7353   t_5741  the new wave of classic rock     tag
# 11160  a_9650                    Stone Gods  artist
#
#
# Community ID: 412
# Members count: 2
#        nodeID           name    type
# 7310   a_9671  Border Patrol  artist
# 11728  t_5190      ska metal     tag
#
#
# Community ID: 413
# Members count: 2
#       nodeID                 name    type
# 6150  a_9757  Наталья Могилевская  artist
# 6437  t_5236         mogilevskaya     tag
#
#
# Community ID: 414
# Members count: 2
#       nodeID          name    type
# 6225  a_9781        los ex  artist
# 6521  t_5247  chilean rock     tag
#
#
# Community ID: 415
# Members count: 2
#         nodeID            name    type
# 8663   a_10234  Yum!Yum!ORANGE  artist
# 10960   t_3934           j-ska     tag
#
#
# Community ID: 416
# Members count: 2
#         nodeID                       name    type
# 10719   t_5738               sleaze metal     tag
# 12075  a_10446  Addiction For Destruction  artist
#
#
# Community ID: 417
# Members count: 2
#         nodeID               name    type
# 8572   a_10464  Dub Incorporation  artist
# 14014   t_5745      french reggae     tag
#
#
# Community ID: 418
# Members count: 2
#        nodeID          name    type
# 6280  a_10490  The Joystick  artist
# 6503   t_5751    skate-punk     tag
#
#
# Community ID: 419
# Members count: 2
#         nodeID          name    type
# 5785   a_10571  Mustard Plug  artist
# 11669   t_6114      fun rock     tag
#
#
# Community ID: 420
# Members count: 2
#         nodeID                                       name    type
# 10298  a_10611                                Fang Island  artist
# 13808   t_5821  motherfuckin rabbits ejaculating sunshine     tag
#
#
# Community ID: 421
# Members count: 2
#         nodeID           name    type
# 9997   a_10758  The Carpettes  artist
# 10601   t_2079         punk77     tag
#
#
# Community ID: 422
# Members count: 2
#        nodeID               name    type
# 6198  a_10920  Scenes And Sirens  artist
# 6384   t_6081          salsa pop     tag
#
#
# Community ID: 423
# Members count: 2
#        nodeID         name    type
# 6403  a_10925          黃立行  artist
# 6502   t_6084  chinese pop     tag
#
#
# Community ID: 424
# Members count: 2
#        nodeID         name    type
# 6306  a_10935          서태지  artist
# 6475   t_6094  korean rock     tag
#
#
# Community ID: 425
# Members count: 2
#         nodeID                            name    type
# 10464   t_6144              panic at the disco     tag
# 12228  a_10985  Brendon Urie and Dresden Dolls  artist
#
#
# Community ID: 426
# Members count: 2
#         nodeID           name    type
# 9852    t_3521        pop emo     tag
# 12371  a_11553  The Movielife  artist
#
#
# Community ID: 427
# Members count: 2
#         nodeID               name    type
# 8486   a_11607      Pulling Teeth  artist
# 14109   t_6543  metallic hardcore     tag
#
#
# Community ID: 428
# Members count: 2
#        nodeID                name    type
# 6257  a_11799       Tyrone Andrew  artist
# 6482   t_6703  good christian rap     tag
#
#
# Community ID: 429
# Members count: 2
#        nodeID                      name    type
# 6283  a_11969                     Kable  artist
# 6534   t_6907  houston psychedelic rock     tag
#
#
# Community ID: 430
# Members count: 2
#        nodeID            name    type
# 6161  a_12050  La Vela Puerca  artist
# 6470   t_6983  latin ska punk     tag
#
#
# Community ID: 431
# Members count: 2
#         nodeID            name    type
# 8937    t_7271   not math rock     tag
# 11268  a_12375  Crime In Choir  artist
#
#
# Community ID: 432
# Members count: 2
#        nodeID       name    type
# 6387  a_12526  Ukurralle  artist
# 6489   t_7398  agrometal     tag
#
#
# Community ID: 433
# Members count: 2
#        nodeID            name    type
# 6233  a_12585              빅뱅  artist
# 6413   t_6088  korean hip hop     tag
#
#
# Community ID: 434
# Members count: 2
#        nodeID          name    type
# 6292  a_12600    Big Dipper  artist
# 6486   t_7470  earlie indie     tag
#
#
# Community ID: 435
# Members count: 2
#         nodeID              name    type
# 8874   a_12812  9GOATS BLACK OUT  artist
# 11982   t_7557     jrock kawaiii     tag
#
#
# Community ID: 436
# Members count: 2
#        nodeID                         name    type
# 6203  a_12832                 Parni Valjak  artist
# 6519   t_7592  best croatian pop-rock band     tag
#
#
# Community ID: 437
# Members count: 2
#         nodeID            name    type
# 8404    t_7596  inflight music     tag
# 13428  a_12878  abyssal plains  artist
#
#
# Community ID: 438
# Members count: 2
#        nodeID                  name    type
# 6373  a_12973              Babyland  artist
# 6461   t_7656  electronic junk punk     tag
#
#
# Community ID: 439
# Members count: 2
#         nodeID             name    type
# 8233   a_12975           16Volt  artist
# 10430  t_11248  dark industrial     tag
#
#
# Community ID: 440
# Members count: 2
#        nodeID           name    type
# 6297  a_13001  Mariage Blanc  artist
# 6507   t_7682        ringpop     tag
#
#
# Community ID: 441
# Members count: 2
#        nodeID      name    type
# 8697  a_13138    Ok que  artist
# 8842   t_5886  rock pop     tag
#
#
# Community ID: 442
# Members count: 2
#        nodeID                                               name    type
# 6230  a_13301                                                joa  artist
# 6483   t_7992  lapiz conciente vakero hip hop latino toxic cr...     tag
#
#
# Community ID: 443
# Members count: 2
#         nodeID           name    type
# 8873   a_13409       Cairokee  artist
# 11040   t_8043  oriental rock     tag
#
#
# Community ID: 444
# Members count: 2
#         nodeID       name    type
# 9385   a_13434    Пелагея  artist
# 12946   t_4309  etno rock     tag
#
#
# Community ID: 445
# Members count: 2
#         nodeID       name    type
# 9198   a_13510     Kurban  artist
# 11645  t_10409  turk rock     tag
#
#
# Community ID: 446
# Members count: 2
#        nodeID         name    type
# 6235  a_10729        Gotye  artist
# 6451   t_8192  aussie rock     tag
#
#
# Community ID: 447
# Members count: 2
#         nodeID                   name    type
# 5959     t_264        90s pop espanol     tag
# 11522  a_13666  Los Fresones Rebeldes  artist
#
#
# Community ID: 448
# Members count: 2
#        nodeID                      name    type
# 6296  a_13689             James Murdoch  artist
# 6463   t_8372  great pop with real soul     tag
#
#
# Community ID: 449
# Members count: 2
#        nodeID        name    type
# 9628   t_8801    art-rock     tag
# 9844  a_13999  Heartscore  artist
#
#
# Community ID: 450
# Members count: 2
#         nodeID         name    type
# 8605    t_8867   cello rock     tag
# 11013  a_14063  Cellofourte  artist
#
#
# Community ID: 451
# Members count: 2
#         nodeID                          name    type
# 7169   a_14075  The Radio R.A.T. Misery Hour  artist
# 12324   t_8878                 pre-war blues     tag
#
#
# Community ID: 452
# Members count: 2
#        nodeID                                       name    type
# 6441  a_14209              Broadcast and The Focus Group  artist
# 6466   t_3355  sound collage psychedelia electronic folk     tag
#
#
# Community ID: 453
# Members count: 2
#        nodeID            name    type
# 6352  a_14219  Aselin Debison  artist
# 6457   t_8982      celtic pop     tag
#
#
# Community ID: 454
# Members count: 2
#         nodeID          name    type
# 7943   a_14227  Venom Knight  artist
# 10690   t_8987      nerd rap     tag
#
#
# Community ID: 455
# Members count: 2
#         nodeID                   name    type
# 7863    t_3379            wizard rock     tag
# 11907  a_14315  Draco and the Malfoys  artist
#
#
# Community ID: 456
# Members count: 2
#        nodeID            name    type
# 6085  a_14489    The Ace Cats  artist
# 6527   t_9214  neo-rockabilly     tag
#
#
# Community ID: 457
# Members count: 2
#        nodeID       name    type
# 6222  a_14542     Zahara  artist
# 6477   t_9279  chica pop     tag
#
#
# Community ID: 458
# Members count: 2
#        nodeID                   name    type
# 6252  a_14641    Kids in the Kitchen  artist
# 6443   t_1183  aussie pop dance band     tag
#
#
# Community ID: 459
# Members count: 2
#         nodeID                   name    type
# 10561  a_14667     The Hidden Cameras  artist
# 13868  t_11813  gay church folk music     tag
#
#
# Community ID: 460
# Members count: 2
#         nodeID                        name    type
# 10754   t_9496  my favorite hip hop artist     tag
# 13862  a_14734                        Tyga  artist
#
#
# Community ID: 461
# Members count: 2
#         nodeID                name    type
# 9387   a_14765  Alexander Kowalski  artist
# 10475   t_7277                9000     tag
#
#
# Community ID: 462
# Members count: 2
#         nodeID               name    type
# 8875   a_14911     Prawe Skrzydło  artist
# 11436   t_9619  rock patriotyczny     tag
#
#
# Community ID: 463
# Members count: 2
#         nodeID                    name    type
# 10725  a_14987  RICHARD DIXON-COMPOSER  artist
# 13768   t_9658         christian blues     tag
#
#
# Community ID: 464
# Members count: 2
#        nodeID            name    type
# 6140  a_15114      Chyno Nyno  artist
# 6517   t_9707  hip-hop latino     tag
#
#
# Community ID: 465
# Members count: 2
#        nodeID            name    type
# 6398  a_15463        DEPAPEPE  artist
# 6469   t_9991  j-pop acoustic     tag
#
#
# Community ID: 466
# Members count: 2
#         nodeID             name    type
# 10147  a_15668  Ricchi e Poveri  artist
# 10492   t_9356      italo-disco     tag
#
#
# Community ID: 467
# Members count: 2
#         nodeID                                  name    type
# 7085   a_15948                               Ранетки  artist
# 11573   t_6241  slamming guttural brutal death metal     tag
#
#
# Community ID: 468
# Members count: 2
#        nodeID                     name    type
# 6265  a_16006                    KODLA  artist
# 6473   t_4477  russian underground rap     tag
#
#
# Community ID: 469
# Members count: 2
#         nodeID        name    type
# 9898   a_16027        Kreş  artist
# 13377  t_10461  disco rock     tag
#
#
# Community ID: 470
# Members count: 2
#        nodeID     name    type
# 6156  a_16060  Osborne  artist
# 6434  t_11482  popping     tag
#
#
# Community ID: 471
# Members count: 2
#         nodeID              name    type
# 6713    a_9843   Barrington Levy  artist
# 13533  t_10508  country: jamaica     tag
#
#
# Community ID: 472
# Members count: 2
#         nodeID           name    type
# 6205   a_16186     Егор Летов  artist
# 11748   t_9463  siberian punk     tag
#
#
# Community ID: 473
# Members count: 2
#        nodeID        name    type
# 6248  a_16257  Battleship  artist
# 6472  t_10668    neo punk     tag
#
#
# Community ID: 474
# Members count: 2
#         nodeID       name    type
# 8719   a_16270   Medicine  artist
# 11562   t_7520  noise-pop     tag
#
#
# Community ID: 475
# Members count: 2
#         nodeID            name    type
# 8666   a_16277            Jets  artist
# 11179   t_5123  neo rockabilly     tag
#
#
# Community ID: 476
# Members count: 2
#        nodeID                 name    type
# 6175  a_16288            ブルー・エンジェル  artist
# 6417  t_10678  japanese rockabilly     tag
#
#
# Community ID: 477
# Members count: 2
#        nodeID                   name    type
# 6298  a_16305          Billy Wallace  artist
# 6479   t_9224  louisiana rock n roll     tag
#
#
# Community ID: 478
# Members count: 2
#         nodeID               name    type
# 10195  a_16418         The Trucks  artist
# 13559  t_10811  girl electro rock     tag
#
#
# Community ID: 479
# Members count: 2
#         nodeID                           name    type
# 9045    t_4264                   blues fusion     tag
# 11206  a_16650  John Lee Hooker & Miles Davis  artist
#
#
# Community ID: 480
# Members count: 2
#        nodeID          name    type
# 6375  a_16772         Mulan  artist
# 6407   t_4410  anarchy punk     tag
#
#
# Community ID: 481
# Members count: 2
#        nodeID                         name    type
# 6288  a_16787  The Time Travelling Pirates  artist
# 6478  t_11134              a crock of crap     tag
#
#
# Community ID: 482
# Members count: 2
#        nodeID        name    type
# 6371  a_16866    The Rebs  artist
# 6525  t_11182  melody pop     tag
#
#
# Community ID: 483
# Members count: 2
#        nodeID          name    type
# 6244  a_17093        Kisses  artist
# 6488  t_11371  balearic pop     tag
#
#
# Community ID: 484
# Members count: 2
#        nodeID                              name    type
# 6340  a_17149                       Ryan's Hope  artist
# 6465  t_11402  the best punk rock album of 2006     tag
#
#
# Community ID: 485
# Members count: 2
#         nodeID             name    type
# 9722    t_9962  real indie rock     tag
# 13050  a_17307          Mineral  artist
#
#
# Community ID: 486
# Members count: 2
#        nodeID       name    type
# 9344   t_6849  spacerock     tag
# 9579  a_17324  Autodrone  artist
#
#
# Community ID: 487
# Members count: 2
#         nodeID      name    type
# 9914   t_11632  drumfunk     tag
# 11801  a_17412    Alaska  artist
#
#
# Community ID: 488
# Members count: 2
#        nodeID             name    type
# 6372  a_17534          Mordida  artist
# 6516  t_11660  indie jazz rock     tag
#
#
# Community ID: 489
# Members count: 2
#        nodeID                    name    type
# 6217  a_17535            Rosie and Me  artist
# 6462  t_11661  indie folk acustic art     tag
#
#
# Community ID: 490
# Members count: 2
#        nodeID            name    type
# 6229  a_17536  Wander Wildner  artist
# 6481   t_8652     gremio rock     tag
#
#
# Community ID: 491
# Members count: 2
#        nodeID         name    type
# 6313  a_17622  Silent Hill  artist
# 6532   t_8984     darkness     tag
#
#
# Community ID: 492
# Members count: 2
#         nodeID           name    type
# 10365  a_17797           松尾清憲  artist
# 13882  t_11839  evergreen pop     tag
#
#
# Community ID: 493
# Members count: 2
#         nodeID                 name    type
# 5640   t_11937           synth-punk     tag
# 13116  a_15551  Help She Can't Swim  artist
#
#
# Community ID: 494
# Members count: 2
#        nodeID                       name    type
# 6393  a_17994  Abhaya & the Steam Injuns  artist
# 6491  t_12068           nepali rock band     tag
#
#
# Community ID: 495
# Members count: 2
#         nodeID          name    type
# 8714   a_18260  Gorump Peyya  artist
# 10184   t_9806      dark psy     tag
#
#
# Community ID: 496
# Members count: 2
#         nodeID             name    type
# 10302  a_18308  Μύρωνας Στρατής  artist
# 14037    t_295       greek rock     tag
#
#
# Community ID: 497
# Members count: 2
#        nodeID                    name    type
# 6167  a_18547           The Crucified  artist
# 6505  t_12528  crossover thrash metal     tag
#
#
# Community ID: 498
# Members count: 2
#        nodeID            name    type
# 2453   u_2085  Invalid prefix    user
# 5208  a_18615           YEFFI  artist
#
#
# Community ID: 499
# Members count: 2
#         nodeID                  name    type
# 8681   a_18632  Bloody Dead and Sexy  artist
# 10891  t_12627     batcave deathrock     tag
#
#
# Community ID: 500
# Members count: 2
#        nodeID               name    type
# 6268  a_18639       Brain Police  artist
# 6496   t_5408  stoner power rock     tag

# %% [markdown]
# We can also get generate a summary table that lists each community ID along with the counts of tags, artists, and users in each community.

# %%
community_summary_louvain = node_df_louvain.groupby('communityID')['type'].value_counts().unstack(fill_value=0)

# Calculate the total number of entities in each community
community_summary_louvain['total_entities'] = community_summary_louvain.sum(axis=1)

# Reset the index to turn the index into a column
community_summary_louvain.reset_index(inplace=True)

# Display the summary table
community_summary_louvain
# Out:
# type  communityID  artist  tag  user  total_entities
# 0               0    3968  426   589            4983
# 1               1    3210  261   186            3657
# 2               2    2446  443   261            3150
# 3               3    2254  257   537            3048
# 4               4     742   97    86             925
# ..            ...     ...  ...   ...             ...
# 496           496       1    1     0               2
# 497           497       1    1     0               2
# 498           498       1    0     1               2
# 499           499       1    1     0               2
# 500           500       1    1     0               2
#
# [501 rows x 5 columns]

# %% [markdown]
# #### Community Sizes
#
# If we want to explore how the Louvain conducted its partitions, we can also review the sizes of the communities by:
# - Normal histogram showing distirbution of size amongst communities, however, this isn't too clear.
# - Box Plot could show where the majhority of communities exist in terms of size, and whether there are many outliers.
# - A closer look at the 20 largest communities gives us an idea of their size.
# - Pie Chart with a categorization of communities in small, medium and large.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate the size of each community
community_sizes_louvain = node_df_louvain.groupby('communityID').size()

# Plot a histogram
plt.figure(figsize=(12, 6))
plt.hist(community_sizes_louvain, bins=50, alpha=0.75)
plt.title('Histogram of Community Sizes')
plt.xlabel('Community Size')
plt.ylabel('Number of Communities')
plt.grid(True)
plt.show()

# Plot a boxplot
plt.figure(figsize=(8, 6))
plt.boxplot(community_sizes_louvain, vert=False)
plt.title('Box Plot of Community Sizes')
plt.xlabel('Community Size')
plt.show()

# Plot sizes of the top N communities
top_n = 20
top_communities = community_sizes_louvain.nlargest(top_n).sort_values()
top_communities.plot(kind='barh', figsize=(10, 8))
plt.title(f'Top {top_n} Largest Communities')
plt.xlabel('Number of Nodes')
plt.ylabel('Community ID')
plt.show()

# Plot pie chart
def categorize_size(x):
    if x <= 10:
        return 'Small (<=10)'
    elif x <= 100:
        return 'Medium (11-100)'
    else:
        return 'Large (>100)'

size_categories = community_sizes_louvain.apply(categorize_size).value_counts()

size_categories.plot(kind='pie', autopct='%1.1f%%', startangle=140, figsize=(8, 8))
plt.title('Community Size Categories')
plt.ylabel('')  # Hide the y-label as it's not informative for a pie chart
plt.show()

# %% [markdown]
# #### Community Content Analysis
#
# In order to determine if the separation of entities into communities actually makes sense, we need to look at the internal components of communities.

# %%
community = node_df_louvain[node_df_louvain['communityID'] == 5]
# Count the occurrence of each type within the community
print(community['type'].value_counts())
# List all unique tags or artists within the community
print("Unique tags:", community[community['type'] == 'tag']['name'].unique())
print("Unique artists:", community[community['type'] == 'artist']['name'].unique())
# Out:
# type
# artist    326
# tag        33
# user       15
# Name: count, dtype: int64
# Unique tags: ['rap' 'hip hop' 'gangsta rap' 'hip hop/rap' 'east coast rap'
#  'alternative hip-hop' 'hardcore rap' 'west coast rap' 'deutschrap'
#  'classic rap' 'funkalistic' 'old school hip hop' 'south rap' 'german rap'
#  'best of hip hop' 'like rick ghraphixxx' 'best rapper alive'
#  'funkalistik' 'german hip hop' 'my favourite rappers' 'white rap'
#  'new york rap' 'hip hop classic' 'epitome of hip hop' 'chillil'
#  'black rap' 'deutsch rap' 'lithuanian hip hop' 'punchlinerap'
#  'best rapper ever' 'gansta rap' 'real rap' 'ultimate crap']
# Unique artists: ['Nas' 'The Roots' '2Pac' 'Talib Kweli' 'Busta Rhymes' 'Vanilla Ice'
#  'Dr. Dre' 'Mos Def' 'Wu-Tang Clan' 'Ice Cube' 'Notorious B.I.G.'
#  '50 Cent' 'Raekwon' 'The Streets' 'Public Enemy' 'N.W.A' 'Fort Minor'
#  'DMX' 'Mobb Deep' 'Snoop Dogg' 'Xzibit' 'Common' 'Ghostface Killah'
#  'The Game' 'Rick GhraphiXxX' 'Azad' 'Andre 3000' 'Ludacris'
#  'Bone Thugs-N-Harmony' 'Sonny Black & Frank White' 'Fugees' 'Gang Starr'
#  'Bizarre' 'Too $hort' 'D12' 'Lloyd Banks' 'Lupe Fiasco' 'Tech N9ne'
#  'Royce da 5\'9"' 'Method Man' 'Eazy-E' 'Pharrell' 'Run-D.M.C.'
#  'ConeCrewDiretoria' 'JAW' 'Aesop Rock' 'Black Star' 'New Boyz'
#  'Atmosphere' 'GZA/Genius' 'Little Brother' 'T-Pain'
#  'Favorite & Hollywood Hank' 'Chamillionaire' 'Jedi Mind Tricks'
#  'Fabolous' 'Ao Cubo' 'Obie Trice' 'Clipse' 'Method Man & Redman' 'AZ'
#  'Beanie Sigel' 'Joe Budden' 'Timbaland & Magoo' 'Wale' 'Termanology'
#  'A-Team' 'LL Cool J' 'Kurtis Blow' 'Three 6 Mafia' 'P. Diddy' 'Styles P'
#  'Meth, Ghost & Rae' 'Will Smith' 'Warren G' 'Naughty by Nature' 'Redman'
#  'Fugative' 'Ja Rule' 'Lisa "Left Eye" Lopes' 'Papoose' '$lick' 'Proof'
#  'TERIYAKI BOYZ' 'Gabriel o Pensador' 'Senser' 'Nate57' 'Pezet/Małolat'
#  'Lil Mama' 'Lyrics Born' 'Farid Bang' 'Big L' 'Freddie Jackson'
#  'Mc Dexnyz' 'Fat Joe' 'WC' 'Big Punisher' 'Marcelo D2' 'Young Jeezy'
#  'Jay Electronica' 'Chakuza' 'Cuban Link' 'Flora Matos' 'MellowHype'
#  'Shawnna' 'WWE' 'RIP SLYME' 'G-Unit' 'Freeway' 'Masta Killa' 'Twista'
#  'Asher Roth' 'Haftbefehl' 'Jurassic 5' 'Nyze' "Tha' Rayne" 'EMICIDA'
#  'Young Buck' 'Hush' 'Taktloss' 'Kardinal Offishall' 'Citizen Cope'
#  'Kool G Rap' 'Case' 'D-Bo' 'k-os' 'Stat Quo' 'Montell Jordan' 'Eyedea'
#  'Trina' 'Saad' "Lil' Kim" 'Westside Connection' 'Chingy' 'DJ Vandan'
#  'Michael Jackson & Paul McCartney' 'Eric B. & Rakim' 'Tua' 'Gravediggaz'
#  'Separate' 'Bizzy Bone' 'Cassidy' 'Necro' '徐懷鈺' 'Six-Fo feat. $lick'
#  'M.O.P.' 'Fler' 'Mase' 'Cast of Camp Rock 2' 'Sean Price' 'XBXRX'
#  'Nu Jerzey Devil' 'Vanich (Military Clan)' 'Re-Up Gang' 'Kollegah'
#  'Petey Pablo' 'Khia' 'Ms. Jade' 'Kottonmouth Kings' 'N-Dubz' 'EPMD'
#  'Master Tempo' 'Maino' 'Pretty Ricky' 'DJ 600V' 'Eldo'
#  'One Day as a Lion' 'The Diplomats' 'Plies' 'Young Money' 'RZA'
#  'Slim Thug' 'Pharoahe Monch' 'Fisz Emade jako Tworzywo Sztuczne'
#  "Lil' Scrappy" 'Twiztid' 'Cartel De Santa' 'Ya Boy' 'Mario Winans'
#  'Tony Yayo' 'Bizzy Montana' 'Onyx' 'Hell Razah' 'Black Violin'
#  'Crooked I' 'Bilal' 'Pezet' 'Sway' 'Rakim' 'T-Raperzy znad Wisły'
#  'Lil Jon & The East Side Boyz' "Cam'ron" "Fat Freddy's Drop" 'Cashis'
#  'Fettes Brot' 'Terror Squad' 'Zion I' 'Die Fantastischen Vier' 'O.C.'
#  'J. Cole' 'Jacki-O' 'Reks' 'Mystikal' 'PIH' 'Guilty Simpson' 'Chrishan'
#  'The LOX' 'Peja' 'Eminem ft. Xzibit & Nate Dogg' 'Children of the Corn'
#  'The Alchemist' 'Havoc' 'Gucci Mane' 'KMD' 'Lyfe Jennings' 'Jadakiss'
#  'DJ Risk One' 'Rhymefest' 'Ten Typ Mes' 'Saigon' 'Skee-Lo' 'Fokus'
#  'Rick Ross' 'Afroman' 'Memphis Bleek' 'J.R. Writer' 'Montana Tucker'
#  'Jean Grae' 'YoungBloodZ' 'Favorite' 'Stavento' 'Slick Rick'
#  '8Ball & MJG' 'Tower of Rome' 'The Fartz' 'dead prez' 'Brother Ali'
#  'Birdman' 'Evidence' "Lil' Flip" 'Canibus' 'Mac Miller' 'HiFi Banda'
#  'DonGURALesko' 'Nate Dogg' 'HollywoodsFinest' 'Jay Dee' 'Trick Trick'
#  'Bliss n Eso' 'Junior Caldera' 'Fred Hammond' 'Trav' 'Cormega'
#  'Reflection Eternal' 'Waldemar Kasta' 'DonGURALesko & Matheo' 'Blaq Poet'
#  'E-40' 'Joell Ortiz' '213' 'Rychu Peja SoLUfka' 'Zion I & The Grouch'
#  'The Coup' '50 Cent, Eminem, Ca$his & Lloyd Banks'
#  'Invisibl Skratch Piklz' 'Main Source' 'Stack Bundles'
#  'Juelz Santana & Lil Wayne' '40 Glocc' 'Ras Kass' 'Tha Realest'
#  'Borysewicz-Kukiz' 'CPU' 'Large Professor' 'Инна Steel и Михей'
#  'Celo & Abdi' 'Automatikk' 'DJ Messiah, 50 Cent And Eminem'
#  'DonGURALesko & Dj Kostek' 'WWO' 'Rinkadink' 'Fashawn' 'Pill' 'XSI'
#  'Eminem & Royce Da 5\'9"' 'Tede' 'Nipsey Hussle' 'DJ Whoo Kid' 'KRS-One'
#  'Menog' 'Cool Calm Pete' 'Godsilla' 'Bun B' 'Snaga & Pillath'
#  'Rock of Heltah Skeltah' 'Sonny Black & Saad' 'UniKKatiL'
#  'Marco Polo & Ruste Juxx' '9th Wonder & Buckshot' 'maritza rodriguez'
#  'Benzino' 'JAW und Hollywood Hank' 'MC Lyte' 'A-Alikes' 'Snaga Und Fard'
#  'Spider Loc' 'Uncle Murda' 'Warheit' 'DJ Premier' 'Eko Fresh'
#  'DJ Whoo Kid & Tony Yayo' 'Black&Mouse' 'Big Syke' 'Smoke DZA'
#  'Aries Spears' 'Telly Tellz' 'Bass Sultan Hengzt' 'Slums Attack'
#  'Ali Vegas' 'Berlins Most Wanted' 'Dubfire' 'Frank White und Godsilla'
#  'Rap P' 'KRS-One & Marley Marl' 'Xeg' 'Jehst']

# %% [markdown]
# We can also look at the distribution of tags across communities, and whether there is a coherent thematic difference between communities. This is partial evidence for a successful detection of community structures.

# %%
# Filter out the tag-type nodes
tags_df_louvain = node_df_louvain[node_df_louvain['type'] == 'tag'].copy()

# Group by communityID and tag name, then count occurrences
tag_counts_by_community_louvain = tags_df_louvain.groupby(['communityID', 'name']).size().reset_index(name='count')

# Sort the results within each community by count, descending
tag_counts_by_community_sorted_louvain = tag_counts_by_community_louvain.sort_values(by=['communityID', 'count'], ascending=[True, False])

tag_counts_by_community_sorted_louvain
# Out:
#       communityID                                    name  count
# 0               0                                00s rock      1
# 1               0                            80s hardcore      1
# 2               0  80s songs not actually made in the 80s      1
# 3               0                               80s y 90s      1
# 4               0                                   90210      1
# ...           ...                                     ...    ...
# 1989          495                                dark psy      1
# 1990          496                              greek rock      1
# 1991          497                  crossover thrash metal      1
# 1992          499                       batcave deathrock      1
# 1993          500                       stoner power rock      1
#
# [1994 rows x 3 columns]

# %% [markdown]
# We ensure that we select 5 random communities that have at least 1 tag each, otherwise the visualization would not be complete. We look at the top tags in each of those communities to determine whether there are distinctions made.

# %%
# For each community, select the top N tags to analyze
top_n = 5
top_tags_by_community_louvain = tag_counts_by_community_sorted_louvain.groupby('communityID').head(top_n)

# Set a seed for reproducibility
np.random.seed(999)

# Identify communities with at least one tag
communities_with_tags_louvain = tags_df_louvain['communityID'].unique()

# Check if we have at least 5 such communities
if len(communities_with_tags_louvain) >= 5:
    # Randomly select 5 communities that have at least one tag
    selected_communities = np.random.choice(communities_with_tags_louvain, 5, replace=False)
else:
    # If there are not enough communities with tags, just take what's available
    selected_communities = communities_with_tags_louvain

# Filter the top tags for these selected communities
selected_top_tags = top_tags_by_community_louvain[top_tags_by_community_louvain['communityID'].isin(selected_communities)]

import seaborn as sns

# Plot the top tags for the selected communities
plt.figure(figsize=(15, 10))
sns.barplot(x='count', y='name', hue='communityID', data=selected_top_tags, dodge=False)
plt.title('Top Tags in 5 Randomly Selected Communities With Tags')
plt.xlabel('Frequency')
plt.ylabel('Tags')
plt.legend(title='Community ID', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Assuming 'selected_top_tags' contains the top tags for the selected communities
# Each tag is unique to a community, so we will visualize the presence of tags within communities

# Create a new figure and axis
plt.figure(figsize=(15, 10))
ax = plt.subplot()

# Get unique communities and tags for plotting
unique_communities_louvain = selected_top_tags['communityID'].unique()
unique_tags_louvain = selected_top_tags['name'].unique()

# Create a categorical plot
# For each community, we'll plot a line at y=1
for community in unique_communities_louvain:
    # Get the tags for this community
    community_tags = selected_top_tags[selected_top_tags['communityID'] == community]['name']
    # Plot each tag with a dot on the line
    ax.plot(community_tags, [community] * len(community_tags), 'o', label=f'Community {community}', linestyle='')

# Improve the plot aesthetics
ax.set_yticks(unique_communities_louvain)
ax.set_yticklabels([f'Community {id}' for id in unique_communities_louvain])
ax.set_ylabel('Communities')
ax.set_xlabel('Tags')
plt.title('Presence of Tags in Selected Communities')
plt.legend()
plt.grid(True)
plt.xticks(rotation=90)  # Rotate x-axis labels to avoid overlap
plt.tight_layout()  # Adjust the padding between and around subplots

# Show the plot
plt.show()

# %%
# Get the first 5 community IDs
first_5_communities = sorted(tags_df['communityID'].unique())[6:25]

# Filter tags from these communities
first_5_tags = tags_df[tags_df['communityID'].isin(first_5_communities)]

# Create a categorical plot to show the tags for each of the first 5 communities
plt.figure(figsize=(15, 10))
ax = plt.subplot()

# Plotting
for community in first_5_communities:
    # Get the tags for this community
    community_tags = first_5_tags[first_5_tags['communityID'] == community]['name']
    # Plot each tag with a dot on the line
    ax.plot(community_tags, [community] * len(community_tags), 'o', label=f'Community {community}', linestyle='')

# Improve the plot aesthetics
ax.set_yticks(first_5_communities)
ax.set_yticklabels([f'Community {id}' for id in first_5_communities])
ax.set_ylabel('Communities')
ax.set_xlabel('Tags')
plt.title('Tags in 5 Communities')
plt.legend()
plt.grid(True)
plt.xticks(rotation=90)  # Rotate x-axis labels to avoid overlap
plt.tight_layout()  # Adjust the padding between and around subplots

# Show the plot
plt.show()

# %%
# Categorize each community by the number of tags it contains
counts = node_df_louvain[node_df_louvain['type'] == 'tag']['communityID'].value_counts()

# Define categories
no_tags = (counts == 0).sum()
one_tag = (counts == 1).sum()
less_than_ten_tags = ((counts > 1) & (counts < 10)).sum()
ten_or_more_tags = (counts >= 10).sum()

# Make sure to include communities with no tags
total_communities = node_df_louvain['communityID'].nunique()
no_tags = total_communities - len(counts)

# Prepare data for the pie chart
categories = ['No Tags', '1 Tag', '2-9 Tags', '10+ Tags']
sizes = [no_tags, one_tag, less_than_ten_tags, ten_or_more_tags]

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=categories, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Tags Across Communities')
plt.show()

# %% [markdown]
# ### **For Leiden**

# %% [markdown]
# #### Overview of Community Data
#
# First, we aggregate the data by community ID to get an overview of each community's composition. We group our DataFrame by the community ID and then examine the types and names within each community.

# %%
# Group by community ID and list out members of each community
community_groups = node_df_leiden.groupby('communityID')

# Example to print out the composition of each community
for community_id, group in community_groups:
    print(f"Community ID: {community_id}")
    print(f"Members count: {len(group)}")
    print(group[['nodeID', 'name', 'type']].head())  # Adjust as needed
    print("\n")
# Out:
# Community ID: 0
# Members count: 4153
#   nodeID              name type
# 0   t_73              rock  tag
# 2   t_79       alternative  tag
# 4   t_81             indie  tag
# 6   t_78  alternative rock  tag
# 7   t_25               80s  tag
#
#
# Community ID: 1
# Members count: 3853
#    nodeID          name type
# 3    t_18    electronic  tag
# 5    t_33  experimental  tag
# 9    t_14       ambient  tag
# 11  t_187   electronica  tag
# 12   t_13      chillout  tag
#
#
# Community ID: 2
# Members count: 2928
#    nodeID         name type
# 15  t_181         punk  tag
# 29  t_182    punk rock  tag
# 32  t_376    metalcore  tag
# 47  t_169     pop punk  tag
# 63   t_56  melancholic  tag
#
#
# Community ID: 3
# Members count: 2861
#    nodeID        name    type
# 1    t_24         pop     tag
# 23  t_109    pop rock     tag
# 48  t_512    romantic     tag
# 55  t_199  electropop     tag
# 78   a_67     Madonna  artist
#
#
# Community ID: 4
# Members count: 2649
#    nodeID              name type
# 17  t_192      classic rock  tag
# 19   t_83              jazz  tag
# 20  t_735               70s  tag
# 21  t_625              soul  tag
# 25  t_387  progressive rock  tag
#
#
# Community ID: 5
# Members count: 2498
#    nodeID               name type
# 14    t_1              metal  tag
# 16   t_72          hard rock  tag
# 26  t_386        heavy metal  tag
# 38   t_76  progressive metal  tag
# 40    t_5        death metal  tag
#
#
# Community ID: 6
# Members count: 1221
#     nodeID         name type
# 22   t_103          rap  tag
# 34   t_304      hip hop  tag
# 56   t_311       reggae  tag
# 75   t_265          ska  tag
# 204  t_197  gangsta rap  tag
#
#
# Community ID: 7
# Members count: 594
#       nodeID             name type
# 46     t_308            latin  tag
# 133    t_356        latin pop  tag
# 378  t_12639    winds of soul  tag
# 756    t_728  rock en espanol  tag
# 766   t_8116     turkish rock  tag
#
#
# Community ID: 8
# Members count: 531
#      nodeID    name type
# 67    t_140   j-pop  tag
# 113   t_139  j-rock  tag
# 213   t_164   k-pop  tag
# 246  t_1316    jpop  tag
# 270  t_1219   jrock  tag
#
#
# Community ID: 9
# Members count: 100
#      nodeID         name    type
# 218  t_1955         90's     tag
# 357   t_124    pop dance     tag
# 491  t_1973  house music     tag
# 661  t_1969    dance 90s     tag
# 778  a_1081  Ace of Base  artist
#
#
# Community ID: 10
# Members count: 50
#        nodeID            name    type
# 185     t_297        pop-rock     tag
# 1365   a_4609      Brainstorm  artist
# 1658   t_1628     russian pop     tag
# 1669  t_10393  indie-romantic     tag
# 2360  t_10394        rock-pop     tag
#
#
# Community ID: 11
# Members count: 48
#         nodeID                    name    type
# 6553    u_1499          Invalid prefix    user
# 10725  a_14987  RICHARD DIXON-COMPOSER  artist
# 13768   t_9658         christian blues     tag
# 16075  a_14992                Big Stuf  artist
# 16867  a_15002        Joel Rosenberger  artist
#
#
# Community ID: 12
# Members count: 20
#         nodeID                                               name    type
# 2135   a_13100                            Honeybird & the Birdies  artist
# 4795    u_1205                                     Invalid prefix    user
# 10750   t_7813                                           antifolk     tag
# 13668   t_7829                                           rocketta     tag
# 13687   t_6028  people who are freakier and folkier than mothe...     tag
#
#
# Community ID: 13
# Members count: 5
#        nodeID          name    type
# 6253   a_3348     KESSENCHU  artist
# 12580  t_1623   gabber punk     tag
# 12732  t_1624  digital-punk     tag
# 12804  t_1618   techno punk     tag
# 13548  t_1617    cyber-punk     tag
#
#
# Community ID: 14
# Members count: 4
#        nodeID                                 name    type
# 5722   a_9154                        Rafael Wanyer  artist
# 11093  t_4800                nx zero pop rock novo     tag
# 12186  t_4797                              passado     tag
# 12713  t_4801  pop rock cover pop dance identidade     tag
#
#
# Community ID: 15
# Members count: 3
#       nodeID                                       name    type
# 6266  a_5904                                Hearts Fail  artist
# 9734  t_2961  post-punk new wave goth alternative indie     tag
# 9990  t_2960                        post-punk post punk     tag

# %% [markdown]
# We can also get generate a summary table that lists each community ID along with the counts of tags, artists, and users in each community.

# %%
community_summary_leiden = node_df_leiden.groupby('communityID')['type'].value_counts().unstack(fill_value=0)

# Calculate the total number of entities in each community
community_summary_leiden['total_entities'] = community_summary_leiden.sum(axis=1)

# Reset the index to turn the index into a column
community_summary_leiden.reset_index(inplace=True)

# Display the summary table
community_summary_leiden
# Out:
# type  communityID  artist  tag  user  total_entities
# 0               0    3339  380   434            4153
# 1               1    3423  264   166            3853
# 2               2    2374  241   313            2928
# 3               3    2104  211   546            2861
# 4               4    2230  291   128            2649
# 5               5    1924  365   209            2498
# 6               6    1072   99    50            1221
# 7               7     519   56    19             594
# 8               8     465   44    22             531
# 9               9      88   10     2             100
# 10             10      35   14     1              50
# 11             11      46    1     1              48
# 12             12      10    9     1              20
# 13             13       1    4     0               5
# 14             14       1    3     0               4
# 15             15       1    2     0               3

# %% [markdown]
# #### Community Sizes
#
# If we want to explore how the Louvain conducted its partitions, we can also review the sizes of the communities by:
# - Normal histogram showing distirbution of size amongst communities, however, this isn't too clear.
# - Box Plot could show where the majhority of communities exist in terms of size, and whether there are many outliers.
# - A closer look at the 20 largest communities gives us an idea of their size.
# - Pie Chart with a categorization of communities in small, medium and large.

# %%
# Calculate the size of each community
community_sizes_leiden = node_df_leiden.groupby('communityID').size()

# Plot a histogram
plt.figure(figsize=(12, 6))
plt.hist(community_sizes_leiden, bins=50, alpha=0.75)
plt.title('Histogram of Community Sizes')
plt.xlabel('Community Size')
plt.ylabel('Number of Communities')
plt.grid(True)
plt.show()

# Plot a boxplot
plt.figure(figsize=(8, 6))
plt.boxplot(community_sizes_leiden, vert=False)
plt.title('Box Plot of Community Sizes')
plt.xlabel('Community Size')
plt.show()

# Plot sizes of the top N communities
top_n = 20
top_communities = community_sizes_leiden.nlargest(top_n).sort_values()
top_communities.plot(kind='barh', figsize=(10, 8))
plt.title(f'Top {top_n} Largest Communities')
plt.xlabel('Number of Nodes')
plt.ylabel('Community ID')
plt.show()

# Plot pie chart
def categorize_size(x):
    if x <= 10:
        return 'Small (<=10)'
    elif x <= 100:
        return 'Medium (11-100)'
    else:
        return 'Large (>100)'

size_categories = community_sizes_leiden.apply(categorize_size).value_counts()

size_categories.plot(kind='pie', autopct='%1.1f%%', startangle=140, figsize=(8, 8))
plt.title('Community Size Categories')
plt.ylabel('')  # Hide the y-label as it's not informative for a pie chart
plt.show()

# %% [markdown]
# #### Specific Community Analysis

# %%
community = node_df_louvain[node_df_leiden['communityID'] == 8]
# Count the occurrence of each type within the community
print(community['type'].value_counts())
# List all unique tags or artists within the community
print("Unique tags:", community[community['type'] == 'tag']['name'].unique())
print("Unique artists:", community[community['type'] == 'artist']['name'].unique())
# Out:
# type
# artist    465
# tag        44
# user       22
# Name: count, dtype: int64
# Unique tags: ['j-pop' 'j-rock' 'k-pop' 'jpop' 'jrock' 'kpop' 'japanese pop'
#  'french pop' 'asian pop' 'jpop favorites' 'j-punk' 'j rock' 'korean rock'
#  'chinese pop' 'japanese rock' 'wizard rock' 'melodic hard rock' 'hk-pop'
#  'k-hip hop' 'rap eletronic' 'japanese trance' 'k-rap'
#  'electronic - trance - psytrance'
#  'j-pop japanese pop jpop female vocalists jazz japanese music j-rock'
#  'j rock plastic tree' 'c-pop' 'korean pop' 'j-ska'
#  'shinee ringdingdong kpop ring ding ding k-pop' 'mysterious'
#  'jrock kawaiii'
#  'j-pop japanese jpop pop female vocalists japan japanese music asian'
#  'j-pop japanese jpop pop anime japan hip-hop female vocalists'
#  'este disco me hace sentir un orgasmo'
#  'j-pop japanese jpop pop anime j-rock female vocalists japanese music'
#  'j rock indie' 'jap rap' 'rock japanese' 'j  rock' 'rock steady baby'
#  'cpop' 'mixture rock' 'alternative hip hop' 'henrylaurocks']
# Unique artists: ['安室奈美恵' '浜崎あゆみ' '宇多田ヒカル' 'ASIAN KUNG-FU GENERATION' 'YUI' '大塚愛' 'モーニング娘。'
#  'DIR EN GREY' 'Olivia' 'HIGH and MIGHTY COLOR' '椎名林檎' 'Perfume'
#  '[unknown]' '王菲' '中島美嘉' '天野月子' 'Capsule' 'Nightmare' '川田まみ'
#  'Brown Eyed Girls' '東京事変' 'Alice Nine' '安倍なつみ' '雅-MIYAVI-' 'the GazettE'
#  "D'espairsRay" 'Buono!' 'Berryz工房' '嵐' '梶浦由記' 'けちゃっぷmania' 'Erika' '鈴木あみ'
#  'Sailor Moon' 'Moi dix Mois' '서태지' '平井堅' 'Ketchup Mania' '黃立行' 'f(x)'
#  "L'Arc~en~Ciel" 'Polysics' '玉置成実' '松浦亜弥' 'BIG BANG' 'Do As Infinity'
#  'U-KISS' 'MC 몽' 'GD&TOP' 'メロン記念日' 'Super Junior' 'S.M. THE BALLAD' 'Kara'
#  '℃-ute' 'Flow' 'Rie fu' '동방신기' '矢井田瞳' 'GACKT' 'MC Sniper' 'LM.C' '2PM'
#  'Miz' 'Aural Vampire' 'ギルガメッシュ' 'm-flo' 'Tommy february6' 'exist†trace'
#  'Crystal Kay' '아이비' '비' '승리' 'Plastic Tree' '남녀공학' 'Najoua Belyzel' '현아'
#  '12012' '後藤真希' 'ViViD' 'TERIYAKI BOYZ' '883' '北出菜奈' '茅原実里' '絢香' 'Alan'
#  'Dragon Ash' 'Orange Caramel' 'UVERworld' 'B2ST' 'Christophe Willem'
#  'T.M.Revolution' '羅志祥' 'Tommy heavenly6' 'Yum!Yum!ORANGE' '李玟'
#  'Wonder Girls' 'アンティック-珈琲店-' 'RIP SLYME' '9GOATS BLACK OUT' 'Sowelu'
#  'Tigarah' '백지영' 'Every Little Thing' 'SE7EN' '가인' 'C.N.BLUE' 'HYDE'
#  'DELUHI' 'Nek' "OLIVIA inspi' REIRA (TRAPNEST)" 'Dark Schneider' '샤이니'
#  '배치기' 'After School' 'Versailles' 'LUNA SEA' 'heidi.'
#  'Hazel Nuts Chocolate' 'Zero Assoluto' 'BONNIE PINK' '藤本美貴' 'immi'
#  'KAT-TUN' '相川七瀬' 'CSS' 'Superbus' 'Alain Souchon' 'SS501' 'NEWS'
#  'HALCALI' 'ORANGE RANGE' 'Aira Mitsuki' 'ムック' '田村ゆかり' 'hide' 'YUKI'
#  'Arash' '福原美穂' '水樹奈々' 'Grégory Lemarchal' 'Gothika' '中澤裕子'
#  'abingdon boys school' 'Celtas Cortos' 'MALICE MIZER' 'Janne Da Arc'
#  '栗林みな実' '東方神起' 'hitomi' 'sifow' 'ZE:A' 'An Cafe' '이수영(여)' 'BeForU' '植松伸夫'
#  "ANNA TSUCHIYA inspi' NANA (BLACK STONES)" '平野綾' 'Sadie' 'K' 'ポルノグラフィティ'
#  '윤하' '美勇伝' 'See-Saw' '志方あきこ' 'RENTRER EN SOI' '島みやえい子' 'HAKUEI' 'misono'
#  'ルルティア' 'Kalafina' 'ヴァルナ' '蔡依林' 'アヲイ' 'Anna Tsuchiya' 'Move' 'UnsraW'
#  'Clazziquai Project' 'Lucio Battisti' 'ギルティア' 'キャンゼル' 'Rain'
#  'Saori@destiny' '坂本真綾' 'S.E.S.' 'day after tomorrow' 'BUCK-TICK'
#  'Suemitsu & THE Suemith' 'JYJ' 'AYABIE' 'Yuna Ito' 'FREENOTE'
#  'Edvin Marton' 'access' 'Suara' '樹海' 'Angela Aki' 'Draco and the Malfoys'
#  'AAA' 'Megaromania' 'Dio - Distraught Overlord' 'KOTOKO' 'Davut Güloğlu'
#  '福井舞' '木村カエラ' 'Mink' '山下智久' 'KICK THE CAN CREW' 'KOKIA' 'IOSYS' 'w-inds.'
#  'Aluto' 'TOKIO' 'Lorie' 'stonecollar' '高橋瞳' '손담비' '奥井雅美' '清春' 'Spin Aqua'
#  'KinKi Kids' '林原めぐみ' 'lynch.' 'Nega' 'Heather Dale' 'Chantal Goya'
#  'トゥーン工場' 'ayaka' 'Arashi' 'Ikimono-Gakari' 'Naomi Yohani' '分島花音'
#  'DREAMS COME TRUE' '少女-ロリヰタ-23区' 'Kaya' 'Enam' 'ALI PROJECT' '2AM'
#  'Sneaky Sound System' 'モンゴル800' 'キャナァーリ倶楽部' 'globe' 'ZARD' 'ravex'
#  '月島きらり starring 久住小春(モーニング娘。)' 'ケツメイシ' 'SADS' 'LOVE PSYCHEDELICO'
#  'Mr.Children' 'VIDOLL' 'Sweetbox' 'やなわらばー' '下村陽子' 'いきものがかり' '浜渦正志' '有澤孝紀'
#  '光田康典' '林俊傑' 'オレスカバンド' 'Epik High' '鬼束ちひろ' '-OZ-' 'SuG' '孫燕姿' 'リア・ディゾン'
#  '倉木麻衣' 'Nic Endo' 'Phantasmagoria' 'スピッツ' 'SUGIZO' '妖精帝國' '崎元仁' 'Twinkle'
#  'The Chorus (Les Choristes)' 'THE KIDDIE' '土屋アンナ' 'El Hombre Gancho'
#  'ＬｕＬｕ' 'Mindless Faith' 'ダリ' 'Paffendorf' 'Na Fili' 'ATC'
#  'Hironosuke Satou' '송지은' 'ハロー！プロジェクト' 'V6' 'Julma-Henri & Syrjäytyneet'
#  'SCREW' 'ステレオポニー' '4Tops & KAT-TUN'
#  'Royal Stockholm Philharmonic Orchestra' 'B2K' 'Yo-Yo Ma' '青山テルマ'
#  'Satou Rina & Inoue Marina & Chihara Minori' 'Initial D'
#  'Nature Ambience' 'AmIEvil' 'SoulJa' 'Final Fantasy (Soundtracks)'
#  'Tha Blue Herb' 'HINOIチーム' 'YOU THE ROCK★' '伊藤由奈' 'Alize' 'Nature Sounds'
#  'Lia' 'Envus' 'AKB48' 'Niccolò Paganini' '3mmey' 'OreSkaBand'
#  'PENICILLIN' 'AI' 'ｂｏｒｎ' 'Ikuta Toma & Yabu Kota' 'V-last.' 'スガシカオ' '彩音'
#  'Nano' 'MISIA' 'IU' 'サディ' 'ＰＥＲＥＳＴＲＯＩＫＡ' 'ケミカルピクチャーズ' 'Salyu' 'アンジェラ・アキ'
#  '笹川美和' '詩月カオリ' 'Banana Girl' 'TRAX' 'Lycaon'
#  'Junya Nakano, Masashi Hamauzu & Nobuo Uematsu' 'Jackie Chan & Kim' 'HΛL'
#  'Hora' 'W & Whale' 'Untouchable' '浜口史郎' 'YOSHIKI' 'Dil Se'
#  'Administrator' '湯川潮音' 'as.milk' 'D' 'Remi Bandali' 'Pupa' 'Briskeby'
#  'And' 'auncia' 'GARNET CROW' 'Luzmelt' 'Cocco' '彩菜' 'Matenrou Opera'
#  'ＶａｎｅｓｓＡ' '菅野祐悟' 'Lc5' 'DJ OZMA' 'Spider-Man 2' 'Lee Holdridge'
#  'Noel Quinlan' 'Jay Park' '신화' 'Duel Jewel' 'Rhymester' '摩天楼オペラ' '平原綾香'
#  'amber gris' 'Ikuta Toma & KAT-TUN' 'The Rescues' '劉德華' 'マキシマム ザ ホルモン'
#  'Nature Sound Collection' 'Hey! Say! JUMP' '姫神' '氷室京介' 'GIRL NEXT DOOR'
#  'FictionJunction YUUKA' 'Mr.' '3Tops' 'YA-KYIM' '夏川りみ' '西野カナ'
#  'Vanilla Unity' 'ハートレス' 'Ella Fitzgerald & Louis Armstrong' 'Paco Bello'
#  'Maverick' '佐藤ひろ美' 'angela' '米倉千尋' '河野伸' '坂本美雨' 'ブローディア' 'Ikuta Toma'
#  'Aqua Timez' 'KCO' 'school food punishment' 'Asriel' 'Wasted Land'
#  'Loveholic' 'www.DjFahad.com' "Cristina D'Avena" 'Puukko-Allu' 'Afshin'
#  '4TOPS' 'トクマルシューゴ' 'Wicked' 'moumoon' 'Jin-Roh' 'Laith Al-Deen'
#  'DaizyStripper' '石川智晶' 'ダウナー' 'Chinese mix' 'ダリス' 'Xhelazz' 'Dear Bitch'
#  '아웃사이더' '岡本玲' '張震嶽' '박정현' 'ゾロ' '有里知花' '工藤静香' 'Macaco' '椎名林檎×斎藤ネコ'
#  'Yoshitaka Hirota, Yasunori Mitsuda' 'ｂｏｏｇｉｅｍａｎ' '闇の末裔' 'Mina/심지환/최지호'
#  'Doping Panda' 'UNLIMITS' 'ｍａｃｈｉｎｅ' '元ちとせ' 'Fede Comin y Fran Fernandez'
#  '堀江由衣' 'Mario Galaxy Orchestra' 'Chuck Jonkey'
#  'Yamashita Tomohisa & Ikuta Toma' '김종국' 'Sweet Vacation' 'ＭＡＮＮＥＱＵＩＮ'
#  '王力宏' '平成維新' '愛狂います。' 'Newsies' '이수영(여);' '¹Ì³ª' 'Doug Carroll'
#  'Radioactivo' 'Hi:BRiD' 'DOGinTheパラレルワールドオーケストラ' 'The LEGENDARY SIX NINE'
#  'ＲＥＤ' 'Acoustic Cafe' 'Bishoujo Senshi' 'dragon ball z' 'Motoo Fujiwara'
#  'BAELSCOPE' 'アンデット' '下川みくに' 'Lemon Room Project' 'Wise']

# %% [markdown]
# We can also look at the distribution of tags across communities, and whether there is a coherent thematic difference between communities. This is partial evidence for a successful detection of community structures.

# %%
# Filter out the tag-type nodes
tags_df_leiden = node_df_leiden[node_df_leiden['type'] == 'tag'].copy()

# Group by communityID and tag name, then count occurrences
tag_counts_by_community_leiden = tags_df.groupby(['communityID', 'name']).size().reset_index(name='count')

# Sort the results within each community by count, descending
tag_counts_by_community_sorted_leiden = tag_counts_by_community_leiden.sort_values(by=['communityID', 'count'], ascending=[True, False])

tag_counts_by_community_sorted_leiden
# Out:
#       communityID                                    name  count
# 0               0                                00s rock      1
# 1               0                            80s hardcore      1
# 2               0  80s songs not actually made in the 80s      1
# 3               0                               80s y 90s      1
# 4               0                                   90210      1
# ...           ...                                     ...    ...
# 1989          495                                dark psy      1
# 1990          496                              greek rock      1
# 1991          497                  crossover thrash metal      1
# 1992          499                       batcave deathrock      1
# 1993          500                       stoner power rock      1
#
# [1994 rows x 3 columns]

# %%
# For each community, select the top N tags to analyze
top_n = 5
top_tags_by_community_leiden = tag_counts_by_community_sorted_leiden.groupby('communityID').head(top_n)

# Set a seed for reproducibility
np.random.seed(999)

# Identify communities with at least one tag
communities_with_tags_leiden = tags_df_leiden['communityID'].unique()

# Check if we have at least 5 such communities
if len(communities_with_tags_leiden) >= 5:
    # Randomly select 5 communities that have at least one tag
    selected_communities_leiden = np.random.choice(communities_with_tags_leiden, 5, replace=False)
else:
    # If there are not enough communities with tags, just take what's available
    selected_communities_leiden = communities_with_tags_leiden

# Filter the top tags for these selected communities
selected_top_tags_leiden = top_tags_by_community_leiden[top_tags_by_community_leiden['communityID'].isin(selected_communities_leiden)]

import seaborn as sns

# Plot the top tags for the selected communities
plt.figure(figsize=(15, 10))
sns.barplot(x='count', y='name', hue='communityID', data=selected_top_tags_leiden, dodge=False)
plt.title('Top Tags in 5 Randomly Selected Communities With Tags')
plt.xlabel('Frequency')
plt.ylabel('Tags')
plt.legend(title='Community ID', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Assuming 'selected_top_tags' contains the top tags for the selected communities
# Each tag is unique to a community, so we will visualize the presence of tags within communities

# Create a new figure and axis
plt.figure(figsize=(15, 10))
ax = plt.subplot()

# Get unique communities and tags for plotting
unique_communities_leiden = selected_top_tags_leiden['communityID'].unique()
unique_tags_leiden = selected_top_tags_leiden['name'].unique()

# Create a categorical plot
# For each community, we'll plot a line at y=1
for community in unique_communities_leiden:
    # Get the tags for this community
    community_tags = selected_top_tags[selected_top_tags_leiden['communityID'] == community]['name']
    # Plot each tag with a dot on the line
    ax.plot(community_tags, [community] * len(community_tags), 'o', label=f'Community {community}', linestyle='')

# Improve the plot aesthetics
ax.set_yticks(unique_communities_leiden)
ax.set_yticklabels([f'Community {id}' for id in unique_communities_leiden])
ax.set_ylabel('Communities')
ax.set_xlabel('Tags')
plt.title('Presence of Tags in Selected Communities')
plt.legend()
plt.grid(True)
plt.xticks(rotation=90)  # Rotate x-axis labels to avoid overlap
plt.tight_layout()  # Adjust the padding between and around subplots

# Show the plot
plt.show()

# %%
# Get the first 5 community IDs
first_5_communities = sorted(tags_df_leiden['communityID'].unique())[9:15]

# Filter tags from these communities
first_5_tags = tags_df_leiden[tags_df_leiden['communityID'].isin(first_5_communities)]

# Create a categorical plot to show the tags for each of the first 5 communities
plt.figure(figsize=(15, 10))
ax = plt.subplot()

# Plotting
for community in first_5_communities:
    # Get the tags for this community
    community_tags = first_5_tags[first_5_tags['communityID'] == community]['name']
    # Plot each tag with a dot on the line
    ax.plot(community_tags, [community] * len(community_tags), 'o', label=f'Community {community}', linestyle='')

# Improve the plot aesthetics
ax.set_yticks(first_5_communities)
ax.set_yticklabels([f'Community {id}' for id in first_5_communities])
ax.set_ylabel('Communities')
ax.set_xlabel('Tags')
plt.title('Tags in 5 Communities')
plt.legend()
plt.grid(True)
plt.xticks(rotation=90)  # Rotate x-axis labels to avoid overlap
plt.tight_layout()  # Adjust the padding between and around subplots

# Show the plot
plt.show()

# %%
# Categorize each community by the number of tags it contains
counts = node_df_leiden[node_df_leiden['type'] == 'tag']['communityID'].value_counts()

# Define categories
no_tags = (counts == 0).sum()
one_tag = (counts == 1).sum()
less_than_ten_tags = ((counts > 1) & (counts < 10)).sum()
ten_or_more_tags = (counts >= 10).sum()

# Make sure to include communities with no tags
total_communities = node_df_leiden['communityID'].nunique()
no_tags = total_communities - len(counts)

# Prepare data for the pie chart
categories = ['No Tags', '1 Tag', '2-9 Tags', '10+ Tags']
sizes = [no_tags, one_tag, less_than_ten_tags, ten_or_more_tags]

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=categories, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Tags Across Communities')
plt.show()
