# %% [markdown]
# ## Visualization for JUST Embeddings using t-SNE
#
# We will import the .embeddings file generated by running JUST, and we project the 128-dimensional vectors down to 2 dimensions using the [t-SNE](http://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html) algorithm.

# %% [markdown]
# ### Step 1: Loading from .embedding files into Pandas Dataframes
#
# Pandas DataFrames are tables of data that can be created from [many input sources](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html), such as [CSV files](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) and [SQL databases](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_sql.html).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# File path
embeddings_file = 'JUST_Outputs/lastfm.embeddings'

# Initialize lists to store node indexes and embeddings
node_indexes = []
embeddings = []

# Process the embeddings file
with open(embeddings_file, 'r') as file:
    for line in file:
        parts = line.split(maxsplit=1)
        node_indexes.append(parts[0])
        embeddings.append([float(val) for val in parts[1].split()])

# Convert embeddings to DataFrame
embeddings_df = pd.DataFrame(embeddings)

# Assign a new index to the DataFrame
embeddings_df.index = range(1, len(embeddings_df) + 1)

# Check the first few rows of the DataFrame
print(embeddings_df.head())

embeddings_df.shape

#Remove first element from node_indexes list
node_indexes.pop(0)

print(node_indexes) 

#Extract node_indexes list and save as .txt file
# Path where the updated list will be saved
output_file_path = "JUST_Outputs/node_indexes.txt"

# Write the updated list to a file, each node index on a new line
with open(output_file_path, "w") as file:
    for node_index in node_indexes:
        file.write(f"{node_index}\n")
# Out:
#           0         1         2         3         4         5         6    \
# 1  128.000000       NaN       NaN       NaN       NaN       NaN       NaN
# 2   -0.268324  0.141691  0.971436  0.348922  0.287573  0.640673  1.052779
# 3   -0.290419  0.160172  1.008188  0.340387  0.314301  0.647436  1.088299
# 4   -0.273399  0.129781  0.947435  0.348366  0.303420  0.634279  1.021371
# 5   -0.272619  0.138470  0.979513  0.353874  0.282447  0.636980  1.064016
#
#         7         8         9    ...       118       119       120       121  \
# 1       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 2  0.318871 -0.323992  1.118473  ...  1.664275  0.088501 -0.236643 -0.975985
# 3  0.313804 -0.303957  1.143632  ...  1.681908  0.105923 -0.242556 -0.983798
# 4  0.308203 -0.290688  1.068174  ...  1.614935  0.077580 -0.243821 -0.923067
# 5  0.318275 -0.288842  1.113455  ...  1.637067  0.101625 -0.237792 -0.960264
#
#         122       123       124       125       126       127
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2 -0.104974 -0.155675 -0.022122  0.397242 -1.146176 -0.042564
# 3 -0.108789 -0.148499 -0.004750  0.408538 -1.182146 -0.052888
# 4 -0.091465 -0.155652 -0.013521  0.383262 -1.120166 -0.075994
# 5 -0.105029 -0.156502 -0.000799  0.407506 -1.141540 -0.053185
#
# [5 rows x 128 columns]
# ['t_24', 't_73', 't_18', 't_81', 't_79', 't_33', 't_292', 't_14', 't_78', 't_84', 't_103', 't_13', 't_25', 't_187', 't_181', 't_352', 't_83', 't_1', 't_376', 't_625', 't_72', 't_296', 't_304', 't_545', 't_387', 't_109', 't_74', 't_192', 't_386', 't_182', 't_735', 't_105', 't_87', 't_5', 't_829', 't_193', 't_311', 't_76', 't_275', 't_247', 't_570', 't_85', 't_90', 't_839', 't_140', 't_308', 't_91', 't_169', 't_4', 't_565', 't_385', 't_389', 't_575', 't_724', 't_826', 't_512', 't_712', 't_574', 't_265', 't_615', 't_393', 't_199', 't_23', 't_120', 't_17', 't_139', 't_836', 't_742', 't_7', 't_1076', 't_6', 't_177', 't_190', 't_183', 't_1354', 't_825', 't_445', 't_203', 't_600', 't_253', 't_56', 't_1222', 't_249', 't_108', 't_164', 't_82', 't_626', 't_327', 't_349', 't_89', 't_242', 't_70', 't_1316', 't_189', 't_4449', 't_821', 't_170', 't_233', 't_75', 't_1249', 't_1627', 't_7938', 't_1219', 't_356', 't_12639', 't_2', 't_202', 't_1096', 't_1538', 't_564', 't_2141', 't_2140', 't_9817', 't_6628', 't_197', 't_8505', 't_2115', 't_4046', 't_743', 'u_1543', 't_1365', 't_1534', 't_9823', 't_6162', 't_1247', 'u_78', 't_2064', 't_2215', 't_7937', 't_848', 't_1640', 'a_289', 't_3507', 't_2244', 't_617', 'a_89', 't_1859', 't_1812', 't_4430', 't_297', 't_3555', 't_145', 't_2191', 't_1198', 't_6645', 't_1210', 't_528', 't_2525', 't_4258', 't_1286', 'u_1281', 't_3586', 'u_1210', 't_588', 't_1372', 't_1455', 't_1079', 't_22', 'a_288', 'u_1258', 't_1734', 't_8116', 't_160', 't_1767', 't_1358', 't_124', 't_757', 't_509', 't_612', 't_2021', 'a_333', 't_6383', 't_19', 't_543', 'a_701', 't_513', 't_80', 't_738', 't_537', 'a_300', 't_505', 'u_831', 't_1074', 't_1351', 't_42', 't_6164', 'a_295', 't_9430', 'a_227', 't_5939', 'a_154', 't_5329', 't_2887', 't_12642', 't_8310', 'a_55', 't_842', 'a_67', 't_394', 't_1593', 't_8052', 'a_292', 't_2458', 'a_498', 't_1796', 't_1684', 't_3925', 'u_298', 't_3829', 't_1955', 't_1634', 't_619', 't_546', 't_9825', 't_2809', 't_723', 'u_1488', 't_1025', 'a_349', 't_198', 't_1017', 't_12220', 't_728', 't_395', 't_683', 't_9427', 't_7040', 't_2272', 't_6824', 't_1682', 't_1001', 't_1251', 'u_143', 't_414', 'a_65', 'u_1213', 'a_466', 'u_1597', 't_1554', 't_1973', 'a_306', 'u_1087', 't_8501', 't_7256', 't_5009', 't_9433', 't_9429', 't_10259', 'a_302', 't_2938', 't_1843', 't_2192', 't_4530', 'u_1625', 'u_545', 'a_72', 't_1322', 't_978', 't_8499', 't_1181', 't_9203', 'a_157', 't_4340', 't_344', 'a_461', 'u_1869', 'a_229', 't_279', 'a_190', 't_5632', 't_8500', 'a_291', 'u_142', 'u_1130', 't_792', 't_261', 'a_377', 't_10581', 'u_212', 't_2197', 'a_378', 'u_236', 't_9829', 't_7286', 'u_390', 't_9491', 'u_1568', 't_2196', 'u_1478', 'u_1956', 'u_1785', 't_4116', 't_2199', 't_1091', 'u_1023', 't_2534', 't_6980', 't_3937', 'u_405', 'a_298', 'u_1773', 't_1486', 't_2091', 't_907', 'u_179', 'u_1342', 'u_1249', 'u_1102', 't_1373', 'a_234', 'u_2061', 't_734', 'u_621', 'a_173', 'a_679', 'a_299', 't_3706', 't_2087', 't_7474', 't_1387', 'u_1503', 'a_903', 't_1469', 't_2204', 'u_1670', 'a_163', 'u_2037', 't_1987', 'u_749', 't_3708', 'u_2068', 'a_228', 'a_207', 'a_230', 'u_941', 'u_1230', 't_1359', 't_104', 'u_1145', 'a_344', 'u_1801', 'a_486', 'u_593', 't_8502', 'u_232', 'u_1895', 't_1951', 'a_464', 'u_691', 'u_310', 't_542', 'a_198', 'a_1412', 't_2609', 'u_1709', 'u_1660', 'u_1662', 'u_1132', 't_3310', 'u_1308', 't_4523', 'u_851', 'u_859', 't_1628', 'u_128', 't_2056', 'u_514', 'u_1905', 't_756', 'u_46', 't_6486', 'u_1300', 'u_1069', 'u_1642', 't_6105', 't_624', 't_12267', 't_196', 'u_339', 'u_198', 't_1870', 'a_707', 't_8106', 'u_723', 't_1653', 'u_343', 't_977', 'u_655', 'a_735', 'u_2039', 'u_1789', 'u_59', 't_1834', 'a_511', 't_1532', 'u_355', 'a_917', 'u_2018', 't_2530', 'u_2042', 'u_481', 't_3930', 'u_1164', 'a_599', 't_2195', 't_9972', 'a_441', 'u_1253', 't_891', 'u_1761', 'u_1343', 'a_318', 't_8414', 'a_220', 'u_730', 'u_2020', 't_3364', 't_12549', 'u_1690', 't_3844', 'u_162', 't_6806', 't_7346', 't_1737', 'u_211', 't_9262', 'a_972', ...

# %%
# Assuming 'embeddings_df' is your DataFrame
# Drop the first row
embeddings_df = embeddings_df.drop(1)

# Reset the DataFrame index
embeddings_df.reset_index(drop=True, inplace=True)

# Now 'embeddings_df' is ready for further analysis
print(embeddings_df.head())

embeddings_df.shape
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.268324  0.141691  0.971436  0.348922  0.287573  0.640673  1.052779
# 1 -0.290419  0.160172  1.008188  0.340387  0.314301  0.647436  1.088299
# 2 -0.273399  0.129781  0.947435  0.348366  0.303420  0.634279  1.021371
# 3 -0.272619  0.138470  0.979513  0.353874  0.282447  0.636980  1.064016
# 4 -0.291217  0.160274  1.003322  0.347430  0.313924  0.650415  1.085262
#
#         7         8         9    ...       118       119       120       121  \
# 0  0.318871 -0.323992  1.118473  ...  1.664275  0.088501 -0.236643 -0.975985
# 1  0.313804 -0.303957  1.143632  ...  1.681908  0.105923 -0.242556 -0.983798
# 2  0.308203 -0.290688  1.068174  ...  1.614935  0.077580 -0.243821 -0.923067
# 3  0.318275 -0.288842  1.113455  ...  1.637067  0.101625 -0.237792 -0.960264
# 4  0.331747 -0.309921  1.149851  ...  1.686988  0.087522 -0.244171 -0.975921
#
#         122       123       124       125       126       127
# 0 -0.104974 -0.155675 -0.022122  0.397242 -1.146176 -0.042564
# 1 -0.108789 -0.148499 -0.004750  0.408538 -1.182146 -0.052888
# 2 -0.091465 -0.155652 -0.013521  0.383262 -1.120166 -0.075994
# 3 -0.105029 -0.156502 -0.000799  0.407506 -1.141540 -0.053185
# 4 -0.099082 -0.145192  0.006959  0.405039 -1.177663 -0.068183
#
# [5 rows x 128 columns]
# (21518, 128)

# %% [markdown]
# ### Step 2: Generating Node Target List for Color Mapping
#
# In order to generate a color map with a legend for each node type, we need to traverse through the node_indexes list and assign each node to its corresponding node type.

# %%
node_targets = ['tag' if id.startswith('t') else 'artist' if id.startswith('a') else 'user' for id in node_indexes]

print(node_targets)
# Out:
# ['tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'user', 'tag', 'tag', 'tag', 'tag', 'tag', 'user', 'tag', 'tag', 'tag', 'tag', 'tag', 'artist', 'tag', 'tag', 'tag', 'artist', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'user', 'tag', 'user', 'tag', 'tag', 'tag', 'tag', 'tag', 'artist', 'user', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'artist', 'tag', 'tag', 'tag', 'artist', 'tag', 'tag', 'tag', 'tag', 'artist', 'tag', 'user', 'tag', 'tag', 'tag', 'tag', 'artist', 'tag', 'artist', 'tag', 'artist', 'tag', 'tag', 'tag', 'tag', 'artist', 'tag', 'artist', 'tag', 'tag', 'tag', 'artist', 'tag', 'artist', 'tag', 'tag', 'tag', 'user', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'user', 'tag', 'artist', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'user', 'tag', 'artist', 'user', 'artist', 'user', 'tag', 'tag', 'artist', 'user', 'tag', 'tag', 'tag', 'tag', 'tag', 'tag', 'artist', 'tag', 'tag', 'tag', 'tag', 'user', 'user', 'artist', 'tag', 'tag', 'tag', 'tag', 'tag', 'artist', 'tag', 'tag', 'artist', 'user', 'artist', 'tag', 'artist', 'tag', 'tag', 'artist', 'user', 'user', 'tag', 'tag', 'artist', 'tag', 'user', 'tag', 'artist', 'user', 'tag', 'tag', 'user', 'tag', 'user', 'tag', 'user', 'user', 'user', 'tag', 'tag', 'tag', 'user', 'tag', 'tag', 'tag', 'user', 'artist', 'user', 'tag', 'tag', 'tag', 'user', 'user', 'user', 'user', 'tag', 'artist', 'user', 'tag', 'user', 'artist', 'artist', 'artist', 'tag', 'tag', 'tag', 'tag', 'user', 'artist', 'tag', 'tag', 'user', 'artist', 'user', 'tag', 'user', 'tag', 'user', 'artist', 'artist', 'artist', 'user', 'user', 'tag', 'tag', 'user', 'artist', 'user', 'artist', 'user', 'tag', 'user', 'user', 'tag', 'artist', 'user', 'user', 'tag', 'artist', 'artist', 'tag', 'user', 'user', 'user', 'user', 'tag', 'user', 'tag', 'user', 'user', 'tag', 'user', 'tag', 'user', 'user', 'tag', 'user', 'tag', 'user', 'user', 'user', 'tag', 'tag', 'tag', 'tag', 'user', 'user', 'tag', 'artist', 'tag', 'user', 'tag', 'user', 'tag', 'user', 'artist', 'user', 'user', 'user', 'tag', 'artist', 'tag', 'user', 'artist', 'user', 'tag', 'user', 'user', 'tag', 'user', 'artist', 'tag', 'tag', 'artist', 'user', 'tag', 'user', 'user', 'artist', 'tag', 'artist', 'user', 'user', 'tag', 'tag', 'user', 'tag', 'user', 'tag', 'tag', 'tag', 'user', 'tag', 'artist', 'user', 'user', 'user', 'artist', 'tag', 'tag', 'user', 'artist', 'tag', 'user', 'artist', 'user', 'user', 'user', 'tag', 'user', 'artist', 'user', 'tag', 'tag', 'user', 'user', 'tag', 'tag', 'user', 'tag', 'tag', 'user', 'tag', 'user', 'tag', 'tag', 'tag', 'tag', 'user', 'tag', 'user', 'user', 'tag', 'user', 'user', 'artist', 'user', 'user', 'tag', 'tag', 'user', 'user', 'user', 'user', 'user', 'artist', 'user', 'user', 'user', 'tag', 'tag', 'artist', 'tag', 'tag', 'artist', 'tag', 'user', 'artist', 'tag', 'user', 'user', 'user', 'artist', 'tag', 'tag', 'user', 'artist', 'tag', 'user', 'tag', 'artist', 'artist', 'user', 'user', 'tag', 'artist', 'user', 'user', 'user', 'tag', 'tag', 'tag', 'user', 'artist', 'tag', 'user', 'user', 'artist', 'user', 'user', 'tag', 'user ...

# %% [markdown]
# ### Step 3: Run t-SNE on Embedding DF

# %%
from sklearn.manifold import TSNE


transform = TSNE  # PCA

trans = transform(n_components=2)
node_embeddings_2d = trans.fit_transform(embeddings_df)

# %% [markdown]
# ### Step 4: Creating Color Map and Plotting t-SNE Results

# %%
#Create a Color Map
unique_targets = np.unique(node_targets)
colors = plt.cm.get_cmap('viridis', len(unique_targets))  # You can choose different colormaps
label_map = {label: colors(i) for i, label in enumerate(unique_targets)}
node_colours = [label_map[target] for target in node_targets]

#Plotting
plt.figure(figsize=(20, 16))
for target in unique_targets:
    indices = [i for i, x in enumerate(node_targets) if x == target]
    plt.scatter(node_embeddings_2d[indices, 0], node_embeddings_2d[indices, 1], color=label_map[target], label=target, alpha=0.5)

plt.title("t-SNE visualization of JUST node embeddings")
plt.legend(loc='best')  # Adjust the legend location as needed
plt.show()
